# %% [markdown]
# ### Dataset

# %%
# Basic corpus statistics & script coverage (choose split)
from pathlib import Path
from collections import Counter
import unicodedata, math

SPLIT = "train"  # "train", "valid", or "test"
corpus_path = Path('..') / f'/content/hicm_corpus.{SPLIT}.txt'
#/content/hicm_corpus.train.txt
assert corpus_path.exists(), f"Corpus file not found for split '{SPLIT}'."

sample_lines = 250000  # adjust for speed vs accuracy
char_counter = Counter()
line_count = 0

# Unicode block ranges
DEV_START, DEV_END = 0x0900, 0x097F
LAT_START, LAT_END = 0x0041, 0x007A  # rough (includes uppercase/lowercase subset)

with corpus_path.open('r', encoding='utf-8') as f:
    for line in f:
        line_count += 1
        for ch in line.rstrip('\n'):
            char_counter[ch] += 1
        if line_count >= sample_lines:
            break

cats = Counter()
for ch, freq in char_counter.items():
    cp = ord(ch)
    if DEV_START <= cp <= DEV_END:
        cats['Devanagari'] += freq
    elif 'A' <= ch <= 'Z' or 'a' <= ch <= 'z':
        cats['Latin'] += freq
    elif ch.isdigit():
        cats['Digits'] += freq
    elif ch.isspace():
        cats['Whitespace'] += freq
    else:
        cats['Other'] += freq

total_chars = sum(cats.values())
print(f"Split: {SPLIT}")
print(f"Lines sampled: {line_count:,}")
print(f"Unique chars in sample: {len(char_counter):,}")
print("Character category distribution (approx):")
for k, v in cats.items():
    print(f"  {k:12s}: {v:10d}  ({v/total_chars*100:5.2f}%)")

coverage = total_chars / sum(char_counter.values())
print(f"Character coverage observed (sampling fraction): {coverage:0.4f}")

# Show top 20 Devanagari chars and top 20 Latin chars
print('\nTop 20 Devanagari chars:')
dev_top = [(c, char_counter[c]) for c in char_counter if DEV_START <= ord(c) <= DEV_END]
for c, freq in sorted(dev_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")

print('\nTop 20 Latin chars:')
lat_top = [(c, char_counter[c]) for c in char_counter if ('A' <= c <= 'Z' or 'a' <= c <= 'z')]
for c, freq in sorted(lat_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")
# Out:
# Split: train
# Lines sampled: 250,000
# Unique chars in sample: 256
# Character category distribution (approx):
#   Devanagari  :    5661498  (52.55%)
#   Whitespace  :    1768861  (16.42%)
#   Latin       :    3291223  (30.55%)
#   Digits      :      46988  ( 0.44%)
#   Other       :       5783  ( 0.05%)
# Character coverage observed (sampling fraction): 1.0000
#
# Top 20 Devanagari chars:
#   ा : 471759
#   क : 441787
#   े : 384211
#   र : 340468
#   ह : 261269
#   ् : 247805
#   न : 232096
#   स : 222320
#   ि : 219077
#   ं : 212237
#   ी : 211774
#   त : 196960
#   म : 173584
#   ो : 151878
#   य : 147182
#   प : 137621
#   ल : 130523
#   ै : 110126
#   व : 105705
#   । : 93437
#
# Top 20 Latin chars:
#   e : 390334
#   a : 288520
#   i : 265743
#   t : 250821
#   r : 237903
#   n : 236442
#   s : 233903
#   o : 217772
#   l : 157297
#   c : 138138
#   d : 126591
#   m : 104110
#   u : 103160
#   p : 99256
#   h : 79936
#   g : 75503
#   y : 52465
#   f : 52339
#   b : 49796
#   v : 39678

# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)

# %%
# Train SentencePiece Unigram tokenizer
import sentencepiece as spm
from pathlib import Path

corpus_path = Path('..') / '/content/hicm_corpus.train.txt'
assert corpus_path.exists(), "Train corpus file missing. Build it first."

VOCAB_SIZE = 32000  # change to e.g. 38000 or 40000 if needed
MODEL_PREFIX = f"hicm_unigram_{VOCAB_SIZE}"
MODEL_TYPE = 'unigram'
CHAR_COVERAGE = 1.0
NORMALIZATION = 'nfkc'

model_file = Path(f"{MODEL_PREFIX}.model")
vocab_file = Path(f"{MODEL_PREFIX}.vocab")

if model_file.exists():
    print(f"Model {model_file} already exists. Delete it to retrain.")
else:
    cmd = (
        f"--input={corpus_path} "
        f"--model_prefix={MODEL_PREFIX} "
        f"--model_type={MODEL_TYPE} "
        f"--vocab_size={VOCAB_SIZE} "
        f"--character_coverage={CHAR_COVERAGE} "
        f"--normalization_rule_name={NORMALIZATION} "
        f"--unk_id=0 --unk_piece=<unk> "
        f"--bos_id=1 --bos_piece=<bos> "
        f"--eos_id=2 --eos_piece=<eos> "
        f"--pad_id=3 --pad_piece=<pad> "
        f"--input_sentence_size=8000000 --shuffle_input_sentence=true "
        f"--max_sentence_length=2048 "
    )
    print("Training command:\n", cmd)
    spm.SentencePieceTrainer.Train(cmd)
    print("Training complete.")
    print("Generated files:", model_file, vocab_file)

# Quick sanity check
sp = spm.SentencePieceProcessor()
sp.load(str(model_file))
print("Loaded model with vocab size:", sp.get_piece_size())
print("Sample pieces:", [sp.id_to_piece(i) for i in range(10)])
# Out:
# Training command:
#  --input=/content/hicm_corpus.train.txt --model_prefix=hicm_unigram_32000 --model_type=unigram --vocab_size=32000 --character_coverage=1.0 --normalization_rule_name=nfkc --unk_id=0 --unk_piece=<unk> --bos_id=1 --bos_piece=<bos> --eos_id=2 --eos_piece=<eos> --pad_id=3 --pad_piece=<pad> --input_sentence_size=8000000 --shuffle_input_sentence=true --max_sentence_length=2048
# Training complete.
# Generated files: hicm_unigram_32000.model hicm_unigram_32000.vocab
# Loaded model with vocab size: 32000
# Sample pieces: ['<unk>', '<bos>', '<eos>', '<pad>', '\r', '▁के', '।', '▁में', '▁है', '▁की']

# %%
# Advanced analysis: segmentation stats & script ratios
from pathlib import Path
import sentencepiece as spm
from collections import Counter
import random

VOCAB_SIZE = 32000
MODEL_PREFIX = f"hicm_unigram_{VOCAB_SIZE}"
model_file = Path(f"{MODEL_PREFIX}.model")
corpus_path = Path('..') / '/content/hicm_corpus.train.txt'

sp = spm.SentencePieceProcessor(); sp.load(str(model_file))

sample_limit = 5000
lengths = []
script_piece_counter = Counter()
DEV_START, DEV_END = 0x0900, 0x097F

with corpus_path.open('r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.strip()
        if not line: continue
        pieces = sp.encode(line, out_type=str)
        lengths.append(len(pieces))
        for p in pieces:
            # classify piece by first char heuristic
            if p.startswith('<'): # special
                script_piece_counter['SPECIAL'] += 1
            else:
                ch = p[0]
                cp = ord(ch)
                if DEV_START <= cp <= DEV_END:
                    script_piece_counter['DEV'] += 1
                elif ('A' <= ch <= 'Z') or ('a' <= ch <= 'z'):
                    script_piece_counter['LAT'] += 1
                elif ch.isdigit():
                    script_piece_counter['DIGIT'] += 1
                else:
                    script_piece_counter['OTHER'] += 1
        if i+1 >= sample_limit:
            break

avg_len = sum(lengths)/len(lengths)
print(f"Sampled sentences: {len(lengths)}")
print(f"Avg pieces per sentence: {avg_len:0.2f}")
print("Piece script distribution:")
for k,v in script_piece_counter.items():
    print(f"  {k:7s}: {v:7d} ({v/sum(script_piece_counter.values())*100:5.2f}%)")

# OOV simulation: replace 0.5% of chars with a rare symbol and observe unk rate
random.seed(13)
rare_char = '¤'  # seldom used
modified_lines = []
with corpus_path.open('r', encoding='utf-8') as f:
    for i, line in enumerate(f):
        if i >= 1000: break
        chars = list(line.strip())
        for idx, ch in enumerate(chars):
            if random.random() < 0.005:
                chars[idx] = rare_char
        modified_lines.append(''.join(chars))

unk_id = sp.piece_to_id('<unk>')
unk_tokens = 0
total_tokens = 0
for line in modified_lines:
    ids = sp.encode(line, out_type=int)
    total_tokens += len(ids)
    unk_tokens += sum(1 for i in ids if i == unk_id)

# Out of
print(f"\nOOV simulation on 1000 lines: unk token rate = {unk_tokens/total_tokens*100:5.3f}%")
print("Done.")
# Out:
# Sampled sentences: 5000
# Avg pieces per sentence: 9.62
# Piece script distribution:
#   OTHER  :   40137 (83.44%)
#   DEV    :    5426 (11.28%)
#   LAT    :    2456 ( 5.11%)
#   DIGIT  :      83 ( 0.17%)
#
# OOV simulation on 1000 lines: unk token rate = 0.000%
# Done.

# %%
# Load & test tokenizer on full file (returns list of token lists)
import sentencepiece as spm
from pathlib import Path

VOCAB_SIZE = 32000
MODEL_PREFIX = f"hicm_unigram_{VOCAB_SIZE}"
model_file = Path(f"{MODEL_PREFIX}.model")
assert model_file.exists(), "Model file missing. Train tokenizer first."

sp = spm.SentencePieceProcessor()
sp.load(str(model_file))

# ---- NEW FUNCTION: tokenize a file line-by-line ----
def tokenize_file(filepath: str):
    filepath = Path(filepath)
    assert filepath.exists(), f"Input file not found: {filepath}"

    tokenized_lines = []

    with filepath.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                tokenized_lines.append([])   # Empty line → empty token list
            else:
                tokenized_lines.append(sp.encode(line, out_type=str))

    return {
        "num_lines": len(tokenized_lines),
        "tokens_per_line": tokenized_lines
    }

# ---- USAGE ----
input_file = "hicm_corpus.train.txt"   # <-- replace with your file path
result = tokenize_file(input_file)

result
# Out:
# {'num_lines': 4200000,
#  'tokens_per_line': [['▁दूसरे',
#    '▁दिन',
#    '▁मैंने',
#    '▁झूल',
#    'े',
#    '▁पर',
#    '▁खेल',
#    'ती',
#    '▁हुई',
#    '▁a',
#    '▁छोटी',
#    '▁सी',
#    '▁प्यार',
#    'ी',
#    'प',
#    '्या',
#    'री',
#    '▁girl',
#    '▁देखी',
#    '।'],
#   ['▁झारखंड', '▁उच्च', '▁court', '▁की', '▁website', '▁देखें'],
#   ['▁st', 'y', 'li', 'st', '▁प्र', 'साधक'],
#   ['▁display', '▁s', '▁पर', '▁रु', 'ट', '▁login', '▁वर्जित', '▁है'],
#   ['▁हर',
#    '▁चीज',
#    '▁की',
#    '▁relevan',
#    'ce',
#    '▁का',
#    '▁final',
#    '▁measure',
#    '▁life',
#    '▁ही',
#    '▁हो',
#    '▁सकता',
#    '▁है',
#    '।'],
#   ['▁women', '▁empowerment', '▁समिति'],
#   ['▁आप',
#    '▁a',
#    '▁खिला',
#    'डी',
#    '▁कि',
#    '▁कीमत',
#    '▁कैसे',
#    '▁fix',
#    '▁करते',
#    '▁हैं'],
#   ['▁कृपया',
#    '▁इस',
#    '▁action',
#    '▁के',
#    '▁समर्थन',
#    '▁में',
#    '▁उद्देश्य',
#    '▁और',
#    '▁reasons',
#    '▁को',
#    '▁प्रस्तुत',
#    '▁करें',
#    '।'],
#   ['▁इमारत',
#    'ी',
#    '▁timber',
#    '▁furniture',
#    '▁तथा',
#    '▁fuel',
#    '▁के',
#    '▁लिए',
#    '▁forest',
#    '▁काटे',
#    '▁गये',
#    '।'],
#   ['▁national', '▁human', '▁आयोग', '▁भारत'],
#   ['▁events',
#    '▁ही',
#    '▁समय',
#    '▁में',
#    '▁कहीं',
#    '▁south',
#    '▁मलाबार',
#    '▁में',
#    '▁घटी',
#    '▁है',
#    '।'],
#   ['▁मुद्रक', '▁की', '▁state'],
#   ['▁ग़',
#    'ा',
#    'ज़',
#    'ियों',
#    '▁के',
#    '▁सर',
#    'पट',
#    '▁दौड़ने',
#    '▁वाले',
#    '▁horses',
#    '▁की',
#    '▁war'],
#   ['▁vagina', '▁में', '▁प्रवेश', '▁एक', '▁penis'],
#   ['▁सारे', '▁public', '▁interface', 's', '▁सुन', 'ें'],
#   ['▁एक',
#    '▁fo',
#    'll',
#    'icular',
#    '▁हाइपर',
#    '▁के',
#    'र',
#    'ैट',
#    'ोसिस',
#    '▁जो',
#    '▁प्रायः',
#    '▁विटामिन',
#    'ए',
#    '▁की',
#    '▁deficiency',
#    '▁से',
#    '▁होता',
#    '▁है'],
#   ['▁file', '▁स्वरूप'],
#   ['▁संपूर्ण',
#    '▁सुरक्षा',
#    '▁incident',
#    '▁रिपोर्टिंग',
#    '▁प्रपत्र',
#    '▁जमा',
#    '▁करना'],
#   ['▁अतः',
#    '▁कुछ',
#    '▁नहीं',
#    '▁मैं',
#    '▁by',
#    '▁खाता',
#    '▁हूँ',
#    '▁पूर्व',
#    'ों',
#    '▁और',
#    '▁places',
#    '▁के',
#    '▁रब',
#    '▁की',
#    '▁हमे',
#    '▁इसकी',
#    '▁able',
#    '▁प्राप्त',
#    '▁है'],
#   ['▁प्रत्यक्ष', '▁व्यय', '▁की', '▁कौन', 'सी', '▁expenses', 's', '▁हैं'],
#   ['▁भले',
#    '▁ही',
#    '▁उस',
#    '▁book',
#    '▁में',
#    '▁एक',
#    '▁z',
#    'ill',
#    'ion',
#    '▁comic',
#    '▁पुस्तक',
#    '▁अक्षर',
#    '▁था'],
#   ['▁अनन्त', '▁शयन', 'म्', '▁ayyangar'],
#   ['▁को', 'णीय', '▁और', '▁ulcer', 'ative', '▁s', 'to', 'mat', 'itis'],
#   ['▁इस',
#    '▁account',
#    '▁को',
#    '▁अनुप्रयोग',
#    '▁विशिष्ट',
#    '▁password',
#    '▁की',
#    '▁जरुरत',
#    '▁है',
#    '▁s'],
#   ['▁जो', '▁कि', '▁global', '▁की', '▁short', '▁messaging', '▁सेवा', '▁है'],
#   ['▁हम', '▁both', '▁से', '▁निकलेंगे', '▁और', '▁ये', '▁दोनो'],
#   ['▁accounting',
#    '▁तथा',
#    '▁लेखापरीक्षा',
#    '▁से',
#    '▁proper',
#    '▁standard',
#    '▁का',
#    '▁सुनिश्च',
#    'य',
#    '▁करना'],
#   ['▁क्या',
#    '▁नोड्स',
#    '▁n',
#    '▁की',
#    '▁number',
#    '▁के',
#    '▁संदर्भ',
#    '▁में',
#    '▁di',
#    'j',
#    'ks',
#    'tra',
#    '▁के',
#    '▁time',
#    '▁चल',
#    '▁रहा',
#    '▁है'],
#   ['▁इसका',
#    '▁अर्थ',
#    '▁है',
#    '▁प्रकृति',
#    '▁को',
#    '▁इसकी',
#    '▁सभी',
#    '▁diversity',
#    '▁उपहार',
#    'ों',
#    '▁तथा',
#    '▁mun',
#    'ific',
#    'ence',
#    '▁सहित',
#    '▁अपनाना',
#    '।'],
#   ['▁साधारण',
#    '▁शब्दों',
#    '▁में',
#    '▁इस',
#    '▁proteins',
#    '▁को',
#    '▁4',
#    '▁categories',
#    '▁में',
#    '▁बांटा',
#    '▁जा',
#    '▁सकता',
#    '▁है'],
#   ['▁convert', 'ibility', '▁विन', 'िम', 'ेय', 'ता'],
#   ['▁भारतीय', '▁economy', '▁पर', '▁प्रभाव'],
#   ['▁के',
#    '▁द्वारा',
#    '▁defined',
#    '▁machine',
#    '▁नाम',
#    '▁से',
#    '▁port',
#    '▁जिससे',
#    '▁आप',
#    '▁प्राक्',
#    'सी',
#    '▁से',
#    '▁होकर',
#    '▁जाते',
#    '▁हैं'],
#   ['▁एन',
#    'ोफ',
#    '्ली',
#    'स',
#    '▁की',
#    '▁कुछ',
#    '▁species',
#    '▁ही',
#    '▁malaria',
#    '▁फैला',
#    'ती',
#    '▁हैं'],
#   ['▁waste',
#    '▁जिसका',
#    '▁अन्य',
#    '▁living',
#    '▁organisms',
#    '▁द्वारा',
#    '▁क्षय',
#    '▁किया',
#    '▁जाता',
#    '▁है'],
#   ['▁पिछली', '▁thread', '▁प्रदर्शित', '▁करें'],
#   ['▁capital',
#    '▁payments',
#    '▁बजट',
#    '▁provision',
#    '▁से',
#    '▁अधिक',
#    '▁नहीं',
#    '▁होना',
#    '▁चाहिए',
#    '।'],
#   ['▁हिन्दी',
#    '▁इनमें',
#    '▁से',
#    '▁सबसे',
#    '▁अधिक',
#    '▁develop',
#    '▁थी',
#    '▁44',
#    '▁अतः',
#    '▁उसको',
#    '▁भाषा',
#    '▁की',
#    '▁recognition',
#    '▁मिली',
#    '।'],
#   ['▁किसी',
#    '▁something',
#    '▁को',
#    '▁li',
#    'king',
#    '▁करने',
#    '▁का',
#    '▁अधिनियम',
#    '।'],
#   ['▁material', '▁production', '▁और', '▁वितरण'],
#   ['▁distribution',
#    '▁में',
#    '▁reports',
#    '▁की',
#    '▁शिकायत',
#    '▁की',
#    '▁गई',
#    '▁है',
#    '।'],
#   ['▁क्या',
#    '▁लोग',
#    '▁fire',
#    '▁बुझाने',
#    '▁वाले',
#    '▁brigade',
#    '▁ला',
#    '▁कर',
#    '▁fire',
#    '▁नहीं',
#    '▁बुझा',
#    'ते'],
#   ['▁offspring', '▁या', '▁a', '▁व्यक्ति', '▁का', '▁तत्काल', '▁children'],
#   ['▁depression',
#    '▁के',
#    '▁उपचार',
#    '▁के',
#    '▁लिए',
#    '▁used',
#    '▁होने',
#    '▁वाली',
#    '▁दवा',
#    '▁को',
#    '▁ant',
#    'ide',
#    'press',
#    'ants',
#    '▁दवा',
#    '▁एंट',
#    'िड',
#    'ि',
#    'प्रेस',
#    'ेंट',
#    '▁कहते',
#    '▁हैं',
#    '।'],
#   ['▁कहो',
#    'गे',
#    '▁के',
#    '▁यदि',
#    '▁मुझे',
#    '▁नही',
#    '▁know',
#    '▁होता',
#    '▁तो',
#    '▁मैं',
#    '▁यहाँ',
#    '▁3',
#    '▁रखता',
#    '▁और'],
#   ['▁ऐसे',
#    '▁बैंक',
#    '▁जो',
#    '▁foreign',
#    '▁में',
#    '▁registered',
#    '▁हों',
#    '▁तथा',
#    '▁जिनक',
#    'ा',
#    '▁head',
#    '▁देश',
#    '▁की',
#    '▁सीमा',
#    '▁से',
#    '▁बाहर',
#    '▁हो',
#    '।'],
#   ['▁हर',
#    '▁year',
#    '▁diwali',
#    '▁पूरे',
#    '▁india',
#    '▁में',
#    '▁और',
#    '▁दुनिया',
#    '▁भर',
#    '▁में',
#    '▁मनाई',
#    '▁जाती',
#    '▁है',
#    '।'],
#   ['▁इन',
#    '▁one',
#    's',
#    '▁को',
#    '▁रद्द',
#    '▁करें',
#    '▁और',
#    '▁हम',
#    '▁n',
#    'm',
#    '▁r',
#    '▁हो'],
#   ['▁priyobroto',
#    '▁को',
#    '▁लगा',
#    '▁था',
#    '▁कि',
#    '▁khudi',
#    'k',
#    'elo',
#    '▁नहीं',
#    '▁नहीं',
#    '▁केवल',
#    '▁tea',
#    '▁अथवा',
#    '▁इसी',
#    '▁like',
#    '▁का',
#    '▁कुछ',
#    '▁कहेगा',
#    '।'],
#   ['▁यूआरएल', '▁इतिहास', '▁में', '▁items', '▁की', '▁number'],
#   ['▁ऐसा',
#    '▁amazing',
#    '▁व्यापार',
#    '▁हमारे',
#    '▁पुरातन',
#    'पन',
#    '्थ',
#    'ी',
#    '▁land',
#    '▁में',
#    '▁ही',
#    '▁पनप',
#    '▁सकता',
#    '▁है',
#    '।'],
#   ['▁last', '▁का', '▁submission', '▁दिनांक', '▁10', '112014'],
#   ['▁बिक्री', '▁कर', '▁registration', '▁no'],
#   ['▁तल',
#    'छ',
#    'ट',
#    '▁तरल',
#    '▁से',
#    '▁col',
#    'ect',
#    'ed',
#    '▁किया',
#    '▁गया',
#    '▁और',
#    '▁उनकी',
#    '▁composition',
#    '▁का',
#    '▁studied',
#    '▁किया',
#    '▁गया'],
#   ['▁कुछ',
#    '▁ही',
#    '▁दिनों',
#    '▁में',
#    '▁thousands',
#    '▁लाख',
#    'ो',
#    '▁people',
#    '▁व',
#    'ं',
#    'हा',
#    '▁थे'],
#   ['▁ने',
#    'ट',
#    'लिंक',
#    '▁नियंत्रण',
#    '▁श्रेय',
#    '▁enable',
#    '▁सक्रिय',
#    '▁करने',
#    '▁में',
#    '▁असमर्थः',
#    '▁s'],
#   ['▁इससे',
#    '▁हमें',
#    '▁cause',
#    '▁चिंता',
#    '▁होगी',
#    '▁और',
#    '▁हमें',
#    '▁अधिक',
#    '▁vigilance',
#    '▁तथा',
#    '▁तैयार',
#    '▁रहना',
#    '▁पड़ेगा',
#    '।'],
#   ['▁यह',
#    '▁स्व',
#    'ीय',
#    'कृति',
#    '▁मनो',
#    'नीत',
#    '▁national',
#    '▁य',
#    '▁authorities',
#    '▁द्वारा',
#    '▁दी',
#    '▁जाती',
#    '▁है',
#    '।',
#    '▁सीडी'],
#   ['▁अध्यक्ष',
#    '▁से',
#    '▁new',
#    '▁योजना',
#    '▁को',
#    '▁approve',
#    '▁करने',
#    '▁का',
#    '▁urged',
#    '▁किया',
#    '▁गया',
#    '▁है',
#    '।'],
#   ['▁we', 'i', '▁river', '▁चीन'],
#   ['▁इन', '▁files', '▁या', '▁फ़ोल्डर', 'ों', '▁की', '▁तुलना', '▁करें'],
#   ['▁नुक्सान', '▁कि', 'न', '▁में', '▁accumulate', '▁हो', '▁सकता', '▁है'],
#   ['▁इसके',
#    '▁प्रमुख',
#    '▁मुख्य',
#    '▁central',
#    '▁आयुक्त',
#    '▁केन्द्री',
#    '▁labour',
#    '▁है',
#    '।'],
#   ['▁जब',
#    '▁short',
#    '▁कालावधि',
#    '▁में',
#    '▁अनेक',
#    '▁financial',
#    '▁companies',
#    '▁अस्तित्व',
#    '▁में',
#    '▁आ',
#    '▁गई',
#    '▁हों',
#    '।'],
#   ['▁एक', '▁prefix', '▁जिसका', '▁अर्थ', '▁है', '▁jaundice', '▁है'],
#   ['▁state', '▁बैंक', '▁ऑफ़', '▁patiala'],
#   ['▁प्रत्येक',
#    '▁locality',
#    '▁में',
#    '▁पुस्तकालय',
#    '▁की',
#    '▁establishment',
#    '▁तथा',
#    '▁प्रौढ़',
#    'शिक्षा',
#    '▁की',
#    '▁encourage',
#    'd',
#    '▁दिया',
#    '▁जाना',
#    '▁चाहिए',
#    '।'],
#   ['▁प्रदाह', 'क', '▁bowel', '▁रोग'],
#   ['▁kidney', '▁जहां', '▁multiple', '▁nephro', 'ns', '▁जा', '▁रहे', '▁हैं'],
#   ['▁अनुचित', '▁होने', '▁के', '▁virtue', '▁not', '▁कोई', '▁राशि'],
#   ['▁आए', '▁अन्य', '▁जन', '▁लेकर', '▁iron', '▁शृंखला', 'एं'],
#   ['▁आप',
#    '▁permission',
#    '▁के',
#    '▁लिए',
#    '▁token',
#    's',
#    '▁सक्रिय',
#    '▁नहीं',
#    '▁है'],
#   ['▁a',
#    '▁गंभीर',
#    '▁attack',
#    '▁के',
#    '▁समय',
#    '▁साँस',
#    '▁लेने',
#    '▁में',
#    '▁difficult',
#    '▁स्पष्ट',
#    '▁दिखाई',
#    '▁देती',
#    '▁है'],
#   ['▁assistant', '▁प्रचालक', '▁sub', '▁स्टेशन'],
#   ['▁जब',
#    '▁तक',
#    '▁मैं',
#    '▁mr',
#    '▁car',
#    'lock',
#    '▁के',
#    '▁विज्ञान',
#    '▁class',
#    '▁मे',
#    '▁नही',
#    '▁गई'],
#   ['▁अभी',
#    '▁के',
#    '▁लिए',
#    '▁के',
#    '▁लिए',
#    '▁इस',
#    '▁class',
#    '▁के',
#    '▁मुझे',
#    '▁लगता',
#    '▁है',
#    '▁कि',
#    '▁हम',
#    '▁सिर्फ',
#    '▁इस',
#    '▁definition',
#    '▁का',
#    '▁use',
#    '▁करना',
#    '▁चाहिए',
#    '।'],
#   ['▁न',
#    'न्द',
#    '▁का',
#    '▁father',
#    '▁या',
#    '▁कोई',
#    '▁male',
#    '▁अभि',
#    'वा',
#    'वक',
#    '▁home',
#    '▁पर',
#    '▁नहीं',
#    '▁था',
#    '।'],
#   ['▁और',
#    '▁अपनी',
#    '▁mercy',
#    '▁से',
#    '▁अपने',
#    '▁brother',
#    '▁हारून',
#    '▁को',
#    '▁नबी',
#    '▁बनाकर',
#    '▁उसे',
#    '▁दिया'],
#   ['▁ये',
#    '▁देख',
#    '▁कर',
#    '▁he',
#    '▁बोल',
#    '▁उठे',
#    'गा',
#    '▁कि',
#    '▁allah',
#    '▁की',
#    '▁क़सम',
#    '▁तुम',
#    '▁तो',
#    '▁मुझे',
#    '▁भी',
#    '▁ruin',
#    'ed',
#    '▁करने',
#    '▁ही',
#    '▁को',
#    '▁थे'],
#   ['▁hot',
#    '▁और',
#    '▁sp',
#    'ic',
#    'y',
#    '▁ख',
#    'ट्टे',
#    '▁व',
#    '▁नमक',
#    'ीन',
#    '▁items',
#    '▁का',
#    '▁सेवन',
#    '▁नहीं',
#    '▁करना',
#    '▁चाहिए',
#    '।'],
#   ['▁in',
#    '▁के',
#    '▁हर',
#    '▁corner',
#    '▁के',
#    '▁people',
#    '▁से',
#    '▁जुड़ने',
#    '▁के',
#    '▁लिए',
#    '▁',
#    'समयसमय',
#    '▁पर'],
#   ['▁मंडप',
#    '▁में',
#    '▁आगे',
#    '▁और',
#    '▁पीछे',
#    '▁two',
#    '▁bays',
#    '▁हैं',
#    '▁जो',
#    '▁mukha',
#    '▁और',
#    '▁ardha',
#    '▁बनाते',
#    '▁हैं',
#    '।'],
#   ['▁समान',
#    '▁में',
#    '▁change',
#    '▁लाने',
#    '▁में',
#    '▁science',
#    '▁major',
#    '▁प्रेरक',
#    '▁शक्ति',
#    '▁है',
#    '।'],
#   ['▁सिं',
#    'ब',
#    'ियो',
#    'सिस',
#    '▁ने',
#    '▁thousands',
#    '▁students',
#    '▁के',
#    '▁fortune',
#    's',
#    '▁का',
#    '▁कायापलट',
#    '▁किया',
#    '▁है',
#    '।'],
#   ['▁educational',
#    '▁स्वयं',
#    '▁organization',
#    '▁के',
#    '▁उत्पाद',
#    '▁के',
#    '▁रूप',
#    '▁में',
#    '।'],
#   ['▁फ़ाइल', '▁delete'],
#   ['▁रोज', 'ा', '▁parks', '▁से', '▁martin', '▁लू', 'थर', '▁king', '▁तक'],
#   ['▁अपना', '▁personal', '▁trash', '▁फ़ोल्डर', '▁खोलें'],
#   ['▁मुगल', '▁delhi'],
#   ['▁विषम', '▁show', '▁शीर्ष', 'सूचना'],
#   ['▁अपने',
#    '▁क्षेत्र',
#    '▁की',
#    '▁always',
#    '▁लड़ने',
#    '▁को',
#    '▁ter',
#    'it',
#    'tory',
#    '▁रहते',
#    '▁हैं',
#    '।'],
#   ['▁नियत', '▁point', '▁representation', '▁तंत्र'],
#   ['▁search', '▁इंजिन', '▁select'],
#   ['▁मैं', '▁तुम्हें', '▁an', '▁सादृश्य', '▁दूँ', 'गी'],
#   ['▁और',
#    '▁अध्यापक',
#    '▁education',
#    '▁के',
#    '▁standards',
#    '▁एवं',
#    '▁स्तरों',
#    '▁का',
#    '▁उचित',
#    '▁संरक्षण',
#    '▁किया',
#    '▁जा',
#    '▁सके',
#    '।'],
#   ['▁वे',
#    'खंड',
#    '▁इसका',
#    '▁underground',
#    '▁डंठल',
#    '▁useful',
#    '▁होता',
#    '▁है',
#    '।'],
#   ['▁samaj', '▁इसी', '▁परंपरा', '▁का', '▁महत्वपूर्ण', '▁part', '▁है', '।'],
#   ['▁c',
#    '▁ऐसे',
#    '▁other',
#    '▁राज्यक्षेत्र',
#    '▁जो',
#    '▁acquired',
#    '▁किए',
#    '▁जाएँ',
#    '▁समाविष्ट',
#    '▁होंगे',
#    '।'],
#   ['▁ऊपर',
#    '▁entered',
#    '▁किये',
#    '▁गये',
#    '▁passphrase',
#    '▁की',
#    '▁confirm',
#    '▁करें'],
#   ['▁वे',
#    '▁इस',
#    '▁स्थान',
#    '▁की',
#    '▁natural',
#    '▁beauty',
#    '▁को',
#    '▁देख',
#    '▁place',
#    '▁थे',
#    '।'],
#   ['▁मूल्य',
#    '।',
#    '▁अगर',
#    '▁वे',
#    '▁000',
#    '▁सबसे',
#    '▁अच्छा',
#    '▁way',
#    '▁है',
#    '▁charging',
#    '▁कर',
#    '▁रहे',
#    '▁हैं'],
#   ['▁के', 'सी', 'एम', '▁user', 'ac', 'count'],
#   ['▁selected', '▁पंक्तियों', '▁की', '▁height'],
#   ['▁मंजूरी',
#    '▁authority',
#    '▁ex',
#    'tant',
#    '▁delegation',
#    '▁अधिकारों',
#    '▁के',
#    '▁अनुसार'],
#   ['▁हम', '▁लोग', '▁an', '▁कला', 'परियोजना', '▁कर', '▁रहे', '▁हैं'],
#   ['▁अतः',
#    '▁इस',
#    '▁बड़ी',
#    '▁money',
#    '▁की',
#    '▁व्यवस्था',
#    '▁india',
#    '▁से',
#    '▁ही',
#    '▁करनी',
#    '▁थी',
#    '।'],
#   ['▁अब',
#    '▁mutual',
#    '▁फंड',
#    '▁कंपनियां',
#    '▁overseas',
#    '▁सि',
#    'क्यू',
#    'रिटी',
#    '▁में',
#    '▁रुपया',
#    '▁लगा',
#    '▁सकेंगी',
#    '।'],
#   ['▁मस',
#    'ूल',
#    '▁माणिक',
#    '▁के',
#    '▁life',
#    '▁में',
#    '▁published',
#    '▁होने',
#    '▁वाला',
#    '▁last',
#    '▁उपन्यास',
#    '▁था',
#    '।'],
#   ['▁teaching', '▁विधि', 'याँ'],
#   ['▁इस',
#    '▁बड़े',
#    '▁x',
#    '▁मान',
#    '▁हम',
#    '▁पर',
#    '▁इस',
#    '▁point',
#    '▁के',
#    '▁साथ',
#    '▁शुरू'],
#   ['▁उन्होंने',
#    '▁singer',
#    '▁के',
#    '▁स्वर',
#    '▁को',
#    '▁पह',
#    'िच',
#    'ान',
#    'ते',
#    '▁हुए',
#    '▁बुल्ले',
#    '▁से',
#    '▁पूछा',
#    'क्या',
#    '▁तू',
#    '▁bulh',
#    'a',
#    '▁है'],
#   ['▁time',
#    '▁के',
#    '▁इस',
#    '▁point',
#    '▁पर',
#    '▁सं',
#    'चन',
#    'ल',
#    'गत',
#    '▁money',
#    '▁enough',
#    '▁नहीं',
#    '▁है',
#    '।'],
#   ['▁यहाँ', '▁चौराह', 'े', '▁पर', '▁मेरा', '▁x', 'मान', '▁went', '▁में'],
#   ['▁व्यापार',
#    '▁competition',
#    '▁रोक',
#    '▁गुट',
#    'बन',
#    '्दी',
#    '▁trade',
#    '▁गतिविधियों',
#    '▁के',
#    '▁संयम',
#    'न',
#    '▁के',
#    '▁intention',
#    '▁से',
#    '▁inspired',
#    '▁होती',
#    '▁है',
#    '।'],
#   ['▁यदि',
#    '▁यह',
#    '▁चुना',
#    '▁जाता',
#    '▁है',
#    '▁current',
#    '▁cell',
#    '▁पाठ',
#    '▁under',
#    'line',
#    'd',
#    '▁किया',
#    '▁जाएगा'],
#   ['▁कुछ',
#    '▁harmful',
#    '▁insects',
#    '▁भी',
#    '▁programme',
#    '▁में',
#    '▁highlight',
#    'ed',
#    '▁डाला',
#    '▁गया',
#    '▁है'],
#   ['▁सभी',
#    '▁संदेश',
#    '▁को',
#    '▁folder',
#    '▁में',
#    '▁बतौर',
#    '▁read',
#    '▁mark',
#    '▁करें'],
#   ['▁सॉफ्टवेयर',
#    '▁installer',
#    '▁को',
#    '▁शुरु',
#    '▁करे',
#    '▁और',
#    '▁input',
#    '▁flash',
#    '▁input',
#    '▁को',
#    '▁खोजें',
#    '।'],
#   ['▁financial', '▁सलाहकार'],
#   ['▁बहुत', '▁लघु', '▁आकार', '▁में', '▁photos', '▁वाली', '▁reduced'],
#   ['▁enough',
#    '▁information',
#    '▁j',
#    'na',
#    'anam',
#    'rut',
#    'am',
#    '▁आदि',
#    '▁पर',
#    '▁ar',
#    'nik',
#    '▁जानकारी'],
#   ['▁नी',
#    'रा',
#    '▁ऐसी',
#    '▁चीज',
#    '▁है',
#    '▁जिसे',
#    '▁निकालने',
#    '▁की',
#    '▁जगह',
#    '▁पर',
#    '▁ही',
#    '▁immediately',
#    '▁पीना',
#    '▁therefore',
#    '▁है',
#    '।'],
#   ['▁और',
#    '▁चैनल',
#    '▁बस',
#    '▁केवल',
#    '▁अंतिम',
#    'उपयोग',
#    'कर्ता',
#    '▁demand',
#    '▁को',
#    '▁fulfill',
#    '▁करने',
#    '▁के',
#    '▁लिए',
#    '▁है',
#    '।'],
#   ['▁tamil', '▁input', '▁विधि', '▁tamil', '99'],
#   ['▁कार्यस्थान', '▁3', '▁पर', '▁जाएँ'],
#   ['▁मुझे',
#    '▁mistakes',
#    '▁करने',
#    '▁का',
#    '▁right',
#    '▁है',
#    '▁और',
#    '▁सभी',
#    '▁व्यक्ति',
#    '▁की',
#    '▁responsibility',
#    '▁है',
#    '▁कि',
#    '▁उसे',
#    '▁स्वीकार',
#    '▁करें',
#    '।'],
#   ['▁राष्ट्र', '▁उन्हें', '▁gratitude', '▁के', '▁साथ', '▁याद', '▁रखेगा'],
#   ['▁और',
#    '▁हमने',
#    '▁उन',
#    '▁लोगों',
#    '▁पर',
#    '▁पत्थर',
#    '▁का',
#    '▁shower',
#    '▁बरसाया',
#    'प',
#    'स',
#    '▁observe',
#    '▁ग़ौर',
#    '▁तो',
#    '▁करो',
#    '▁कि',
#    '▁गुनाहगार',
#    'ों',
#    '▁का',
#    '▁end',
#    '▁आखिर',
#    '▁क्या',
#    '▁हुआ'],
#   ['▁इस', '▁तरह', '▁से', '▁उन', '▁modification', '▁में', '▁है'],
#   ['▁वह',
#    '▁position',
#    '▁जहां',
#    '▁वर्तमान',
#    '▁मान',
#    '▁displayed',
#    '▁किया',
#    '▁जाता',
#    '▁है'],
#   ['▁सुरक्षित', '▁password', '▁generator', '▁को', '▁शामिल', '▁करें'],
#   ['▁हं', 'गाम', 'ेदार', '▁b', 'ash'],
#   ['▁उनके',
#    '▁जीवन',
#    '▁ने',
#    '▁कई',
#    '▁हिन्दी',
#    '▁फ़िल्म',
#    'ों',
#    '▁के',
#    '▁characters',
#    '▁को',
#    '▁inspired',
#    '▁किया',
#    '।'],
#   ['▁बहुत',
#    '▁सारा',
#    '▁audio',
#    '▁चुना',
#    '▁गया',
#    '▁है',
#    '▁केवल',
#    '▁पहले',
#    '▁1',
#    'f',
#    '▁सेकंड',
#    '▁तक',
#    '▁ऑडियो',
#    '▁का',
#    '▁analyz',
#    'ed',
#    '▁किया',
#    '▁जाएगा'],
#   ['▁financial',
#    '▁penalty',
#    '▁को',
#    '▁seven',
#    '▁days',
#    '▁के',
#    '▁भीतर',
#    '▁भरना',
#    '▁होगा',
#    '।'],
#   ['▁प्रत्येक', '▁संदेश', '▁के', '▁साथ', '▁picture', '▁भेजें', '▁s'],
#   ['▁four', '▁बिट', '▁byte'],
#   ['▁दो',
#    '▁passage',
#    'way',
#    's',
#    '▁के',
#    '▁बीच',
#    '▁के',
#    '▁या',
#    '▁पीछे',
#    '▁के',
#    '▁buildings',
#    '▁गलियार',
#    'े',
#    '।'],
#   ['▁गैर', '▁सूचीबद्ध', '▁companies', '▁में', '▁नीति', 'गत', '▁निवेश'],
#   ['▁लगातार',
#    '▁दूसरे',
#    '▁year',
#    '▁यात्री',
#    '▁fare',
#    's',
#    '▁में',
#    '▁कोई',
#    '▁बढे',
#    'तर',
#    'ी',
#    '▁नहीं',
#    '▁की',
#    '▁गई'],
#   ['▁respect', '▁देंगे', '▁gratitude', '▁देंगे', '।'],
#   ['▁उसका',
#    '▁blood',
#    '▁रोगी',
#    '▁के',
#    '▁blood',
#    '▁से',
#    '▁incompatibl',
#    'e',
#    '▁या',
#    '▁बे',
#    'मेल',
#    '▁है'],
#   ['▁immature', '▁मोतियाबिंद'],
#   ['▁वह',
#    '▁पहले',
#    '▁man',
#    '▁थे',
#    '▁जिन्होंने',
#    '▁अपनी',
#    '▁language',
#    '▁में',
#    '▁आत्मकथा',
#    '▁लिखी',
#    '।'],
#   ['▁task', '▁preview', '▁पट्टी', '▁स्थिति'],
#   ['▁राज्य', '▁governments', '▁द्वारा', '▁की', '▁गई', '▁पहल'],
#   ['▁यह', '▁tree', '▁दक्षिण', '▁india', '▁में', '▁होता', '▁है', '।'],
#   ['▁उस', '▁day', '▁वह', '▁अपना', '▁relate', '▁सुना', 'ए', 'गी'],
#   ['▁people',
#    '▁के',
#    '▁groups',
#    '▁जो',
#    '▁खून',
#    '▁या',
#    '▁marriage',
#    '▁के',
#    '▁संबंधों',
#    '▁के',
#    '▁द्वारा',
#    '▁जुड़े',
#    '▁होते',
#    '▁हैं',
#    '।'],
#   ['▁जोड़ें', '▁a', '▁new', '▁target', '▁को'],
#   ['▁सन्',
#    '▁1911',
#    '▁तक',
#    '▁उनके',
#    '▁काम',
#    '▁के',
#    '▁hours',
#    '▁को',
#    '▁लेकर',
#    '▁नियंत्रण',
#    '▁की',
#    '▁कोई',
#    '▁कानूनी',
#    '▁regulatory',
#    '▁नहीं',
#    '▁थी'],
#   ['▁इस',
#    '▁aim',
#    '▁की',
#    '▁सिद्धि',
#    '▁के',
#    '▁लिये',
#    '▁manilal',
#    '▁अपनी',
#    '▁गद्य',
#    'शैली',
#    '▁में',
#    '▁विविधता',
#    '▁ले',
#    '▁आये',
#    '।'],
#   ['▁जाहिर',
#    '▁है',
#    '▁india',
#    '▁इस',
#    '▁मामले',
#    '▁में',
#    '▁सत',
#    '▁stuff',
#    '▁का',
#    '▁बना',
#    '▁है'],
#   ['▁shadow', '▁का', '▁angle'],
#   ['▁उन्हें',
#    '▁लेकर',
#    '▁people',
#    '▁disillusion',
#    'ed',
#    '▁के',
#    '▁शिकार',
#    '▁इसलिए',
#    '▁नहीं',
#    '▁हुए',
#    '▁कि',
#    '▁पह',
#    '▁moderate',
#    's',
#    '▁थे',
#    '▁और',
#    '▁कुछ',
#    '▁दूर',
#    '▁तक',
#    '▁extremist',
#    's',
#    '▁भी',
#    '।'],
#   ['▁brahman', '▁एक', '▁और', '▁सिर्फ़', '▁one', '▁ही', '▁है', '।'],
#   ['▁4', 'd', '▁दिक्', 'काल'],
#   ['▁company',
#    '▁ने',
#    '▁',
#    'om',
#    'r',
#    '▁चिह्न',
#    '▁पठन',
#    '▁हेतु',
#    '▁नया',
#    '▁स्कैन',
#    'र',
#    '▁खरीदा',
#    '▁है',
#    '।'],
#   ['▁अब',
#    '▁इस',
#    '▁node',
#    '▁और',
#    '▁उसके',
#    '▁मातापिता',
#    '▁के',
#    '▁बीच',
#    '▁be',
#    'lat',
#    'ed',
#    '▁से',
#    '▁ही',
#    '▁सही',
#    '▁हो',
#    '।',
#    '▁तो'],
#   ['▁nath', 'ur', 'am', '▁तथा', '▁apt', 'e', '▁का', '▁क्या', '▁हाल', '▁था'],
#   ['▁युद्ध',
#    '▁ने',
#    '▁area',
#    '▁में',
#    '▁अधिक',
#    '▁मारने',
#    '▁की',
#    '▁स्थिति',
#    '▁be',
#    'gotten',
#    '▁की',
#    '।'],
#   ['▁window',
#    '▁शीर्षक',
#    'ों',
#    '▁के',
#    '▁रूप',
#    '▁आकार',
#    '▁को',
#    '▁configure',
#    '▁करें',
#    'name'],
#   ['▁रक्तस्राव',
#    '▁blood',
#    '▁के',
#    '▁flowing',
#    '▁की',
#    '▁process',
#    '▁निरूपित',
#    '▁करता',
#    '▁है'],
#   ['▁दूसरे',
#    '▁दिन',
#    '▁वे',
#    '▁सारे',
#    '▁physician',
#    's',
#    '▁जो',
#    '▁royal',
#    '▁संरक्षण',
#    '▁पाए',
#    '▁हुए',
#    '▁थे',
#    '▁बुलाए',
#    '▁गए',
#    '।'],
#   ['▁मैक्स', 'ि', 'लिस', '▁तथा', '▁kol', 'um'],
#   ['▁संवर्धन',
#    '▁संस्तर',
#    '▁leaves',
#    '▁के',
#    '▁कटे',
#    '▁हुए',
#    '▁pieces',
#    '▁से',
#    '▁बनाए',
#    '▁जाते',
#    '▁हैं',
#    '।'],
#   ['▁forward',
#    '▁के',
#    '▁marketing',
#    '▁के',
#    '▁लिए',
#    '▁बहुत',
#    '▁सारी',
#    '▁commodities',
#    '▁को',
#    '▁लिया',
#    '▁जाएगा',
#    '।'],
#   ['▁खंडन',
#    '▁ही',
#    '▁only',
#    '▁हल',
#    '▁है',
#    '▁तुम्हारे',
#    '▁accusation',
#    's',
#    '▁का',
#    '।'],
#   ['▁of', '▁चाहता', '▁था'],
#   ['▁इनमें',
#    '▁से',
#    '▁हर',
#    '▁छ',
#    'ठ',
#    'वें',
#    '▁villages',
#    '▁में',
#    '▁पीने',
#    '▁के',
#    '▁clean',
#    '▁पानी',
#    '▁की',
#    '▁व्यवस्था',
#    '▁नहीं',
#    '▁है',
#    '।'],
#   ['▁water',
#    '▁लाने',
#    '▁की',
#    '▁कोशिश',
#    '▁करें',
#    '▁उनमें',
#    '▁से',
#    '▁one',
#    '▁बोली',
#    '।'],
#   ['▁rani', '▁छोटी', '▁थी', '▁home', '▁के', '▁लिये', '▁new', '▁थी', '।'],
#   ['▁भो', 'लू', '▁puzzle', 'd', '▁था', '।'],
#   ['▁कुंजी', '▁signature', '▁बदलें'],
#   ['▁त्वचा', '▁का', '▁e', 'rup', 'tion', '▁या', '▁फोड़', 'ा', '▁फूट', 'ना'],
#   ['▁तत्पर', '▁state'],
#   ['▁कार्यालय',
#    '▁के',
#    '▁खुदरा',
#    '▁खर्च',
#    '▁के',
#    '▁लिए',
#    '▁ख',
#    'जांच',
#    'ी',
#    '▁के',
#    '▁पास',
#    '▁000',
#    '▁रुपये',
#    '▁pet',
#    'ties',
#    '▁हैं',
#    '।'],
#   ['▁crust', 'ed', '▁या', '▁शल्क', '▁सहित'],
#   ['▁मेरा',
#    '▁believe',
#    '▁है',
#    '▁कि',
#    '▁हैदराबाद',
#    '▁के',
#    '▁किसी',
#    '▁nizam',
#    '▁ने',
#    '▁कभी',
#    '▁battle',
#    '▁नहीं',
#    '▁जीती',
#    '▁है',
#    '।'],
#   ['▁valve',
#    's',
#    '▁जो',
#    '▁बाएं',
#    '▁ventricle',
#    '▁और',
#    '▁ए',
#    'ट्री',
#    'अम',
#    '▁में',
#    '▁present',
#    '▁होता',
#    '▁हैं'],
#   ['▁north', '▁सीमांत', '▁रेलवे'],
#   ['▁here', 'by', '▁के', '▁बारे', '▁में', '▁purpose', '▁तथ्य'],
#   ['▁रो', '▁board', '▁game', '▁में', '▁केडीई', '▁पांच'],
#   ['▁पी', 'एफसी', '▁c', 's', 'ka', '▁moscow'],
#   ['▁area', '▁आरेख'],
#   ['▁वहां',
#    '▁भी',
#    '▁opposition',
#    '▁के',
#    '▁बजाय',
#    '▁co',
#    '▁से',
#    '▁अधिक',
#    '▁improvement',
#    '▁हो',
#    '▁सकेगा',
#    '।'],
#   ['▁१९',
#    '३२',
#    '▁में',
#    '▁उन्होंने',
#    '▁महिलाओं',
#    '▁की',
#    '▁namely',
#    '▁magazine',
#    '▁‘',
#    'च',
#    'ाँ',
#    'द',
#    '▁का',
#    '▁chand',
#    'h',
#    '▁संभाला',
#    '।'],
#   ['▁मैं', '▁do', '▁के', '▁deserve', '▁feel', '▁नहीं', '।'],
#   ['▁active', 'ly', '▁रूप', '▁से', '▁pump', '▁water'],
#   ['▁moses',
#    '▁ने',
#    '▁कहा',
#    '▁ऐ',
#    '▁साम',
#    'री',
#    '▁तेरा',
#    '▁क्या',
#    '▁case',
#    '▁है'],
#   ['▁फ्रांसिस',
#    'ी',
#    '▁उनकी',
#    '▁a',
#    'ru',
#    '▁भाषा',
#    '▁हो',
#    '▁गई',
#    '▁थी',
#    '▁और',
#    '▁french',
#    '▁उनका',
#    '▁मन',
#    'ची',
#    'ता',
#    '▁of',
#    '▁हो',
#    '▁उठा',
#    '▁था',
#    '।'],
#   ['▁files', '▁चुनें'],
#   ['▁ढाल',
#    '▁उत्तर',
#    '▁से',
#    '▁south',
#    '▁है',
#    '▁44',
#    '▁अतः',
#    '▁अधिकांश',
#    '▁rivers',
#    '▁उत्तर',
#    '▁से',
#    '▁दक्षिण',
#    '▁की',
#    '▁ओर',
#    '▁बहती',
#    '▁हैं',
#    '।'],
#   ['▁रद्द', '▁sent', '▁से', '▁s', '▁calendar', '▁में', '▁canceled'],
#   ['▁specified', '▁फ़ाइल', '▁debug', '▁आउटपुट', '▁भेजें'],
#   ['▁england',
#    '▁से',
#    '▁india',
#    '▁तक',
#    '▁का',
#    '▁स',
#    'फ़र',
#    '▁छः',
#    '▁months',
#    '▁का',
#    '▁हुआ',
#    '▁करता',
#    '▁था',
#    '।'],
#   ['▁फुल', '्', 'हम', '▁broad', 'way'],
#   ['▁और',
#    '▁वे',
#    '▁morning',
#    '▁तेज़ी',
#    '▁के',
#    '▁साथ',
#    '▁चले',
#    '▁मानो',
#    '▁poor',
#    '▁को',
#    '▁रोक',
#    '▁देने',
#    '▁की',
#    '▁उन्हें',
#    '▁able',
#    '▁प्राप्त',
#    '▁है'],
#   ['▁प्रकार', '▁comment', '▁press', '▁write', '▁करें', '▁कुंजी'],
#   ['▁में',
#    '▁publishing',
#    '▁continue',
#    '▁नहीं',
#    '▁रह',
#    '▁सका',
#    '▁क्योंकि',
#    '▁कोई',
#    '▁error',
#    '▁आयी',
#    'ः'],
#   ['▁यह',
#    '▁mathematical',
#    '▁logic',
#    '▁में',
#    '▁अपनायी',
#    '▁गयी',
#    '▁concept',
#    '▁है',
#    '।'],
#   ['▁उज्', 'बे', 'क', 'िस्तान', '▁of'],
#   ['▁first', '▁वैकल्पिक', '▁name', '▁भरें'],
#   ['▁फिर',
#    '▁उसके',
#    '▁heads',
#    '▁पर',
#    '▁खौलत',
#    'े',
#    '▁हुए',
#    '▁water',
#    '▁का',
#    '▁torment',
#    '▁उंडेल',
#    '▁दो'],
#   ['▁पूर्वी',
#    '▁axial',
#    'ly',
#    '▁के',
#    '▁सामने',
#    '▁अक्ष',
#    'ीय',
#    '▁रूप',
#    '▁से',
#    '▁a',
#    '▁मंडप',
#    '▁के',
#    '▁eastern',
#    '▁हैं'],
#   ['▁आप',
#    '▁मैसूर',
#    '▁कांग्रेस',
#    '▁से',
#    '▁भी',
#    '▁इस',
#    '▁question',
#    '▁का',
#    '▁answer',
#    '▁चाहते',
#    '▁हैं',
#    '।'],
#   ['▁और',
#    '▁यदि',
#    '▁इस',
#    '▁top',
#    '▁वाली',
#    '▁संख्या',
#    '▁में',
#    '▁से',
#    '▁hundred',
#    '▁घटा',
#    '▁देता',
#    '▁हूँ',
#    '▁तो'],
#   ['▁run', '▁वी', 'वर', '▁v'],
#   ['▁परिवर्तन',
#    '▁की',
#    '▁speed',
#    '▁और',
#    '▁scale',
#    '▁बहुत',
#    '▁bog',
#    'gl',
#    'ing',
#    '▁है',
#    '।'],
#   ['▁इसलिए', '▁de', 'ka', '▁ठीक', '▁यहाँ', '▁है'],
#   ['▁इस',
#    '▁प्रकार',
#    '▁of',
#    '▁पौधे',
#    '▁cattle',
#    '▁के',
#    '▁खाने',
#    '▁योग्य',
#    '▁भी',
#    '▁नहीं',
#    '▁रहते',
#    '।'],
#   ['▁भिन्नभिन्न',
#    '▁species',
#    '▁के',
#    '▁members',
#    '▁की',
#    '▁प्रजनन',
#    '▁अलग',
#    '▁re',
#    'pro',
#    'd',
#    'ut',
#    'ive',
#    'ly',
#    '▁से',
#    '▁करते',
#    '▁हैं',
#    '।'],
#   ['▁किंतु',
#    '▁उसने',
#    '▁उनकी',
#    '▁thought',
#    '▁को',
#    '▁पूरी',
#    '▁तरह',
#    '▁accept',
#    '▁नहीं',
#    '▁किया',
#    '।'],
#   ['▁वर्तमान',
#    '▁में',
#    '▁चुंबकीय',
#    '▁बुदबुद',
#    '▁स्मृति',
#    '▁का',
#    '▁used',
#    '▁अधिकांश',
#    '▁computers',
#    '▁में',
#    '▁नहीं',
#    '▁होता',
#    '▁है',
#    '।'],
#   ['▁बायाँ', '▁diagram', '▁select'],
#   ['▁धातु',
#    '▁मिश्रण',
#    '▁की',
#    '▁क्रिया',
#    '▁से',
#    '▁किसी',
#    '▁सिक्के',
#    '▁के',
#    '▁value',
#    '▁में',
#    '▁by',
#    '▁ला',
#    '▁देना',
#    '।'],
#   ['▁big', '▁white', '▁बे', 'ढ', 'ंगे', '▁अक्षर', '।'],
#   ['▁उसने',
#    '▁tap',
#    '▁के',
#    '▁water',
#    '▁के',
#    '▁लिये',
#    '▁हुए',
#    '▁विवाद',
#    '▁का',
#    '▁भी',
#    '▁उल्लेख',
#    '▁किया'],
#   ['▁jawaharlal', '▁लाल', '▁नेहरू', '▁वनस्पति', '▁garden'],
#   ['▁कोई',
#    '▁किसी',
#    '▁वस्तु',
#    '▁को',
#    '▁प्राप्त',
#    '▁करने',
#    '▁का',
#    '▁entitled',
#    '▁बनाना',
#    '▁a',
#    '▁natural',
#    '▁अधिकार',
#    '▁नहीं',
#    '▁है',
#    '।'],
#   ['▁war',
#    '▁जो',
#    '▁छिड़',
#    'ा',
#    '▁वह',
#    '▁युद्ध',
#    '▁नहीं',
#    '▁था',
#    '▁जिसका',
#    '▁roy',
#    '▁तथा',
#    '▁others',
#    '▁लोगों',
#    '▁ने',
#    '▁पूर्वानुमान',
#    '▁लगाया',
#    '▁था'],
#   ['▁gaja',
#    'kand',
#    'h',
#    'ka',
#    'tan',
#    'k',
#    '▁तम',
#    'ंत',
#    'कांत',
#    'क',
#    'ं',
#    '▁भ',
#    'जे',
#    '॥',
#    '▁10',
#    '॥'],
#   ['▁विनिमय', '▁folders', '▁से', '▁mi', 'gra', 'ting', '▁कर', '▁रहा', '▁है'],
#   ['▁procedures',
#    '▁के',
#    '▁इस',
#    '▁step',
#    '▁में',
#    '▁आप',
#    '▁को',
#    '▁४',
#    '▁a',
#    '▁से',
#    '▁लेकर',
#    '▁४',
#    '▁f',
#    '▁तक',
#    '▁की',
#    '▁सभी',
#    '▁वही',
#    '▁प्रक्रिया',
#    'ंए',
#    '▁करनी',
#    '▁should'],
#   ['▁और',
#    '▁फिर',
#    '▁अंतिम',
#    '▁भाग',
#    '▁rail',
#    '▁या',
#    'र्ड',
#    '▁के',
#    '▁around',
#    '▁ओर',
#    '▁चलने',
#    '▁वाला',
#    '▁था'],
#   ['▁आज्ञा', '▁writ'],
#   ['▁tourist',
#    '▁स्थान',
#    '▁के',
#    '▁as',
#    '▁में',
#    '▁pilgrimage',
#    '▁केंद्रों',
#    '▁का',
#    '▁विकास',
#    '▁करना'],
#   ['▁संस्थापन', '▁start', '▁हो', '▁रहा', '▁है', '।'],
#   ['▁indian', '▁independence', '▁संग्राम'],
#   ['▁यदि',
#    '▁हां',
#    '▁तो',
#    '▁two',
#    '▁witnesses',
#    '▁के',
#    '▁साथ',
#    '▁nominee',
#    '▁व्यक्तियों',
#    '▁का',
#    '▁details'],
#   ['▁सोचना',
#    '▁होगा',
#    '▁well',
#    '▁तरह',
#    '▁से',
#    '▁वास्तव',
#    '▁में',
#    '▁मुझे',
#    '▁know',
#    '▁है',
#    '▁क्यों',
#    '▁वे',
#    '▁d',
#    '▁use',
#    '▁नहीं',
#    '▁करेगा'],
#   ['▁कियोस्क', '▁एप्लिकेशन', '▁manage', '▁करें'],
#   ['▁लक्ष्मण', '▁की', '▁signature', '▁पारी', '▁बन', '▁गई', '▁है'],
#   ['▁एक',
#    '▁cooperative',
#    '▁बैंक',
#    '▁का',
#    '▁कार्यक्षेत्र',
#    '▁limited',
#    '▁होता',
#    '▁है',
#    '।'],
#   ['▁औसत', '▁परिलब्धि', 'यां', '▁last', '▁वर्ष', '▁से', '▁अधिक', '▁थी', '।'],
#   ['▁gr', 'eg', '▁l', 'um', 'el', 'sky', '▁york', '▁सिटी'],
#   ['▁या',
#    '▁वे',
#    '▁कोई',
#    '▁planning',
#    '▁चलना',
#    '▁चाहते',
#    '▁है',
#    '▁तो',
#    '▁जिन',
#    '▁लोगों',
#    '▁ने',
#    '▁disbelievers',
#    '▁किया',
#    '▁वही',
#    '▁planning',
#    '▁की',
#    '▁लपेट',
#    '▁में',
#    '▁will',
#    '▁है'],
#   ['▁इन्हीं',
#    '▁words',
#    '▁के',
#    '▁साथ',
#    '▁विशिष्ट',
#    '▁guests',
#    '▁देवियो',
#    '▁और',
#    '▁gentlemen',
#    '▁आइए',
#    '▁हम',
#    '▁सब',
#    '▁मिलकर',
#    'ः'],
#   ['▁कुछ',
#    '▁हालत',
#    '▁में',
#    '▁art',
#    'ic',
#    'ulation',
#    '▁की',
#    '▁a',
#    'pha',
#    's',
#    'ia'],
#   ['▁लेकिन',
#    '▁फिर',
#    '▁आप',
#    '▁smart',
#    '▁और',
#    '▁तेज़',
#    '▁kids',
#    '▁को',
#    '▁मिलते',
#    '▁है'],
#   ['▁वह',
#    '▁अपने',
#    '▁software',
#    '▁को',
#    '▁activate',
#    '▁करने',
#    '▁की',
#    '▁कोशिश',
#    '▁कर',
#    '▁रहा',
#    '▁था',
#    '।'],
#   ['▁वे',
#    '▁मस्तिष्क',
#    '▁gandhiji',
#    '▁और',
#    '▁हाथ',
#    'के',
#    '▁harmonious',
#    '▁विकास',
#    'के',
#    '▁मूर्ति',
#    'म',
#    'ंत',
#    '▁उदाहरण',
#    '▁थे',
#    '।'],
#   ['▁स्पैम', 'ए', 'से', 'सिन', '▁built'],
#   ['▁father',
#    '▁ने',
#    '▁one',
#    '▁',
#    'विवेकपूर्ण',
#    '▁precaution',
#    '▁पहले',
#    '▁ही',
#    '▁बरती',
#    '▁थी'],
#   ['▁gran',
#    'it',
#    'ic',
#    '▁g',
#    'ne',
#    'is',
#    's',
#    'es',
#    '▁की',
#    '▁बनी',
#    '▁इसकी',
#    '▁topograph',
#    'y',
#    '▁ऊब',
#    'ड़',
#    'खा',
#    'ब',
#    'ड़',
#    '▁है',
#    '।'],
#   ['▁व्यवहार', '▁to'],
#   ['▁several', '▁देयता'],
#   ['▁bal', 'p', 'ak', 'ram', '▁नेशनल', '▁park'],
#   ['▁सर्वाधिक',
#    '▁runs',
#    '▁का',
#    '▁record',
#    '▁भी',
#    '▁sac',
#    'in',
#    '▁के',
#    '▁नाम',
#    'बीबीसी',
#    '▁पर'],
#   ['▁pro', '▁tennis', '▁में', '▁time', '▁भत', '▁कीमती', '▁है'],
#   ['▁उसने',
#    '▁southern',
#    '▁के',
#    '▁अपने',
#    '▁enemies',
#    '▁के',
#    '▁against',
#    '▁पुनः',
#    '▁struggle',
#    '▁प्रारंभ',
#    '▁किया',
#    '।'],
#   ['▁और',
#    '▁veri',
#    'ly',
#    '▁ही',
#    '▁हमारी',
#    '▁host',
#    '▁ही',
#    '▁प्रभावी',
#    '▁रहेगी'],
#   ['▁किंतु',
#    '▁supreme',
#    '▁court',
#    '▁ने',
#    '▁अब',
#    '▁तक',
#    '▁ऐसा',
#    '▁कोई',
#    '▁distinction',
#    '▁नहीं',
#    '▁देखा',
#    '▁है',
#    '।'],
#   ['▁jail',
#    '▁में',
#    '▁life',
#    '▁के',
#    '▁कैसे',
#    '▁बहु',
#    'रुप',
#    'ी',
#    '▁परिदृश्य',
#    '▁का',
#    '▁represent',
#    's',
#    '▁होता',
#    '▁है',
#    '।'],
#   ['▁binoy', '▁बोला', '▁तो', '▁फिर', '▁सच्ची', '▁speak', '▁कह', 'ूँ', '▁भाई'],
#   ['▁कस', 'ू', 'ती', '▁embroider', 'y', '▁nav', 'ge'],
#   ['▁आज', '▁work', '▁नहीं', '▁about', '▁करें', '▁तो', '▁कैसा', '▁रहेगा'],
#   ['▁एक',
#    '▁entrance',
#    '▁द्वार',
#    '▁जिसके',
#    '▁arch',
#    '▁पर',
#    '▁आवरण',
#    '▁है',
#    '।'],
#   ['▁क्या',
#    '▁तुम',
#    '▁प्रत्येक',
#    '▁उच्च',
#    '▁स्थान',
#    '▁पर',
#    '▁use',
#    'less',
#    '▁एक',
#    '▁स्मारक',
#    '▁का',
#    '▁build',
#    '▁करते',
#    '▁रहोगे'],
#   ['▁काफी',
#    '▁सारी',
#    '▁important',
#    '▁बातें',
#    '▁',
#    'amba',
#    '▁vilas',
#    '▁में',
#    '▁घटी',
#    '▁होंगी',
#    '।'],
#   ['▁फीड', 'र', '▁2'],
#   ['▁हमारे',
#    '▁country',
#    '▁में',
#    '▁तो',
#    '▁इसकी',
#    '▁possibilities',
#    '▁और',
#    '▁भी',
#    '▁अधिक',
#    '▁हैं',
#    '।'],
#   ['▁उनकी',
#    '▁soul',
#    '▁में',
#    '▁पिछले',
#    '▁birth',
#    '▁के',
#    '▁कर्मों',
#    '▁के',
#    '▁कारण',
#    '▁नहीं',
#    '▁लिया',
#    '▁था',
#    '।'],
#   ['▁उच्च', '▁न्यायालय', '▁में', '▁appeal'],
#   ['▁को', 'र', '▁data', '▁import', '▁services'],
#   ['▁यह',
#    '▁सब',
#    '▁इस',
#    '▁dam',
#    'ned',
#    '▁लिफ्ट',
#    '▁की',
#    '▁वजह',
#    '▁से',
#    '▁हुआ',
#    '▁joy',
#    'ce',
#    '▁ने',
#    '▁कहा',
#    '।'],
#   ['▁हॅ',
#    'वर',
#    '▁क्लिक',
#    '▁dwell',
#    '▁क्लिक',
#    '▁विशिष्टता',
#    '▁आपको',
#    '▁mouse',
#    '▁को',
#    '▁स्थिर',
#    '▁पकड़',
#    'कर',
#    '▁क्लिक',
#    '▁करने',
#    '▁देती',
#    '▁है',
#    '।'],
#   ['▁mor', 'bus', '▁नील', '▁रोग'],
#   ['▁trekk',
#    'ing',
#    '▁external',
#    '▁वेबसाइट',
#    '▁जो',
#    '▁a',
#    '▁नई',
#    '▁विंडों',
#    '▁में',
#    '▁खुलती',
#    '▁हैं'],
#   ['▁इसलिए',
#    '▁मेरे',
#    '▁पास',
#    '▁pi',
#    'zz',
#    'a',
#    '▁का',
#    '▁two',
#    '▁भिन्न',
#    '▁है',
#    '▁और',
#    '▁मैं',
#    '▁विभाजित',
#    '▁करने',
#    '▁जा',
#    '▁रहा',
#    '▁m'],
#   ['▁इस',
#    '▁दिन',
#    '▁tulsi',
#    '▁या',
#    '▁houses',
#    '▁के',
#    '▁doors',
#    '▁पर',
#    '▁एक',
#    '▁light',
#    'ed',
#    '▁जल',
#    'ाया',
#    '▁जाता',
#    '▁है',
#    '।'],
#   ['▁मुझे', '▁today', '▁registered', '▁office', '▁जाना', '▁है', '।'],
#   ['▁अथवा',
#    '▁कि',
#    '▁इसे',
#    '▁two',
#    '▁सभाओं',
#    '▁की',
#    '▁joint',
#    '▁समिति',
#    '▁को',
#    '▁सौंपा',
#    '▁जाए'],
#   ['▁निश्चय',
#    '▁ही',
#    '▁यह',
#    '▁क़ुरआन',
#    '▁सारे',
#    '▁संसार',
#    '▁के',
#    '▁lord',
#    '▁की',
#    '▁अवतरित',
#    '▁की',
#    '▁हुई',
#    '▁of',
#    '▁है'],
#   ['▁पीटर', '▁और', '▁मैं', '▁अक्सर', '▁movies', '▁जाते', '▁थे'],
#   ['▁न्यायाधीश',
#    '▁learned',
#    '▁men',
#    '▁होते',
#    '▁थे',
#    '▁और',
#    '▁each',
#    '▁का',
#    '▁अपना',
#    '▁विशिष्ट',
#    '▁व्यक्तित्व',
#    '▁होता',
#    '▁था',
#    '।'],
#   ['▁इसका',
#    '▁means',
#    '▁है',
#    '▁कि',
#    '▁अनेक',
#    '▁rivers',
#    '▁का',
#    '▁पानी',
#    '▁dam',
#    's',
#    '▁द्वारा',
#    '▁एकत्र',
#    '▁करना',
#    '।'],
#   ['▁संचार', '▁और', '▁सूचना', '▁technology', '▁मंत्रालय'],
#   ['▁auditor', 'ial', '▁कार्य'],
#   ['▁automatically',
#    '▁रूप',
#    '▁से',
#    '▁updating',
#    '▁करने',
#    '▁वाला',
#    '▁प्ले',
#    'ल',
#    'िस्ट',
#    '▁बनाओ',
#    '▁जहाँ',
#    'ः'],
#   ['▁दो',
#    '▁blade',
#    's',
#    '▁खड़े',
#    '▁में',
#    '▁घड़ी',
#    '▁की',
#    '▁clock',
#    'wise',
#    '▁में'],
#   ['▁उत्तरदायित्व',
#    '▁आपका',
#    '▁है',
#    '▁guilty',
#    '▁या',
#    '▁return',
#    '▁होने',
#    '▁का',
#    '▁निर्णय',
#    '▁आपको',
#    '▁देना',
#    '▁है'],
#   ['▁there',
#    '▁में',
#    '▁ya',
#    'j',
#    'ur',
#    'ved',
#    'a',
#    '▁की',
#    '▁',
#    '८६',
#    '▁branches',
#    '▁में',
#    '▁से',
#    '▁केवल',
#    '▁४',
#    '▁branches',
#    '▁के',
#    '▁ग्रन्थ',
#    '▁ही',
#    '▁प्राप्त',
#    '▁है'],
#   ['▁बच्चों',
#    '▁का',
#    '▁fine',
#    '▁देकर',
#    '▁उन्हें',
#    '▁फिर',
#    '▁community',
#    '▁में',
#    '▁शामिल',
#    '▁कर',
#    '▁लिया',
#    '▁गया',
#    '▁था',
#    '।'],
#   ['▁दे', 'स', '▁transportation'],
#   ['▁binary', '▁कूट', '▁द्विआधारी', '▁कोड'],
#   ['▁कभीकभी',
#    '▁rocks',
#    '▁के',
#    '▁टूटने',
#    '▁से',
#    '▁उनमें',
#    '▁',
#    'pore',
#    '▁हो',
#    '▁जाते',
#    '▁हैं',
#    '।'],
#   ['▁upright',
#    's',
#    '▁के',
#    '▁बीच',
#    '▁मुख्य',
#    '▁led',
#    'ge',
#    '▁लकड़ी',
#    '▁को',
#    '▁upright',
#    's',
#    '▁में',
#    '▁और',
#    '▁holes',
#    '▁करके',
#    '▁नीचे',
#    '▁स्थिर',
#    '▁किया',
#    '▁जा',
#    '▁सकता',
#    '▁है',
#    '।'],
#   ['▁टीवी', '▁spot', 'light', '▁के', '▁अंतर्गत', '▁बच्चों', '▁की', '▁सुरक्षा'],
#   ['▁परियोजना', '▁की', '▁beneficial', '▁दर', '▁काफी', '▁ऊँची', '▁है', '।'],
#   ['▁ने',
#    'ताजी',
#    '▁ने',
#    '▁इन',
#    '▁द्वीपों',
#    '▁का',
#    '▁martyr',
#    '▁और',
#    '▁स्वराज',
#    '▁द्वीप',
#    '▁ऐसा',
#    '▁names',
#    '▁किया',
#    '।'],
#   ['▁उसने',
#    '▁अपने',
#    '▁son',
#    '▁के',
#    '▁लिए',
#    '▁बड़ी',
#    '▁fortune',
#    '▁छोड़ी',
#    '।'],
#   ['▁मैं',
#    '▁तो',
#    '▁इसके',
#    '▁over',
#    '▁होने',
#    '▁तक',
#    '▁अपने',
#    '▁बिस्तर',
#    '▁में',
#    '▁ही',
#    '▁रह',
#    'ूंगा',
#    '▁rakesh',
#    '▁बोला',
#    '।'],
#   ['▁हि',
#    'रो',
#    'श',
#    'िमा',
#    '▁में',
#    '▁मारे',
#    '▁गए',
#    '▁people',
#    '▁की',
#    '▁कुल',
#    '▁number',
#    '▁लगभग',
#    '▁1',
#    '▁करा',
#    'ड़',
#    '▁थी',
#    '।'],
#   ['▁उन्हें',
#    '▁मानवजाति',
#    '▁के',
#    '▁लिए',
#    '▁education',
#    '▁की',
#    '▁advisory',
#    '▁समिति',
#    '▁का',
#    '▁member',
#    '▁चुना',
#    '▁गया',
#    '।'],
#   ['▁shadow', '▁गुण'],
#   ['▁unfavourable', '▁trade', '▁शेष'],
#   ['▁लोकतंत्र',
#    '▁में',
#    '▁sovereignty',
#    '▁जनता',
#    '▁में',
#    '▁vest',
#    's',
#    '▁होती',
#    '▁है'],
#   ['▁नयी', '▁technology', '▁की', '▁अन्य', '▁tremendous', '▁value'],
#   ['▁और',
#    '▁अपने',
#    '▁lord',
#    '▁की',
#    '▁favour',
#    '▁का',
#    '▁discourse',
#    '▁करते',
#    '▁रहना'],
#   ['▁अवैध', '▁ip', '▁address'],
#   ['▁immovable', '▁property', '▁के', '▁transfer', '▁पर', '▁निर्', 'बन्ध', 'न'],
#   ['▁अपनी',
#    '▁माता',
#    '▁की',
#    '▁मृत्यु',
#    '▁पर',
#    '▁el',
#    'eg',
#    'y',
#    '▁ने',
#    '▁an',
#    '▁विलाप',
#    'िका',
#    '▁भी',
#    '▁लिखी',
#    '▁है',
#    '।'],
#   ['▁window', '▁प्रबंधक', 'ः'],
#   ['▁surat', '▁जिला'],
#   ['▁disease', '▁की', '▁जबरदस्त', '▁या', '▁अति', '▁उग्र', '▁condition'],
#   ['▁chin', 'tu', '▁जी'],
#   ['▁भारत',
#    '▁में',
#    '▁30',
#    '0000',
#    '▁मस्जिद',
#    'ें',
#    '▁हैं',
#    '▁जो',
#    '▁किसी',
#    '▁and',
#    '▁देश',
#    '▁से',
#    '▁अधिक',
#    '▁हैं',
#    '▁यहां',
#    '▁तक',
#    '▁कि',
#    '▁islam',
#    '▁world',
#    '▁से',
#    '▁भी',
#    '▁अधिक',
#    '।'],
#   ['▁हज़रत',
#    '▁ali',
#    '▁रज़ि',
#    '▁से',
#    '▁रि',
#    'वाय',
#    'त',
#    '▁की',
#    '▁गई',
#    '▁एक',
#    '▁honour',
#    '▁है',
#    '।'],
#   ['▁capacity', '▁building', '▁सहयोग'],
#   ['▁गांव',
#    '▁को',
#    '▁लौट',
#    'ता',
#    '▁हुआ',
#    '▁gods',
#    '▁का',
#    '▁रथ',
#    '▁thorn',
#    'y',
#    '▁झाड़िय',
#    'ों',
#    '▁से',
#    '▁झाड़',
#    'ा',
#    '▁जाता',
#    '▁है'],
#   ['▁किसी',
#    '▁विशिष्ट',
#    '▁environment',
#    '▁या',
#    '▁scenario',
#    '▁में',
#    '▁ढल',
#    '▁जाना',
#    '।'],
#   ['▁उसने',
#    '▁अपने',
#    '▁को',
#    '▁lucky',
#    '▁समझा',
#    '।',
#    '▁s',
#    '▁अचानक',
#    '▁उसे',
#    '▁एक',
#    '▁thought',
#    '▁आया',
#    '▁और',
#    '▁वह',
#    '▁चिन्ता',
#    'मग्न',
#    '▁होकर',
#    '▁forehead',
#    '▁पर',
#    '▁हाथ',
#    '▁फेर',
#    'ने',
#    '▁लगा',
#    '।'],
#   ['▁इसमें', '▁छह', '▁से', '▁5', '▁possibilities', '▁हैं'],
#   ['▁online', '▁कर', '▁calculator'],
#   ['▁nowadays', '▁तो', '▁मछलियों', '▁की', '▁भी', '▁farms', '▁होती', '▁है'],
#   ['▁state',
#    '▁सरकारों',
#    '▁के',
#    '▁स्वामित्व',
#    'वाली',
#    '▁संस्थाओं',
#    '▁को',
#    '▁direct',
#    '▁ऋण'],
#   ['▁eight', '▁4', '▁बार', '▁32', '▁है'],
#   ['▁force',
#    '▁कर',
#    '▁रहे',
#    '▁application',
#    '▁को',
#    '▁जबर्दस्त',
#    'ी',
#    '▁बाहर',
#    '▁करें'],
#   ['▁दुनिया',
#    '▁में',
#    '▁enjoyment',
#    '▁तो',
#    '▁they',
#    '▁सा',
#    '▁है',
#    '▁और',
#    '▁आख़िर',
#    'त',
#    '▁में',
#    '▁painful',
#    '▁अज़ाब',
#    '▁है'],
#   ['▁लगभग', '▁full', '▁गोदाम', '▁बेकार'],
#   ['▁work',
#    '▁को',
#    '▁मानव',
#    '▁के',
#    '▁नैतिक',
#    '▁संस्थान',
#    '▁का',
#    '▁foundation',
#    '▁मानना'],
#   ['▁yahoo', '▁होम', '▁screen', '▁नाम', '▁1'],
#   ['▁india',
#    '▁के',
#    '▁पास',
#    '▁शस्त्र',
#    '▁तो',
#    '▁हैं',
#    '▁vision',
#    '▁का',
#    '▁no',
#    '▁है'],
#   ['▁feed', '▁चक्र'],
#   ['▁app', 'lic', 'ative', '▁order', '▁मूल्यांकन'],
#   ['▁ज', 'स', '्स', 'िड', '▁white', 'f', 'ly'],
#   ['▁अपने',
#    '▁the',
#    '▁के',
#    '▁अंतिम',
#    '▁संस्कार',
#    '▁में',
#    '▁उस',
#    '▁man',
#    '▁के',
#    '▁अति',
#    '▁दुख',
#    'पूर्ण',
#    '▁s',
#    '▁को',
#    '▁सुनकर',
#    '▁अंततः',
#    '▁सब',
#    '▁को',
#    '▁हंसी',
#    '▁आने',
#    '▁लगी',
#    '।'],
#   ['▁यह',
#    '▁संभव',
#    '▁है',
#    '▁कि',
#    '▁plaintiff',
#    '▁ऐसी',
#    '▁proceedings',
#    '▁में',
#    '▁सफल',
#    '▁हो',
#    '▁जाए'],
#   ['▁the', '▁रिटर्न', '▁ऑफ़', '▁द', '▁ring'],
#   ['▁आमतौर',
#    '▁पर',
#    '▁distribution',
#    '▁चैनलों',
#    '▁के',
#    '▁four',
#    '▁प्रकार',
#    '▁हैंः'],
#   ['▁प्रतिफल', '▁accounting', '▁दर'],
#   ['▁printer', '▁स्पीड'],
#   ['▁श्रेणीः', 'शास्त्रीय', '▁music'],
#   ['▁u', 'fs', '▁फार्मेट', '▁प्रोग्राम', '▁start', '▁करने', '▁में', '▁अक्षम'],
#   ['▁कि', '▁उसकी', '▁killed', '▁किस', '▁sin', '▁के', '▁कारण', '▁की', '▁गई'],
#   ['▁फसल', '▁सुधार', '▁programme'],
#   ['▁मैं', '▁कहना', '▁चाहता', '▁हूँ', '▁की', '▁two', '▁जमा', '▁four'],
#   ['▁नीले', '▁प्रकाश', '▁की', '▁a', '▁चमक'],
#   ['▁क्रेडिट', '▁linked', '▁subsidy', '▁स्कीम'],
#   ['▁company', '▁का', '▁manifesto', '▁ज़ोर', '▁से', '▁पढ़ा', '▁गया', '।'],
#   ['▁labour', '▁संघ', '▁ने', '▁matter', '▁को', '▁देख', '▁रहे', '▁हैं', '।'],
#   ['▁वह',
#    '▁life',
#    '▁की',
#    '▁सिद्धि',
#    '▁में',
#    '▁love',
#    '▁की',
#    '▁भूमिका',
#    '▁को',
#    '▁admit',
#    's',
#    '▁करते',
#    '▁हैं',
#    '।'],
#   ['▁sacrifici', 'ng', '▁का', '▁त्याग'],
#   ['▁उलट', '▁पलट', '▁noise', '▁या', '▁sound', '▁का', '▁a', '▁मिश्रण', '।'],
#   ['▁बंद',
#    '▁caption',
#    's',
#    '▁को',
#    '▁display',
#    'ing',
#    '▁करना',
#    '▁समाप्त',
#    '▁करें'],
#   ['▁खण्डों', '▁या', '▁भागों', '▁के', '▁मध्य', '▁situated', '▁झिल्ली'],
#   ['▁open', '▁ऋण', '▁बंधक'],
#   ['▁ओ', 'पो', 'सम', '▁an', '▁अपरा', 'विहीन', '▁mam', 'mal', '▁है'],
#   ['▁ऊर्जा', '▁work', '▁करने', '▁की', '▁क्षमता', '▁है'],
#   ['▁कि',
#    '▁मुझे',
#    '▁इस',
#    '▁मंच',
#    '▁पर',
#    '▁दोबारा',
#    '▁आने',
#    '▁का',
#    '▁opportunity',
#    '▁मिला',
#    '▁मैं',
#    '▁बहुत',
#    '▁grateful',
#    '▁हूँ'],
#   ['▁पासवर्ड', '▁रखें', '▁ओ', 'ई', '▁safe'],
#   ['▁belga', 'um', '▁जिला'],
#   ['▁बहुपक्षीय', '▁economic', '▁relations'],
#   ['▁ग्रामीण',
#    '▁centres',
#    '▁खोलने',
#    '▁की',
#    '▁प्रत्येक',
#    '▁bank',
#    '▁की',
#    '▁अपनी',
#    '▁स्वयं',
#    '▁की',
#    '▁policy',
#    '▁है',
#    '।'],
#   ['▁nominal', '▁ब्याज', '▁rate'],
#   ['▁इ',
#    '▁mail',
#    '▁ः',
#    '▁ब',
#    '्ट्',
#    '5',
#    '▁तो',
#    'र्क',
#    '्प',
#    'े',
#    'र्म',
#    'िट',
#    '्स',
#    '्ड',
#    '्',
#    'ङ',
#    'े',
#    'स्',
#    '▁work',
#    'per',
#    'mi',
#    'ts',
#    'd',
#    'fe',
#    's',
#    '▁गो',
#    'व्',
#    '▁उ',
#    'क्'],
#   ['▁कोई',
#    '▁जो',
#    '▁किसी',
#    '▁post',
#    '▁के',
#    '▁लिए',
#    '▁comp',
#    'et',
#    'ing',
#    '▁हो',
#    '▁या',
#    '▁किसी',
#    '▁post',
#    '▁के',
#    '▁लिए',
#    '▁चुनाव',
#    '▁लड',
#    '▁रहा',
#    '▁हो',
#    '।'],
#   ['▁जो',
#    '▁आपके',
#    '▁lord',
#    '▁के',
#    '▁यहाँ',
#    '▁सीमा',
#    '▁का',
#    '▁अतिक्रमण',
#    '▁transgressors',
#    '▁के',
#    '▁लिए',
#    '▁चिन्हित',
#    '▁है',
#    '।'],
#   ['▁282',
#    '▁संघ',
#    '▁या',
#    '▁state',
#    '▁द्वारा',
#    '▁अपने',
#    '▁revenues',
#    '▁के',
#    '▁लिए',
#    '▁जाने',
#    '▁वाले',
#    '▁व्य',
#    '▁य'],
#   ['▁उनका',
#    '▁re',
#    'nunciation',
#    '▁कर्म',
#    '▁का',
#    '▁नहीं',
#    '▁था',
#    '▁बल्कि',
#    '▁कर्म',
#    '▁के',
#    '▁fruits',
#    '▁का',
#    '▁त्याग',
#    '▁था',
#    '।'],
#   ['▁कल्याण', '▁के', '▁measures', '▁योजना'],
#   ['▁मिली',
#    'से',
#    'क',
#    'ण्ड',
#    '▁one',
#    '▁window',
#    '▁frame',
#    '▁ड्र',
#    'ॉ',
#    '▁करने',
#    '▁में'],
#   ['▁there',
#    '▁के',
#    '▁बाद',
#    '▁there',
#    '▁अपील',
#    'ों',
#    '▁के',
#    '▁अनेक',
#    '▁स्तर',
#    '▁हैं',
#    '।'],
#   ['▁स्थानिक',
#    '▁industrial',
#    'isation',
#    '▁पर',
#    '▁decision',
#    '▁सरकार',
#    '▁द्वारा',
#    '▁लिया',
#    '▁जाना',
#    '▁है',
#    '।'],
#   ['▁अध्याय', '▁विशेष', '▁directive', 's'],
#   ['▁जिन',
#    '▁children',
#    '▁के',
#    '▁माँबाप',
#    '▁नहीं',
#    '▁होते',
#    ';',
#    '▁अनाथ',
#    'ालय',
#    '▁उनका',
#    '▁home',
#    '▁होता',
#    '▁है',
#    '▁mother',
#    '▁ने',
#    '▁उदास',
#    '▁स्वर',
#    '▁में',
#    '▁जवाब',
#    '▁दिया',
#    '।'],
#   ['▁विभिन्न',
#    '▁मापदंड',
#    '▁पर',
#    '▁transaction',
#    '▁रिपोर्ट',
#    '▁का',
#    '▁respective'],
#   ['▁tell',
#    'us',
#    '▁के',
#    '▁लिए',
#    '▁tell',
#    'uri',
#    's',
#    '▁में',
#    '▁टेल',
#    'स',
#    '▁या',
#    '▁टेल',
#    'रिस'],
#   ['▁buffalo', '▁दक्षिण', '▁डकोटा'],
#   ['▁खरीदने',
#    '▁में',
#    '▁समर्थ',
#    '▁आयु',
#    'श',
#    '▁quality',
#    '▁और',
#    '▁clinic',
#    'ians',
#    '▁सुनिश्चित',
#    '▁करना',
#    '▁जो',
#    '▁सुरक्षित',
#    '▁और',
#    '▁पर्याप्त',
#    '▁हैं'],
#   ['▁फुल', '▁स्क्रीन', '▁mode', '▁में', '▁लॉक'],
#   ['▁आई',
#    'पीवी',
#    '6',
#    '▁consultancy',
#    '▁सर्विसेज',
#    '▁के',
#    '▁लिए',
#    '▁request',
#    '▁के',
#    '▁लिए',
#    '▁proposal'],
#   ['▁हर', '▁time', '▁a', '▁नया', '▁consumer'],
#   ['▁online', '▁विधि', '▁में', '▁start', '▁करें'],
#   ['▁नै',
#    'रो',
#    'बी',
#    '▁central',
#    '▁से',
#    '▁करीब',
#    '▁an',
#    '▁hour',
#    '▁की',
#    '▁दूरी',
#    '▁पर',
#    '।'],
#   ['▁simple', '▁सादा'],
#   ['▁रंग', '▁installed', '▁नहीं', '▁किया', '▁जा', '▁सका'],
#   ['▁उद्यमिता', '▁development', '▁कार्यक्रम', '▁ई', 'डीपी'],
#   ['▁lymph', 'ocyte', 's', '▁का', '▁formation', '▁और', '▁विकास'],
#   ['▁दो',
#    '▁administrative',
#    '▁officers',
#    '▁पुणे',
#    '▁और',
#    '▁delhi',
#    '▁में',
#    '▁रखे',
#    '▁गये',
#    '।'],
#   ['▁यदि',
#    '▁आप',
#    '▁चिपका',
#    'एँ',
#    '▁कमांड',
#    '▁चुनें',
#    'गे',
#    '▁तो',
#    '▁d',
#    '▁चयनित',
#    '▁item',
#    '▁खिसका',
#    '▁दी',
#    '▁जाएगी'],
#   ['▁अन्त', '्य', '▁line', 'a', '▁श्रोणि', 'चाप', '▁रेखा'],
#   ['▁localization', '▁की', '▁स्थिति', 'ः', '▁indian', '▁perspective'],
#   ['▁s', 'cenic', '▁स्थल'],
#   ['▁c',
#    'eli',
#    'ba',
#    'cy',
#    '▁का',
#    '▁path',
#    '▁जितन',
#    'ा',
#    '▁magnificent',
#    '▁है',
#    '▁उतना',
#    '▁ही',
#    '▁difficult',
#    '▁भी',
#    '▁है',
#    '।'],
#   ['▁gold', '▁को', 'स्ट', '▁queen', 's', 'land'],
#   ['▁function', '▁करना'],
#   ['▁आइए',
#    '▁हम',
#    '▁मिलकर',
#    '▁india',
#    '▁को',
#    '▁सफलता',
#    '▁का',
#    '▁पर्याय',
#    '▁बना',
#    '▁दें',
#    '▁ऐसी',
#    '▁achievement',
#    '▁जिसकी',
#    '▁पूरा',
#    '▁विश्व',
#    '▁be',
#    '▁करे',
#    '।'],
#   ['▁memories',
#    '▁में',
#    '▁आबाद',
#    '▁love',
#    '▁मूर्ति',
#    'याँ',
#    '▁आत्म',
#    'बल',
#    '▁प्रदान',
#    '▁करती',
#    '▁है',
#    '।'],
#   ['▁service', '▁कर', '▁returns', '▁की', '▁filing', '▁की', '▁facility'],
#   ['▁हिन्दी', '▁editor', '▁तथा', '▁वर्तनी', '▁check', 'er'],
#   ['▁यह',
#    '▁एक',
#    '▁डिजाइन',
#    '▁से',
#    '▁non',
#    '▁रूप',
#    '▁से',
#    '▁seamless',
#    'ly',
#    '▁पुनः',
#    'प्रो',
#    'ग्राम',
#    'योग्य',
#    'हीन',
#    '▁उपकरण',
#    '▁है',
#    '।'],
#   ['▁revolutionaries', '▁ने', '▁अच्छी', '▁तरह', '▁fought', '▁किया', '।'],
#   ['▁partial',
#    '▁अथवा',
#    '▁complete',
#    '▁तरह',
#    '▁से',
#    '▁hair',
#    '▁के',
#    '▁गिरने',
#    '▁की',
#    '▁condition'],
#   ['▁they', '▁मान', 'च', 'ै', 'स्टर', '▁ड्रग', 'स', '▁टीम'],
#   ['▁वह',
#    '▁पूंजी',
#    '▁जिसे',
#    '▁business',
#    '▁में',
#    '▁continuous',
#    '▁use',
#    '▁के',
#    '▁लिए',
#    '▁रखा',
#    '▁गया',
#    '▁है',
#    '।'],
#   ['▁a',
#    'the',
#    'ro',
#    'sclerosis',
#    '▁हा',
#    'र्ट',
#    '▁अ',
#    'ट',
#    'ॅ',
#    'क',
#    '▁का',
#    '▁is',
#    '▁सबसे',
#    '▁common',
#    'est',
#    '▁cause',
#    '▁है',
#    '।'],
#   ['▁अभि',
#    'मन',
#    '्यु',
#    '▁और',
#    '▁',
#    'lakshmana',
#    '▁दोनों',
#    '▁young',
#    '▁जु',
#    'झ',
#    '▁उठे',
#    '।'],
#   ['▁4', '▁inch', '▁roll', '▁कागज'],
#   ['▁उनकी',
#    '▁death',
#    '▁के',
#    '▁बाद',
#    '▁property',
#    '▁के',
#    '▁बारे',
#    '▁में',
#    '▁brothers',
#    '▁से',
#    '▁मुकदमेबाजी',
#    '▁होने',
#    '▁लगी',
#    '।'],
#   ['▁इस',
#    '▁अधिवेशन',
#    '▁में',
#    '▁उन्होंने',
#    '▁अंग्रेज़',
#    '▁government',
#    '▁से',
#    '▁dominion',
#    '▁स्टेट',
#    'स',
#    '▁माँगने',
#    '▁की',
#    '▁determined',
#    '▁ली',
#    '▁थी',
#    '।'],
#   ['▁अति',
#    '▁सूक्ष्म',
#    '▁निस्',
#    'यं',
#    'दन',
#    '▁को',
#    'ल',
#    'ाइड',
#    '▁mixture',
#    '▁में',
#    '▁different',
#    '▁प्रकार',
#    '▁के',
#    '▁particles',
#    '▁को',
#    '▁अलग',
#    '▁करता',
#    '▁है',
#    '।'],
#   ['▁मुझे',
#    '▁बस',
#    '▁हटा',
#    '▁दें',
#    '▁कि',
#    '▁yellow',
#    '▁color',
#    '▁से',
#    '▁अन्य',
#    '▁color',
#    '▁के',
#    '▁साथ',
#    '।'],
#   ['▁यह',
#    '▁fort',
#    '▁तेरह',
#    'वीं',
#    '▁शताब्दी',
#    '▁में',
#    '▁kakatiya',
#    '▁राजवंश',
#    '▁द्वारा',
#    '▁built',
#    '▁किया',
#    '▁गया',
#    '▁था',
#    '।'],
#   ['▁long', '▁स्थिति', '▁contact', '▁करें'],
#   ['▁krishna',
#    'day',
#    'al',
#    '▁ने',
#    '▁gora',
#    '▁के',
#    '▁कमरे',
#    '▁में',
#    '▁कब',
#    '▁से',
#    '▁पद',
#    'ा',
#    'र्पण',
#    '▁नहीं',
#    '▁किया',
#    '▁था',
#    '▁यह',
#    '▁कहना',
#    '▁difficult',
#    '▁था',
#    '।'],
#   ['▁padma',
#    '▁विभूषण',
#    '▁padma',
#    '▁भूषण',
#    '▁और',
#    '्',
#    '▁padma',
#    '▁श्री',
#    '▁सम्मान',
#    'प्राप्त',
#    '▁सूची'],
#   ['▁hindu',
#    '▁community',
#    '▁में',
#    '▁प्रवेश',
#    '▁पाने',
#    '▁का',
#    '▁कोई',
#    '▁way',
#    '▁नहीं',
#    '▁है',
#    '।'],
#   ['▁हम',
#    '▁general',
#    '▁accompanied',
#    '▁के',
#    '▁साथ',
#    '▁गए',
#    '▁और',
#    '▁अपने',
#    '▁well',
#    'es',
#    'ley',
#    '▁से',
#    '▁हमने',
#    '▁उसकी',
#    '▁सहायता',
#    '▁की',
#    '।'],
#   ['▁ऐसा',
#    '▁उत्पादक',
#    '▁जो',
#    '▁निम्नतम',
#    '▁lower',
#    '▁के',
#    '▁आसपास',
#    '▁का',
#    '▁manufacturing',
#    '▁कर',
#    '▁रहा',
#    '▁हो',
#    '।'],
#   ['▁आपातकाल', '▁में', '▁grasshopper', '▁उड़', '▁भी', '▁सकता', '▁है', '।'],
#   ['▁old',
#    '▁होने',
#    '▁और',
#    '▁बहुत',
#    '▁अधिक',
#    '▁used',
#    '▁किए',
#    '▁जाने',
#    '▁के',
#    '▁because',
#    '▁जो',
#    '▁सिक्का',
#    '▁बहुत',
#    '▁घिस',
#    '▁गया',
#    '▁हो',
#    '।'],
#   ['▁मैं',
#    '▁समझती',
#    '▁हूं',
#    '▁कि',
#    '▁आपको',
#    '▁इन',
#    '▁questions',
#    '▁पर',
#    '▁discuss',
#    '▁करना',
#    '▁चाहिए',
#    '▁और',
#    '▁हमें',
#    '▁advise',
#    '▁देना',
#    '▁चाहिए',
#    '▁कि',
#    '▁हम',
#    '▁इनके',
#    '▁क्या',
#    '▁जवाब',
#    '▁it'],
#   ['▁ur',
#    'vas',
#    'hi',
#    '▁तुरंत',
#    '▁telegraph',
#    'ical',
#    'ly',
#    '▁द्वारा',
#    '▁madan',
#    '▁के',
#    '▁लिए',
#    '▁बुला',
#    'ती',
#    '▁हैं',
#    '।'],
#   ['▁जार्ज', '▁ja', 'sp', 'ert'],
#   ['▁वे', '▁बंगाली', '▁community', '▁के', '▁कवि', '▁हैं', '।'],
#   ['▁official', '▁काम'],
#   ['▁सभी', '▁jobs', '▁सूची', '▁में', '▁दिखाएँ'],
#   ['▁tangent', '▁की', '▁line', '▁के', '।'],
#   ['▁में', '▁i', '▁को', '▁not', '▁घर', '▁पे', '▁नहीं', '▁होता'],
#   ['▁टेली', 'प्रिंट', 'र', 'फ', 'ै', 'क्स', '▁services'],
#   ['▁छोड़े', '▁गए', '▁लंबे', '▁break', 's', '▁की', '▁संख्या', '▁idle'],
#   ['▁seeds', '▁उत्पादन', '▁programme'],
#   ['▁परियोजना', '▁estimate', 'd', '▁आकार', 'ः', '▁s'],
#   ['▁weather', 'van', 'e', '▁दि', 'ग', '्', 'दर्श', 'क'],
#   ['▁young',
#    '▁engineers',
#    '▁एवं',
#    '▁टेक्',
#    'नो',
#    'क्र',
#    'ॆ',
#    'ट्स',
#    '▁हेतु',
#    '▁techno',
#    'c',
#    'rat',
#    's'],
#   ['▁उनके', '▁लेखन', '▁में', '▁a', '▁flow', '▁है', '।'],
#   ['▁asia', '▁प्रशांत', '▁trade', '▁करारनामा', '▁apt', 'a'],
#   ['▁और',
#    '▁धरती',
#    '▁में',
#    '▁faith',
#    '▁करनेवालों',
#    '▁के',
#    '▁लिए',
#    '▁बहुत',
#    'सी',
#    '▁evidence',
#    '▁है'],
#   ['▁क्या', '▁आप', '▁नये', '▁tenant', '▁हैं'],
#   ['▁किन्हीं',
#    '▁previous',
#    '▁company',
#    '▁laws',
#    '▁के',
#    '▁तहत',
#    '▁registered',
#    '▁कम्प',
#    '▁नी'],
#   ['▁इसका',
#    '▁प्रारम्भ',
#    '▁modest',
#    '▁था',
#    '▁और',
#    '▁growth',
#    '▁भी',
#    '▁मंद',
#    '▁slow',
#    '▁से',
#    '▁था'],
#   ['▁life', '▁की', '▁हर', '▁deals', '▁से', '▁लड़', 'कर'],
#   ['▁और',
#    '▁हम',
#    '▁two',
#    '▁सरल',
#    '▁expressions',
#    '▁में',
#    '▁expand',
#    '▁करने',
#    '▁के',
#    '▁लिए',
#    '▁जा',
#    '▁रहे',
#    '▁हैं'],
#   ['▁बैंक', '▁ने', '▁customers', '▁को', '▁notice', '▁दी', '।'],
#   ['▁उपयोक्ता', '▁ने', '▁saving', '▁रद्द', '▁किया'],
#   ['▁अधिक',
#    '▁adopted',
#    '▁के',
#    '▁consideration',
#    's',
#    '▁से',
#    '▁उन्होंने',
#    '▁tamil',
#    '▁से',
#    '▁भी',
#    '▁कुछ',
#    '▁terms',
#    '▁का',
#    '▁लिया',
#    '▁है',
#    '।'],
#   ['▁इस',
#    '▁के',
#    '▁बाद',
#    '▁इस्लाम',
#    '▁में',
#    '▁caliph',
#    'ate',
#    '▁का',
#    '▁era',
#    '▁beg',
#    'an',
#    '▁हुआ',
#    '।'],
#   ['▁subordinate', '▁कार्यालयों'],
#   ['▁रेशम',
#    'कीट',
#    '▁पालन',
# ...
#    '▁north',
#    '▁एवम',
#    '▁पूर्वी',
#    '▁भाग',
#    '▁की',
#    '▁तरफ़',
#    '▁mountain',
#    '▁तथा'],
#   ['▁भारतीयों', '▁को', '▁बहुत', '▁अधिक', '▁confidence', '▁आया', '▁है'],
#   ['▁3',
#    '71',
#    'c',
#    '▁manipur',
#    '▁state',
#    '▁के',
#    '▁respect',
#    '▁में',
#    '▁विशेष',
#    '▁उपबंध'],
#   ['▁special', '▁वेतन'],
#   ['▁एजेंड',
#    'ा',
#    '▁views',
#    '▁के',
#    '▁शीर्ष',
#    '▁पर',
#    '▁दिखाएँ',
#    '▁option',
#    '▁check'],
#   ['▁इससे',
#    '▁started',
#    '▁करने',
#    '▁के',
#    '▁लिए',
#    '▁इनमें',
#    '▁से',
#    '▁किसी',
#    '▁में',
#    '▁photos',
#    '▁import',
#    '▁करेंः'],
#   ['▁उन्होंने',
#    '▁life',
#    '▁और',
#    '▁काल',
#    'खंड',
#    '▁की',
#    '▁truth',
#    '▁को',
#    '▁pages',
#    '▁पर',
#    '▁उतारा',
#    '।'],
#   ['▁जग', 'द्', 'गुरु', '▁ram', 'bhadra', 'charya', '▁विकलांग', '▁university'],
#   ['▁राज', 'लक्ष्मी', '▁engineering', '▁college'],
#   ['▁राम', 'भू', 'ल', 'चन्द', '▁je', 'th', 'mal', 'ani'],
#   ['▁मैं',
#    '▁अक्सर',
#    '▁husband',
#    '▁से',
#    '▁झु',
#    'ं',
#    'झ',
#    'ला',
#    '▁पड़ता',
#    '▁था',
#    '▁और',
#    '▁उससे',
#    '▁pre',
#    'oc',
#    'c',
#    'up',
#    'ation',
#    's',
#    '▁भी',
#    '▁था',
#    '।'],
#   ['▁drought',
#    '▁के',
#    '▁लिए',
#    '▁अति',
#    '▁vulnerabl',
#    'e',
#    '▁क्षेत्रों',
#    '▁का',
#    '▁पहचानना'],
#   ['▁केंद्रीय',
#    '▁मत्स्य',
#    'पालन',
#    '▁',
#    'nautical',
#    '▁इंजीनियरी',
#    'ंग',
#    '▁प्रशिक्षण',
#    '▁संस्थान'],
#   ['▁ये',
#    '▁initiatives',
#    '▁त्यौहार',
#    '▁के',
#    '▁रूप',
#    '▁में',
#    '▁मना',
#    'ये',
#    '▁जाएं',
#    '▁यह',
#    '▁बहुत',
#    '▁need',
#    '▁है',
#    '।'],
#   ['▁un', 'satisfactory', '▁care', '▁या', '▁ई', 'ला', 'ज़', '।'],
#   ['▁अभियंता', 'ओं', '▁और', '▁contractors', '▁की', '▁appointment'],
#   ['▁विकास',
#    '▁के',
#    '▁कई',
#    '▁बडे',
#    '़',
#    '▁पहलू',
#    '▁a',
#    'ura',
#    'nga',
#    'ze',
#    'b',
#    '▁एवं',
#    '▁last',
#    '▁mugal',
#    '▁शासकों',
#    '▁द्वारा',
#    '▁किये',
#    '▁गये',
#    '।'],
#   ['▁two', '▁equal', '▁हिस्से'],
#   ['▁शक्ति',
#    '▁सम्बन्धी',
#    '▁predominant',
#    'ly',
#    '▁और',
#    '▁ज्ञान',
#    'सम्बन्धी',
#    '▁जड़',
#    'ता',
#    '।'],
#   ['▁पंजीकृत',
#    '▁service',
#    '▁provider',
#    '▁को',
#    '▁निर्धारिती',
#    '▁कहा',
#    '▁जाएगा',
#    '।'],
#   ['▁इसी',
#    '▁दौरान',
#    '▁स्थानीय',
#    '▁manufacture',
#    '▁के',
#    '▁लिए',
#    '▁bengal',
#    '▁के',
#    '▁coal',
#    '▁का',
#    '▁प्रयोग',
#    '▁किया',
#    '▁जा',
#    '▁रहा',
#    '▁था'],
#   ['▁ne',
#    'undor',
#    'f',
#    '▁न्यू',
#    'न्द',
#    'ॉ',
#    'र्फ',
#    'state',
#    '▁of',
#    '▁network',
#    '▁card',
#    '▁is',
#    '▁connected'],
#   ['▁पर',
#    'ां',
#    'त्रिक',
#    '▁fever',
#    '▁स',
#    'ल',
#    'मोन',
#    'ेला',
#    '▁para',
#    'ty',
#    'ph',
#    'oid',
#    '▁जीवाणु',
#    '▁के',
#    '▁कारण',
#    '▁होता',
#    '▁है'],
#   ['▁अस्त',
#    'ु',
#    '▁इस',
#    '▁play',
#    '▁में',
#    '▁वह',
#    '▁सब',
#    '▁है',
#    '▁जिससे',
#    '▁play',
#    '▁good',
#    '▁हो',
#    '▁सके',
#    '।'],
#   ['▁वहाँ',
#    '▁ये',
#    '▁ऊतकों',
#    '▁में',
#    '▁penetrat',
#    'e',
#    '▁करते',
#    '▁हैं',
#    '▁और',
#    '▁adult',
#    '▁कृमि',
#    'यों',
#    '▁में',
#    '▁develop',
#    '▁हो',
#    '▁जाते',
#    '▁हैं',
#    '।'],
#   ['▁फिर',
#    '▁भी',
#    '▁one',
#    '▁से',
#    '▁अधिक',
#    '▁वर्गो',
#    '▁का',
#    '▁आध्यात्मिक',
#    '▁allegiance',
#    '▁सिख',
#    'ला',
#    'ने',
#    '▁लगे',
#    '।'],
#   ['▁constitution',
#    '▁के',
#    '▁specific',
#    '▁अनुच्छेद',
#    '▁का',
#    '▁निरसन',
#    '▁कर',
#    '▁दिया',
#    '▁गया',
#    '▁है',
#    '।'],
#   ['▁linear', '▁समीकरण'],
#   ['▁150', '▁किस', '▁number', '▁का', '▁25', '▁है'],
#   ['▁फ़ाइल', '▁का', '▁rename', '▁बदलें', '▁r'],
#   ['▁युवाओं', '▁संबंधी', '▁संसदीय', '▁forum'],
#   ['▁क्या', '▁text', '▁एकल', '▁पंक्ति', '▁मोड', '▁में', '▁है'],
#   ['▁उस',
#    '▁समय',
#    '▁an',
#    'juman',
#    '▁के',
#    '▁पास',
#    '▁न',
#    '▁funds',
#    '▁थी',
#    '▁न',
#    '▁full'],
#   ['▁१७', '▁june'],
#   ['▁आराम', '▁व', '▁in', '▁के', '▁gardens', '▁में', '▁बहुत', '▁से'],
#   ['▁adopt',
#    '▁की',
#    '▁गति',
#    '▁अपनाएं',
#    'ः',
#    '▁उसका',
#    '▁secret',
#    '▁है',
#    '▁धीर',
#    'ज',
#    '।'],
#   ['▁यह',
#    '▁कहना',
#    '▁गलत',
#    '▁है',
#    '▁कि',
#    '▁hindi',
#    '▁words',
#    '▁को',
#    '▁urdu',
#    '▁से',
#    '▁निकाला',
#    '▁जा',
#    '▁रहा',
#    '▁है',
#    '।'],
#   ['▁कोल्हटकर',
#    '▁का',
#    '▁humour',
#    '▁प्रसाद',
#    'गुण',
#    '▁delight',
#    'ful',
#    '▁प्रा',
#    'ंजी',
#    '▁तथा',
#    '▁उत्त',
#    '▁high',
#    'ly',
#    '▁है',
#    '।'],
#   ['▁एक',
#    '▁brilliant',
#    '▁वैज्ञानिकों',
#    '▁और',
#    '▁engineers',
#    '▁बनने',
#    '▁का',
#    '▁way',
#    '▁तय',
#    '▁कर',
#    '▁सकती',
#    '▁है'],
#   ['▁credit', 's', '▁एवं', '▁license'],
#   ['▁create', '▁से', '▁एक', '▁खोज', '▁फ़ोल्डर', '▁बनाएँ', '▁d'],
#   ['▁उदाहरण',
#    '▁के',
#    '▁लिए',
#    '▁देखें',
#    '▁कि',
#    '▁कैसे',
#    '▁खोज',
#    '▁engine',
#    '▁का',
#    '▁market',
#    '▁developed',
#    '▁हुआ'],
#   ['▁यही',
#    '▁के',
#    '▁resident',
#    '▁रु',
#    'ड',
#    'या',
#    'र्ड',
#    '▁कि',
#    'प',
#    'लिंग',
#    '▁को',
#    '▁१९०७',
#    '▁में',
#    '▁nobel',
#    '▁prize',
#    '▁भी',
#    '▁मिला',
#    '▁था',
#    '।'],
#   ['▁शक्ति', '▁पृथक्करण', '▁का', '▁rules'],
#   ['▁dr',
#    '▁k',
#    'lash',
#    '▁का',
#    '▁accelerator',
#    '▁diagnosis',
#    '▁option',
#    '▁check'],
#   ['▁sita',
#    '▁ram',
#    'lochan',
#    '▁में',
#    '▁एक',
#    '▁है',
#    'ड',
#    'क्ल',
#    'र्क',
#    '▁आया',
#    '▁the',
#    '▁सरकार',
#    '।'],
#   ['▁सब',
#    'ेरे',
#    '▁seven',
#    '▁बजे',
#    '▁उन',
#    'हें',
#    '▁त',
#    'स',
#    '▁world',
#    '▁पर',
#    '▁eyes',
#    '▁next',
#    '▁लेनी',
#    '▁थी',
#    '।'],
#   ['▁कुछ',
#    '▁qualitative',
#    '▁achievements',
#    '▁पर',
#    '▁भी',
#    '▁ध्यान',
#    '▁देना',
#    '▁must',
#    '▁है'],
#   ['▁केवल', '▁एक', '▁न', 'स', '▁पर', '▁swelling', '▁दिखाई', '▁देना'],
#   ['▁संदेश', '▁extraction', '▁प्रक्रिया', '▁विफल', '▁रहा'],
#   ['▁सहायक', '▁traffic', '▁अधिकारी', '▁सर्वेक्षण'],
#   ['▁उपयोक्ता', '▁username', '▁तथा', '▁password', '▁नीचे', '▁भरें'],
#   ['▁6',
#    '▁zero',
#    '▁बड़ा',
#    '▁है',
#    '▁और',
#    '▁5',
#    '▁भी',
#    '▁0',
#    '▁से',
#    '▁बड़ा',
#    '▁है'],
#   ['▁आप',
#    '▁खुद',
#    '▁कल्पना',
#    '▁कर',
#    '▁सकते',
#    '▁हैं',
#    '▁कि',
#    '▁हमारे',
#    '▁children',
#    '▁पर',
#    '▁और',
#    '▁everybody',
#    '▁पर',
#    '▁उसका',
#    '▁क्या',
#    '▁impact',
#    '▁होता',
#    '।'],
#   ['▁exchange',
#    '▁पत्र',
#    '▁की',
#    '▁acknowledgement',
#    '▁obtained',
#    '▁कर',
#    '▁ली',
#    '▁जानी',
#    '▁चाहिए',
#    '।'],
#   ['▁गलत', '▁declare', '▁type'],
#   ['▁ऐसे',
#    '▁accounts',
#    '▁जो',
#    '▁द्विपक्षीय',
#    '▁trade',
#    '▁के',
#    '▁सिलसिले',
#    '▁में',
#    '▁both',
#    '▁पक्षों',
#    '▁द्वारा',
#    '▁रखे',
#    '▁जाएं',
#    '।'],
#   ['▁जब',
#    '▁poet',
#    '▁की',
#    '▁language',
#    '▁अपनी',
#    '▁न',
#    '▁cease',
#    's',
#    '▁की',
#    '▁हो',
#    '▁जाती',
#    '▁है',
#    '▁तब',
#    '▁उसका',
#    '▁कुछ',
#    '▁अनि',
#    'र्व',
#    'च',
#    'नीय',
#    '▁चमत्कार',
#    '▁हो',
#    '▁जाता',
#    '▁है',
#    '।'],
#   ['▁configure', '▁करें', '▁o'],
#   ['▁old', '▁ने', '▁boy', '▁को', '▁उसकी', '▁book', '▁लौटा', '▁दी', '।'],
#   ['▁a', '▁वर्ष', '▁की', '▁घटनाओं', '▁का', '▁record'],
#   ['▁add', '▁स्रोत', '▁file', '...'],
#   ['▁resize', '▁हैंडल', '▁दिखाएँ'],
#   ['▁the', '▁की', '▁being'],
#   ['▁एक', '▁you', '▁देनी', '▁ही', '▁होगी'],
#   ['▁नसीहत', '▁he', 'ed', '▁कर', '▁लेगा', '▁जिसको', '▁god', '▁होगा'],
#   ['▁lamp', '▁का', '▁oil'],
#   ['▁विभिन्न', '▁sorts', '▁का', '▁संगम', '।'],
#   ['▁क्या',
#    '▁ग्नोम',
#    '▁calendar',
#    '▁से',
#    '▁tasks',
#    '▁को',
#    '▁आयात',
#    '▁किया',
#    '▁गया',
#    '▁या',
#    '▁नहीं'],
#   ['▁इस', '▁device', '▁पर', '▁google', '▁drive', '▁अक्षम', '▁करें'],
#   ['▁certificate', '▁की', '▁वैधता'],
#   ['▁five', '▁दिन', '▁i', '▁में', '▁रहना', '▁होता', '।'],
#   ['▁इसका',
#    '▁people',
#    '▁की',
#    '▁thinking',
#    '▁और',
#    '▁उपभोग',
#    '्य',
#    '▁goods',
#    '▁की',
#    '▁खपत',
#    'प्रणाली',
#    '▁पर',
#    '▁प्रभाव',
#    '▁पडा',
#    '▁है',
#    '।'],
#   ['▁उन्होंने',
#    '▁border',
#    'ing',
#    '▁states',
#    '▁को',
#    '▁अधिक',
#    '▁vigil',
#    '▁बरतन',
#    'े',
#    '▁की',
#    '▁advis',
#    'ed',
#    '▁दी',
#    '।'],
#   ['▁हाइ', 'लाइट', '▁box', '▁का', '▁भर', 'ाई', '▁color'],
#   ['▁त्रुटिः',
#    '▁b',
#    's',
#    's',
#    'id',
#    '▁argument',
#    '▁मान',
#    '▁s',
#    '▁a',
#    '▁valid',
#    '▁b',
#    's',
#    's',
#    'id',
#    '▁नहीं',
#    '▁है'],
#   ['▁पर', '▁भारत', '▁की', '▁nervous', '▁की', '▁reasons', '▁different', '▁थी'],
#   ['▁यह', '▁3', '14', '▁के', '▁equal', '▁है', '।'],
#   ['▁6', '▁या', '▁100', '3', '▁है', '।'],
#   ['▁क्षय', '▁रोग', '▁का', '▁क्या', '▁treatment', '▁है'],
#   ['▁columns', '▁के', '▁आरपार', '▁आ', 'ड़ी', '▁पंक्ति', '▁c', 'line'],
#   ['▁चिल्ला',
#    'ने',
#    '▁की',
#    '▁बजाय',
#    '▁सी',
#    'टी',
#    '▁के',
#    '▁loud',
#    'er',
#    '▁कहीं',
#    '▁अधिक',
#    '▁साफ',
#    '▁और',
#    '▁for',
#    '▁होते',
#    '▁हैं',
#    '।'],
#   ['▁स्वयं',
#    '▁quran',
#    '▁में',
#    '▁इस',
#    '▁word',
#    '▁का',
#    '▁कोई',
#    '▁७०',
#    '▁times',
#    '▁mentioned',
#    '▁हुआ',
#    '▁है',
#    '।'],
#   ['▁विंडो', '▁desktop', '▁11', '▁पर'],
#   ['▁उनकी',
#    '▁memory',
#    '▁में',
#    '▁एक',
#    '▁installed',
#    '▁मूर्ति',
#    '▁यहां',
#    '▁स्थापित',
#    '▁है',
#    '।'],
#   ['▁हम', '▁a', '▁छोटी', '▁number', '▁पाते', '▁हैं', '▁क्योंकि', '▁हम'],
#   ['▁new', '▁लम्बाई', '▁choose'],
#   ['▁अधिकतर',
#    '▁काम',
#    '▁वह',
#    '▁अपने',
#    '▁to',
#    '▁पर',
#    '▁bhar',
#    'ad',
#    'wa',
#    'j',
#    '▁के',
#    '▁advice',
#    '▁के',
#    '▁बिना',
#    '▁ही',
#    '▁करता',
#    '▁है',
#    '।'],
#   ['▁निरीक्षण', '▁जो', '▁विस्तृत', '▁details', '▁वाला', '▁हो', '।'],
#   ['▁जो', '▁greek', '▁अक्षर', '▁alpha', '▁द्वारा', '▁चिह्नित', '▁है'],
#   ['▁new', '▁संदेश', '▁window', '▁खोलें'],
#   ['▁क्या',
#    '▁आप',
#    '▁अगल',
#    'ी',
#    '▁sheet',
#    '▁में',
#    '▁spelling',
#    '▁check',
#    '▁करना',
#    '▁चाहेंगे'],
#   ['▁कभी',
#    '▁ये',
#    '▁hard',
#    'er',
#    '▁होता',
#    '▁है',
#    '▁और',
#    '▁कभी',
#    '▁easier',
#    '▁किंतु'],
#   ['▁कालिदास', '▁का', '▁epic', '▁का', 'द', 'म्बर', 'ी', '▁1862'],
#   ['▁और',
#    '▁मैं',
#    '▁hope',
#    '▁करता',
#    '▁हूं',
#    '▁कि',
#    '▁आप',
#    '▁मेरे',
#    '▁अभि',
#    'नन्दन',
#    '▁भी',
#    '▁उसी',
#    '▁spirit',
#    '▁से',
#    '▁accept',
#    '▁करेंगे',
#    '।'],
#   ['▁key',
#    '▁को',
#    '▁दबाने',
#    '▁पर',
#    '▁संकेतक',
#    '▁का',
#    '▁position',
#    '▁निर्दिष्ट',
#    '▁करें',
#    '▁gui',
#    '▁पर',
#    '▁कंट्रोल',
#    '▁लगाएँ',
#    '।'],
#   ['▁और',
#    '▁तो',
#    '▁यह',
#    '▁सब',
#    '▁मेरे',
#    '▁दूसरे',
#    '▁वृत्त',
#    '▁का',
#    '▁quadrant',
#    '▁भाग',
#    '▁intersection',
#    '▁काम'],
#   ['▁उनके', '▁message', '▁समस्त', '▁मानवता', '▁के', '▁लिए', '▁हैं', '।'],
#   ['▁external', '▁छवि', '▁लोड', '▁करें'],
#   ['▁best', '▁प्रयास'],
#   ['▁रिजर्व',
#    '▁rbi',
#    '▁द्वारा',
#    '▁capital',
#    '▁का',
#    '▁पुनर्गठन',
#    '▁किया',
#    '▁जा',
#    '▁रहा',
#    '▁है',
#    '।'],
#   ['▁विजेट', '▁का', '▁data', '▁स्रोत', '▁clear', '▁करें'],
#   ['▁दूसरी',
#    '▁उस',
#    '▁day',
#    '▁के',
#    '▁बाद',
#    '▁से',
#    '▁temple',
#    '▁में',
#    '▁जो',
#    '▁भी',
#    '▁बने',
#    '▁वह',
#    '▁बिना',
#    '▁किसी',
#    '▁भेदभाव',
#    '▁के',
#    '▁सबको',
#    '▁available',
#    '▁हो',
#    '।'],
#   ['▁सेटिंग',
#    '▁पूरे',
#    '▁नहीं',
#    '▁हुए',
#    '▁हैं',
#    '▁इन्हें',
#    '▁complete',
#    '▁करें',
#    '▁और',
#    '▁फिर',
#    '▁try',
#    '▁करें'],
#   ['▁बिलकुल', '▁each', '▁के', '▁ऊपर', '▁each', '▁हैं'],
#   ['▁शोषण',
#    'कर्ता',
#    '▁शोषण',
#    '▁द्वारा',
#    '▁revenue',
#    '▁अर्जित',
#    '▁करता',
#    '▁है',
#    '।'],
#   ['▁y', '▁के', '▁a', '▁समारोह', '▁के', '▁रूप', '▁में', '।'],
#   ['▁कोई', '▁kind', '▁white', '▁foreign', 'er', '▁आकर', '▁बचा', 'एंगे'],
#   ['▁अवैध', '▁status', '▁कोड'],
#   ['▁दूरभाष', '▁no', '▁230', '34', '35', '3'],
#   ['▁नियम', '▁editor'],
#   ['▁हाथ',
#    'कर',
#    'घ',
#    'े',
#    '▁पर',
#    '▁कप',
#    'डा',
#    '▁weaving',
#    '▁का',
#    '▁उद्योग',
#    '।'],
#   ['▁भारत',
#    '▁में',
#    '▁tiger',
#    '▁के',
#    '▁hunt',
#    's',
#    '▁के',
#    '▁लिए',
#    '▁भी',
#    '▁elephant',
#    '▁का',
#    '▁इस्तेमाल',
#    '▁किया',
#    '▁जाता',
#    '▁है',
#    '।'],
#   ['▁five', '▁मिली', 'ग्राम', '▁प्रति', '▁pound'],
#   ['▁mind', '▁ही', '▁mind', '▁इतिहास', '▁के', '▁pages', '▁पलट', '▁गया', '।'],
#   ['▁इनके', '▁पुत्र', '▁स्क', 'न्द', '▁और', '▁ganesh', '▁हैं', '।'],
#   ['▁national', '▁य', '▁long', '▁distance', '▁की', '▁सेवा'],
#   ['▁परंतु',
#    '▁उसके',
#    '▁न',
#    'सी',
#    'ब',
#    '▁में',
#    '▁poverty',
#    '▁एवं',
#    '▁hunger',
#    '▁लिखा',
#    '▁था',
#    '।'],
#   ['▁नई', '▁सूची', '▁entry', '▁add'],
#   ['▁patna', '▁शहर', '▁में', '▁भी', '▁arrest', 's', '▁होती', '▁रहीं', '।'],
#   ['▁therefore',
#    '▁तुम',
#    '▁हमारी',
#    '▁remember',
#    '▁रखो',
#    '▁तो',
#    '▁मै',
#    '▁भी',
#    '▁तुम्हारा',
#    '▁ज़िक्र',
#    '▁खैर',
#    '▁किया',
#    '▁कर',
#    'ु',
#    'ग',
#    'ाँ',
#    '▁और',
#    '▁मेरा',
#    '▁शुक्र',
#    'िया',
#    '▁thankful',
#    '▁करते',
#    '▁रहो',
#    '▁और',
#    '▁ungrateful',
#    '▁न',
#    '▁करो'],
#   ['▁album', '▁नाम', '▁a'],
#   ['▁कपिल', '▁ka', 'k'],
#   ['▁तंत्र',
#    '▁documentation',
#    '▁तंत्र',
#    '▁प्रलेख',
#    'ीकरण',
#    '▁तंत्र',
#    '▁दस्तावेज',
#    'ीकरण'],
#   ['▁परंतु',
#    '▁water',
#    '▁के',
#    '▁अणुओं',
#    '▁में',
#    '▁आयन',
#    'ीकरण',
#    '▁की',
#    '▁tendency',
#    '▁बहुत',
#    '▁कम',
#    '▁होती',
#    '▁है',
#    '।'],
#   ['▁अभिलेख', '▁loading', '▁करते', '▁समय', '▁an', '▁त्रुटि', '▁हुई'],
#   ['▁उनकी',
#    '▁laughter',
#    '▁जिस',
#    '▁तरह',
#    '▁अचानक',
#    '▁फूट',
#    '▁पड़ी',
#    '▁थी',
#    '▁उसी',
#    '▁तरह',
#    '▁अचानक',
#    '▁away',
#    '▁हो',
#    '▁गई',
#    '।'],
#   ['▁यह', '▁fever', '▁के', '▁लिए', '▁बेहतरी', 'न', '▁treatment', '▁है', '।'],
#   ['▁cigarette', '▁का', '▁smoke'],
#   ['▁in',
#    'v',
#    'bin',
#    'o',
#    '▁ट्रा',
#    'यल',
#    '▁failure',
#    '▁failure',
#    '▁की',
#    '▁जांच'],
#   ['▁स्वरोजगार',
#    '▁स्थापित',
#    '▁करने',
#    '▁के',
#    '▁लिए',
#    '▁procedure',
#    '▁की',
#    '▁जानकारी',
#    '▁providing',
#    '▁करना'],
#   ['▁संगठन', '▁के', '▁कानूनी', '▁affairs', '▁most', '▁हैं', '।'],
#   ['▁wishes', '▁दिखाएँ'],
#   ['▁new', '▁और', '▁continuing', '▁योजनाएं'],
#   ['▁यह',
#    '▁वास्तव',
#    '▁में',
#    '▁jai',
#    '▁विज्ञान',
#    '▁का',
#    '▁example',
#    '▁है',
#    '।'],
#   ['▁छेद',
#    '▁की',
#    '▁radius',
#    '▁से',
#    '▁यह',
#    '▁radius',
#    '▁छोटी',
#    '▁नहीं',
#    '▁हो',
#    '▁सकती'],
#   ['▁उन्नत', '▁प्र', 'मे', 'य', '▁setup', '▁am', 's'],
#   ['▁', 'क्रोमियम', '▁आपका', '▁डिफ़ॉल्ट', '▁browser', '▁नहीं', '▁है'],
#   ['▁i', '▁के', '▁पीछेपीछे', '▁हम', '▁buy', '▁के', '▁भीतर', '▁घुस', 'े', '।'],
#   ['▁पॉल', '▁new', 'man'],
#   ['▁rural', '▁विद्य', 'ु', 'करण', '▁corporation', '▁लिमिटेड'],
#   ['▁सम्मेलन', '▁another', '▁अन्य', '▁महत्वपूर्ण', '▁माध्यम', '▁है'],
#   ['▁market', '▁कार्यकलापों', '▁for', '▁finance', '▁पोषण'],
#   ['▁सही', '▁प्रकार', '▁से', '▁solved', '▁किए', '▁tasks', '▁की', '▁number'],
#   ['▁यह', '▁black', '▁छवि', '▁है', '▁या', '▁कोई', '▁रंगीन', '▁image', '▁है'],
#   ['▁1974', '▁पेरिस', '▁ओपन', 'पुरुष', '▁एकल'],
#   ['▁सहायक', '▁run', 'time', '▁messages', '▁को', '▁छापें'],
#   ['▁महा',
#    'धमनी',
#    'के',
#    '▁valve',
#    '▁की',
#    '▁अयोग्य',
#    'ता',
#    '▁के',
#    '▁कारण',
#    '▁दृश्य',
#    '▁found',
#    '▁दिखाई',
#    '▁देता',
#    '▁है'],
#   ['▁fig', '▁bar', '▁x', 'f', 'ig', '▁दस्तावेज़', '▁fig'],
#   ['▁कई',
#    '▁days',
#    '▁तक',
#    '▁for',
#    '▁करने',
#    '▁के',
#    '▁बाद',
#    '▁भी',
#    '▁राजा',
#    '▁से',
#    '▁audience',
#    '▁नहीं',
#    '▁हुई',
#    '।'],
#   ['▁डायर',
#    'िया',
#    '▁शेष',
#    'ान्त',
#    '्र',
#    'ब',
#    'ृ',
#    'हद',
#    'ान्त',
#    '्र',
#    'शोथ',
#    '▁का',
#    '▁a',
#    '▁common',
#    '▁लक्षण',
#    '▁है'],
#   ['▁ड्र',
#    'ॉ',
#    'अर',
#    '▁या',
#    '▁menu',
#    '▁for',
#    '▁displayed',
#    '▁उपकरण',
#    'युक्त',
#    'ि'],
#   ['▁मस्तिष्क', '▁के', '▁ventricle', 's', '▁का', '▁swelling'],
#   ['▁हृदय', '▁के', '▁relating', '▁वॉल', '्व', '▁से', '▁संबंधित'],
#   ['▁iso',
#    'mer',
#    's',
#    '▁जो',
#    '▁एक',
#    '▁ही',
#    '▁संयोजन',
#    '▁रखता',
#    '▁है',
#    '▁लेकिन',
#    '▁अपनी',
#    '▁arrangements',
#    '▁में',
#    '▁differ',
#    '▁होते',
#    '▁हैं'],
#   ['▁mercury',
#    '▁का',
#    '▁सबसे',
#    '▁toxic',
#    '▁यौगिक',
#    '▁है',
#    '▁me',
#    'th',
#    'y',
#    'l',
#    '▁मर',
#    'कर',
#    'ी',
#    '।'],
#   ['▁israel', '▁और', '▁अमेरिकी', '▁congress', 'ion', 'al', '▁के', '▁2'],
#   ['▁नया', '▁package', '▁option', '▁जोड़ें'],
#   ['▁पृष्ठभूमि',
#    '▁विशेष',
#    '▁डिफ़ॉल्ट',
#    '▁background',
#    '▁चुनने',
#    '▁की',
#    '▁ability',
#    '▁इस',
#    '▁दरवाजे',
#    '▁के',
#    '▁पीछे',
#    '▁है'],
#   ['▁embryo',
#    '▁या',
#    '▁भ्रूण',
#    '▁और',
#    '▁गर्भ',
#    'नाल',
#    '▁के',
#    '▁बीच',
#    '▁defi',
#    'n',
#    'it',
#    'ive',
#    '▁जोड़ने',
#    '▁placenta'],
#   ['▁मेरे',
#    '▁दौर',
#    '▁में',
#    '▁kashmir',
#    '▁में',
#    '▁h',
#    'ur',
#    'riya',
#    't',
#    '▁अहम',
#    '▁थी'],
#   ['▁2002',
#    '08',
#    '26',
#    '▁पर',
#    '▁deceased',
#    '▁के',
#    '▁शव',
#    '▁को',
#    '▁post',
#    '▁परीक्षा',
#    '▁के',
#    '▁लिए',
#    '▁भेजा',
#    '▁गया',
#    '▁था'],
#   ...]}

# %% [markdown]
# # TEST

# %%
# Basic corpus statistics & script coverage (choose split)
from pathlib import Path
from collections import Counter
import unicodedata, math

SPLIT = "test"  # "train", "valid", or "test"
corpus_path = Path('..') / f'/content/hicm_corpus.{SPLIT}.txt'
assert corpus_path.exists(), f"Corpus file not found for split '{SPLIT}'."

sample_lines = 250000  # adjust for speed vs accuracy
char_counter = Counter()
line_count = 0

# Unicode block ranges
DEV_START, DEV_END = 0x0900, 0x097F
LAT_START, LAT_END = 0x0041, 0x007A  # rough (includes uppercase/lowercase subset)

with corpus_path.open('r', encoding='utf-8') as f:
    for line in f:
        line_count += 1
        for ch in line.rstrip('\n'):
            char_counter[ch] += 1
        if line_count >= sample_lines:
            break

cats = Counter()
for ch, freq in char_counter.items():
    cp = ord(ch)
    if DEV_START <= cp <= DEV_END:
        cats['Devanagari'] += freq
    elif 'A' <= ch <= 'Z' or 'a' <= ch <= 'z':
        cats['Latin'] += freq
    elif ch.isdigit():
        cats['Digits'] += freq
    elif ch.isspace():
        cats['Whitespace'] += freq
    else:
        cats['Other'] += freq

total_chars = sum(cats.values())
print(f"Split: {SPLIT}")
print(f"Lines sampled: {line_count:,}")
print(f"Unique chars in sample: {len(char_counter):,}")
print("Character category distribution (approx):")
for k, v in cats.items():
    print(f"  {k:12s}: {v:10d}  ({v/total_chars*100:5.2f}%)")

coverage = total_chars / sum(char_counter.values())
print(f"Character coverage observed (sampling fraction): {coverage:0.4f}")

# Show top 20 Devanagari chars and top 20 Latin chars
print('\nTop 20 Devanagari chars:')
dev_top = [(c, char_counter[c]) for c in char_counter if DEV_START <= ord(c) <= DEV_END]
for c, freq in sorted(dev_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")

print('\nTop 20 Latin chars:')
lat_top = [(c, char_counter[c]) for c in char_counter if ('A' <= c <= 'Z' or 'a' <= c <= 'z')]
for c, freq in sorted(lat_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")
# Out:
# Split: test
# Lines sampled: 2,507
# Unique chars in sample: 155
# Character category distribution (approx):
#   Devanagari  :     120315  (38.75%)
#   Whitespace  :      54716  (17.62%)
#   Latin       :     129685  (41.76%)
#   Other       :       3862  ( 1.24%)
#   Digits      :       1934  ( 0.62%)
# Character coverage observed (sampling fraction): 1.0000
#
# Top 20 Devanagari chars:
#   े : 12598
#   क : 12415
#   ा : 9735
#   ह : 6676
#   र : 6404
#   न : 5619
#   ी : 4899
#   ं : 4602
#   स : 4456
#   ि : 4362
#   म : 3599
#   त : 3232
#   ो : 3050
#   ल : 2827
#   प : 2728
#   ् : 2686
#   ै : 2502
#   य : 2361
#   । : 2217
#   ए : 1906
#
# Top 20 Latin chars:
#   e : 15836
#   a : 10557
#   r : 10325
#   i : 10139
#   n : 9373
#   t : 9340
#   o : 8794
#   s : 8204
#   l : 5915
#   c : 5803
#   d : 4411
#   p : 4066
#   m : 4028
#   u : 3509
#   g : 2735
#   h : 2700
#   y : 2150
#   f : 1927
#   b : 1524
#   v : 1375

# %% [markdown]
# # VAL

# %%
# Basic corpus statistics & script coverage (choose split)
from pathlib import Path
from collections import Counter
import unicodedata, math

SPLIT = "valid"  # "train", "valid", or "test"
corpus_path = Path('..') / f'/content/hicm_corpus.{SPLIT}.txt'
assert corpus_path.exists(), f"Corpus file not found for split '{SPLIT}'."

sample_lines = 250000  # adjust for speed vs accuracy
char_counter = Counter()
line_count = 0

# Unicode block ranges
DEV_START, DEV_END = 0x0900, 0x097F
LAT_START, LAT_END = 0x0041, 0x007A  # rough (includes uppercase/lowercase subset)

with corpus_path.open('r', encoding='utf-8') as f:
    for line in f:
        line_count += 1
        for ch in line.rstrip('\n'):
            char_counter[ch] += 1
        if line_count >= sample_lines:
            break

cats = Counter()
for ch, freq in char_counter.items():
    cp = ord(ch)
    if DEV_START <= cp <= DEV_END:
        cats['Devanagari'] += freq
    elif 'A' <= ch <= 'Z' or 'a' <= ch <= 'z':
        cats['Latin'] += freq
    elif ch.isdigit():
        cats['Digits'] += freq
    elif ch.isspace():
        cats['Whitespace'] += freq
    else:
        cats['Other'] += freq

total_chars = sum(cats.values())
print(f"Split: {SPLIT}")
print(f"Lines sampled: {line_count:,}")
print(f"Unique chars in sample: {len(char_counter):,}")
print("Character category distribution (approx):")
for k, v in cats.items():
    print(f"  {k:12s}: {v:10d}  ({v/total_chars*100:5.2f}%)")

coverage = total_chars / sum(char_counter.values())
print(f"Character coverage observed (sampling fraction): {coverage:0.4f}")

# Show top 20 Devanagari chars and top 20 Latin chars
print('\nTop 20 Devanagari chars:')
dev_top = [(c, char_counter[c]) for c in char_counter if DEV_START <= ord(c) <= DEV_END]
for c, freq in sorted(dev_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")

print('\nTop 20 Latin chars:')
lat_top = [(c, char_counter[c]) for c in char_counter if ('A' <= c <= 'Z' or 'a' <= c <= 'z')]
for c, freq in sorted(lat_top, key=lambda x: x[1], reverse=True)[:20]:
    print(f"  {c} : {freq}")
# Out:
# Split: valid
# Lines sampled: 280
# Unique chars in sample: 127
# Character category distribution (approx):
#   Latin       :       7172  (39.70%)
#   Whitespace  :       3129  (17.32%)
#   Devanagari  :       7648  (42.33%)
#   Other       :         54  ( 0.30%)
#   Digits      :         64  ( 0.35%)
# Character coverage observed (sampling fraction): 1.0000
#
# Top 20 Devanagari chars:
#   े : 710
#   क : 635
#   ा : 629
#   ह : 474
#   र : 394
#   ी : 393
#   न : 335
#   ं : 326
#   स : 280
#   । : 272
#   ो : 240
#   म : 227
#   ि : 188
#   ल : 181
#   प : 174
#   त : 169
#   य : 159
#   ै : 154
#   ग : 148
#   ् : 135
#
# Top 20 Latin chars:
#   e : 852
#   i : 602
#   t : 580
#   a : 555
#   r : 533
#   n : 524
#   o : 480
#   s : 454
#   c : 313
#   l : 287
#   d : 284
#   m : 250
#   p : 207
#   u : 204
#   h : 166
#   y : 154
#   g : 149
#   f : 149
#   v : 85
#   b : 79

# %%
# Tokenize validation and test splits and write tokenized output files
from pathlib import Path

# Reuse tokenize_file and loaded SentencePiece processor `sp`
assert 'tokenize_file' in globals(), "tokenize_file() not defined. Run previous cell."

def write_tokenized(result_dict, split_name: str):
    out_file = Path(f"hicm_tokenized.{split_name}.txt")
    with out_file.open('w', encoding='utf-8') as out:
        for tokens in result_dict['tokens_per_line']:
            out.write(' '.join(tokens) + '\n')
    print(f"Wrote {out_file} ({result_dict['num_lines']} lines).")

results = {}
for split in ["valid", "test"]:
    split_path = Path('..') / f"/content/hicm_corpus.{split}.txt"
    if not split_path.exists():
        print(f"Skipping {split}; corpus file missing: {split_path}")
        continue
    res = tokenize_file(split_path)
    results[split] = res
    print(f"{split}: {res['num_lines']} lines tokenized.")
    write_tokenized(res, split)

results
# Out:
# valid: 280 lines tokenized.
# Wrote hicm_tokenized.valid.txt (280 lines).
# test: 2507 lines tokenized.
# Wrote hicm_tokenized.test.txt (2507 lines).
# {'valid': {'num_lines': 280,
#   'tokens_per_line': [['▁headmaster',
#     '▁संध्या',
#     '▁मे',
#     'ड',
#     'पल्ली',
#     'वार',
#     '▁के',
#     '▁encourage',
#     '▁करने',
#     '▁पर',
#     '▁teachers',
#     '▁and',
#     '▁students',
#     '▁ने',
#     '▁sand',
#     '▁से',
#     '▁fort',
#     '▁का',
#     '▁construction',
#     '▁किया',
#     '।'],
#    ['▁मन',
#     'पा',
#     '▁teacher',
#     '▁union',
#     '▁के',
#     '▁president',
#     '▁राज',
#     'ेश',
#     '▁ग',
#     'वर',
#     'े',
#     '▁ने',
#     '▁school',
#     '▁को',
#     '▁gift',
#     '▁देकर',
#     '▁सराहना',
#     '▁की',
#     '।'],
#    ['▁fort',
#     '▁का',
#     '▁testing',
#     '▁रमेश',
#     '▁सात',
#     'पु',
#     'ते',
#     '▁ने',
#     '▁किया',
#     '।'],
#    ['▁fort',
#     '▁construction',
#     '▁में',
#     '▁नि',
#     'खिल',
#     '▁का',
#     'वल',
#     'े',
#     ',',
#     '▁दर्शन',
#     '▁गे',
#     'ड़े',
#     'कर',
#     ',',
#     '▁सा',
#     'हिल',
#     '▁मे',
#     'श्',
#     'राम',
#     '▁इन',
#     '▁students',
#     '▁ने',
#     '▁सह',
#     'भाग',
#     '▁लिया',
#     '।'],
#    ['▁co',
#     'rp',
#     'or',
#     'ator',
#     '▁री',
#     'ता',
#     '▁मुल',
#     'े',
#     '▁ने',
#     '▁स',
#     'दि',
#     'च्छ',
#     'ा',
#     '▁gift',
#     '▁दी',
#     '।'],
#    ['▁friday',
#     '▁को',
#     '▁new',
#     '▁bu',
#     's',
#     '▁stand',
#     '▁पर',
#     '▁signature',
#     '▁campaign',
#     '▁की',
#     '▁starting',
#     '▁की',
#     '▁गई',
#     '।'],
#    ['▁कोमल',
#     '▁की',
#     '▁marriage',
#     '▁को',
#     '▁अभी',
#     '▁2',
#     '▁months',
#     '▁ही',
#     '▁हुए',
#     '▁थे',
#     '।'],
#    ['▁body',
#     '▁को',
#     '▁fan',
#     '▁से',
#     '▁लटक',
#     'ते',
#     '▁देख',
#     '▁वह',
#     '▁चीख',
#     '▁उठी',
#     '▁और',
#     '▁उसके',
#     '▁सु',
#     'सर',
#     '▁को',
#     '▁इस',
#     '▁वाक',
#     'ये',
#     '▁की',
#     '▁news',
#     '▁दी',
#     '।'],
#    ['▁कोमल',
#     '▁को',
#     '▁emergency',
#     '▁government',
#     '▁multi',
#     'spec',
#     'ial',
#     'ity',
#     '▁hospital',
#     ',',
#     '▁sector',
#     '-',
#     '16',
#     '▁में',
#     '▁ले',
#     '▁जाया',
#     '▁गया',
#     '▁जहां',
#     '▁doctors',
#     '▁ने',
#     '▁उसे',
#     '▁dead',
#     '▁लाई',
#     '▁गई',
#     '▁declare',
#     '▁कर',
#     '▁दिया',
#     '।'],
#    ['▁कोमल',
#     '▁का',
#     '▁husband',
#     '▁कुल',
#     'विंद',
#     'र',
#     '▁कुछ',
#     '▁work',
#     '▁नहीं',
#     '▁करता',
#     '।'],
#    ['▁बह',
#     'रहाल',
#     ',',
#     '▁पुलिस',
#     '▁ने',
#     '▁body',
#     '▁को',
#     '▁sector',
#     '-',
#     '16',
#     '▁के',
#     '▁hospital',
#     '▁की',
#     '▁मोर्च',
#     'री',
#     '▁में',
#     '▁रख',
#     'वा',
#     '▁दिया',
#     '▁है',
#     '।'],
#    ['▁पोस्ट',
#     'म',
#     'ार्ट',
#     'म',
#     '▁रिपोर्ट',
#     '▁के',
#     '▁बाद',
#     '▁death',
#     '▁के',
#     '▁real',
#     '▁reasons',
#     '▁का',
#     '▁पता',
#     '▁चल',
#     '▁सकेगा',
#     '।'],
#    ['▁first',
#     '▁and',
#     '▁second',
#     '▁one',
#     '▁day',
#     '▁मुकाबला',
#     '▁हं',
#     'बन',
#     'टो',
#     'टा',
#     '▁में',
#     '▁जबकि',
#     '▁third',
#     '▁one',
#     'day',
#     '▁मुकाबला',
#     '▁दा',
#     'ंब',
#     'ुला',
#     '▁में',
#     '▁खेला',
#     '▁जाएगा',
#     '।'],
#    ['▁वहीं',
#     '▁days',
#     '▁टी',
#     '-',
#     '20',
#     '▁मुकाबले',
#     '▁पाल',
#     '्ले',
#     'के',
#     'ल',
#     '▁में',
#     '▁खेले',
#     '▁जाएंगे',
#     '।'],
#    ['▁ज्ञात',
#     '▁हो',
#     '▁कि',
#     '▁इन',
#     '▁days',
#     '▁city',
#     '▁में',
#     '▁theft',
#     '▁की',
#     '▁incidents',
#     '▁काफी',
#     '▁बढ़',
#     '▁गई',
#     '।'],
#    ['▁हाल',
#     '▁के',
#     '▁fa',
#     'y',
#     's',
#     '▁में',
#     '▁हुई',
#     '▁यह',
#     '▁seven',
#     'th',
#     '▁incident',
#     '▁है',
#     '।'],
#    ['▁यह',
#     '▁notice',
#     '▁लगा',
#     '▁है',
#     '▁d',
#     'to',
#     '▁p',
#     'ff',
#     'ice',
#     '▁के',
#     '▁delivery',
#     '▁counter',
#     '▁पर',
#     '।'],
#    ['▁अगर',
#     '▁ground',
#     '▁reality',
#     '▁की',
#     '▁बात',
#     '▁करें',
#     '▁तो',
#     '▁situation',
#     '▁इससे',
#     '▁कहीं',
#     '▁worse',
#     '▁है',
#     '।'],
#    ['▁कई',
#     '▁applicant',
#     's',
#     '▁ऐसे',
#     '▁भी',
#     '▁हैं',
#     '▁जिन्हें',
#     '▁९',
#     '▁months',
#     '▁के',
#     '▁बाद',
#     '▁भी',
#     '▁',
#     'DL',
#     '▁deliver',
#     '▁नहीं',
#     '▁हो',
#     '▁पाया',
#     '।'],
#    ['▁दो',
#     '▁तीन',
#     '▁months',
#     '▁से',
#     '▁चक्कर',
#     '▁लगा',
#     '▁रहे',
#     '▁applicant',
#     's',
#     '▁की',
#     '▁count',
#     '▁तो',
#     '▁unlimited',
#     '▁है',
#     '।'],
#    ['▁उनका',
#     '▁claim',
#     '▁है',
#     '▁कि',
#     '▁d',
#     'l',
#     '▁तय',
#     '▁time',
#     '▁bound',
#     '▁के',
#     '▁भीतर',
#     '▁ही',
#     '▁deliver',
#     '▁हो',
#     '▁रहे',
#     '▁हैं',
#     '।'],
#    ['▁फिर',
#     '▁notice',
#     '▁क्यों',
#     '▁लगाया',
#     '▁तो',
#     '▁answer',
#     '▁मिला',
#     '▁कि',
#     '▁इस',
#     '▁बाबत',
#     '▁उन्हें',
#     '▁कोई',
#     '▁information',
#     '▁ही',
#     '▁नहीं',
#     '▁है',
#     '।'],
#    ['▁sense',
#     'x',
#     '▁में',
#     '▁involve',
#     '▁thirty',
#     '▁companies',
#     '▁में',
#     '▁से',
#     '▁only',
#     '▁nine',
#     '▁ने',
#     '▁loss',
#     '▁उठाया',
#     '▁जबकि',
#     '▁remaining',
#     '▁सभी',
#     '▁profit',
#     '▁में',
#     '▁रहीं',
#     '।'],
#    ['▁यह',
#     '▁fact',
#     '▁environment',
#     '▁protection',
#     '▁committee',
#     '▁की',
#     '▁inspection',
#     '▁से',
#     '▁सामने',
#     '▁आया',
#     '▁है',
#     '।'],
#    ['▁normal',
#     '▁days',
#     '▁में',
#     '▁यह',
#     '▁figure',
#     '▁',
#     '५५',
#     '▁dec',
#     'ib',
#     'el',
#     '▁होता',
#     '▁है',
#     '।'],
#    ['▁environment',
#     '▁protection',
#     '▁committee',
#     '▁ने',
#     '▁last',
#     '▁year',
#     '▁diwali',
#     '▁के',
#     '▁time',
#     '▁traffic',
#     '▁station',
#     '▁के',
#     '▁पास',
#     '▁noise',
#     '▁pollution',
#     '▁मापा',
#     '▁था',
#     '।'],
#    ['▁diwali',
#     '▁के',
#     '▁पहले',
#     '▁10',
#     '▁november',
#     '▁को',
#     '▁two',
#     '▁different',
#     '▁time',
#     '▁पर',
#     '▁की',
#     '▁गई'],
#    ['▁inspection',
#     '▁minimum',
#     '▁sound',
#     '▁pollution',
#     '▁72',
#     '.',
#     '5',
#     '▁and',
#     '▁maximum',
#     '▁83',
#     '.',
#     '6',
#     '▁पाया',
#     '▁गया',
#     '।'],
#    ['▁diwali',
#     '▁पर',
#     '▁maximum',
#     '▁लोग',
#     '▁इस',
#     '▁पर',
#     '▁ध्यान',
#     '▁नहीं',
#     '▁देते',
#     '▁और',
#     '▁high',
#     '▁sound',
#     '▁वाले',
#     '▁fire',
#     'cr',
#     'ack',
#     'ers',
#     '▁का',
#     '▁use',
#     '▁करते',
#     '▁हैं',
#     '।'],
#    ['▁ड',
#     'ौ',
#     'की',
#     '▁के',
#     '▁village',
#     '▁न',
#     'ग',
#     'ला',
#     '▁देव',
#     'ह',
#     'ंस',
#     '▁में',
#     '▁thursday',
#     '▁night',
#     '▁truck',
#     '▁ने',
#     '▁road',
#     '▁cross',
#     '▁करते',
#     '▁ग्रामीण',
#     '▁हरी',
#     'ओ',
#     'म',
#     '▁को',
#     '▁टक्कर',
#     '▁मार',
#     '▁दी',
#     '।'],
#    ['▁उनकी',
#     '▁death',
#     '▁से',
#     '▁a',
#     'ngry',
#     '▁villagers',
#     '▁ने',
#     '▁फतेह',
#     'ाबाद',
#     '▁road',
#     '▁पर',
#     '▁jam',
#     '▁लगा',
#     '▁दिया',
#     '।'],
#    ['▁force',
#     '▁ने',
#     '▁मौके',
#     '▁पर',
#     '▁पहुंच',
#     'कर',
#     '▁two',
#     '▁hours',
#     '▁से',
#     '▁लगे',
#     '▁jam',
#     '▁को',
#     '▁खुल',
#     'वाया',
#     '।'],
#    ['▁body',
#     '▁को',
#     '▁मोर',
#     'चर',
#     'ी',
#     '▁में',
#     '▁रख',
#     'वाने',
#     '▁के',
#     '▁बाद',
#     '▁बम',
#     'र',
#     'ौली',
#     '▁कटा',
#     'रा',
#     '▁चौक',
#     'ी',
#     '▁के',
#     '▁soldier',
#     '▁रवि',
#     'ंद्र',
#     '▁and',
#     '▁राम',
#     'नर',
#     'ेश',
#     '▁bi',
#     'ke',
#     '▁से',
#     '▁लौट',
#     '▁रहे',
#     '▁थे',
#     '।'],
#    ['▁तो',
#     'रा',
#     '▁चौक',
#     'ी',
#     '▁के',
#     '▁पास',
#     '▁bi',
#     'ke',
#     '▁divide',
#     'r',
#     '▁से',
#     '▁टकरा',
#     'ने',
#     '▁पर',
#     '▁दोनों',
#     '▁injured',
#     '▁हो',
#     '▁गए',
#     '।'],
#    ['▁इसी',
#     '▁दौरान',
#     '▁कला',
#     'ल',
#     '▁ख',
#     'े',
#     'ड़िया',
#     '▁पर',
#     '▁आगे',
#     '▁जाते',
#     '▁truck',
#     '▁driver',
#     '▁ने',
#     '▁sudden',
#     '▁bra',
#     'ke',
#     '▁मार',
#     '▁दिए',
#     '।'],
#    ['▁fast',
#     '▁speed',
#     '▁jeep',
#     '▁truck',
#     '▁के',
#     '▁पिछले',
#     '▁part',
#     '▁में',
#     '▁जा',
#     '▁घुस',
#     'ी',
#     '।'],
#    ['▁उसका',
#     '▁front',
#     '▁part',
#     '▁बुरी',
#     '▁तरह',
#     '▁क्षतिग्रस्त',
#     '▁हो',
#     '▁गया',
#     '।'],
#    ['▁आगे',
#     '▁बैठे',
#     '▁चौक',
#     'ी',
#     '▁प्रभारी',
#     '▁register',
#     '▁पाल',
#     '▁सिंह',
#     '▁की',
#     '▁spot',
#     '▁पर',
#     '▁ही',
#     '▁death',
#     '▁हो',
#     '▁गई',
#     '।'],
#    ['▁driver',
#     '▁या',
#     'कू',
#     'ब',
#     '▁and',
#     '▁soldier',
#     '▁अरविंद',
#     ',',
#     '▁रवि',
#     'ंद्र',
#     '▁व',
#     '▁राम',
#     'नर',
#     'ेश',
#     '▁wound',
#     'ed',
#     '▁हो',
#     '▁गए',
#     '।'],
#    ['▁मौके',
#     '▁पर',
#     '▁पहुंचे',
#     '▁officers',
#     '▁ने',
#     '▁wound',
#     'ed',
#     '▁को',
#     '▁s',
#     'n',
#     '▁emergency',
#     '▁में',
#     '▁admit',
#     '▁कराया',
#     '।'],
#    ['▁inspector',
#     '▁ताज',
#     'गंज',
#     '▁हरी',
#     '▁मोहन',
#     '▁ने',
#     '▁बताया',
#     '▁truck',
#     '▁driver',
#     '▁के',
#     '▁against',
#     '▁case',
#     '▁दर्ज',
#     '▁किया',
#     '▁है',
#     '।'],
#    ['▁friday',
#     '▁को',
#     '▁दर',
#     'ो',
#     'गा',
#     '▁के',
#     '▁body',
#     '▁को',
#     '▁police',
#     '▁line',
#     '▁में',
#     '▁salute',
#     '▁दी',
#     '▁गई',
#     '।'],
#    ['▁परि',
#     'जन',
#     '▁final',
#     '▁rituals',
#     '▁के',
#     '▁लिए',
#     '▁body',
#     '▁को',
#     '▁मैन',
#     'पुरी',
#     '▁ले',
#     '▁गए',
#     '।'],
#    ['▁वह',
#     '▁original',
#     'ly',
#     '▁ए',
#     'टा',
#     '▁के',
#     '▁मल',
#     'ा',
#     'वन',
#     '▁के',
#     '▁रहने',
#     '▁वाले',
#     '▁थे',
#     '।'],
#    ['▁family',
#     '▁में',
#     '▁two',
#     '▁sons',
#     '▁and',
#     '▁three',
#     '▁daughters',
#     '▁हैं',
#     '।'],
#    ['▁three',
#     '▁days',
#     '▁पहले',
#     '▁ही',
#     '▁हरी',
#     'पर्व',
#     'त',
#     '▁की',
#     '▁नेहरू',
#     '▁नगर',
#     '▁चौक',
#     'ी',
#     '▁से',
#     '▁बम',
#     'र',
#     'ौली',
#     '▁कटा',
#     'रा',
#     '▁transfer',
#     '▁हुआ',
#     '▁था',
#     '।'],
#    ['▁वहीं',
#     ',',
#     '▁वीर',
#     'वार',
#     '▁दिन',
#     'भर',
#     '▁भी',
#     '▁electricity',
#     '▁पर',
#     '▁dependent',
#     '▁होने',
#     '▁वाला',
#     '▁business',
#     '▁पूरी',
#     '▁तरह',
#     '▁से',
#     '▁ठ',
#     'प',
#     '▁रहा',
#     '।'],
#    ['▁यहां',
#     '▁तक',
#     '▁की',
#     '▁banks',
#     '▁and',
#     '▁offices',
#     '▁के',
#     '▁paper',
#     'work',
#     '▁प्रभावित',
#     '▁रहे',
#     '।'],
#    ['▁electricity',
#     '▁न',
#     '▁होने',
#     '▁की',
#     '▁reason',
#     '▁से',
#     '▁full',
#     '▁city',
#     '▁में',
#     '▁water',
#     '▁की',
#     '▁heavy',
#     '▁scarcity',
#     '▁बनी',
#     '▁रही',
#     '।'],
#    ['▁mobile',
#     '▁service',
#     '▁and',
#     '▁बाकी',
#     '▁work',
#     '▁भी',
#     '▁प्रभावित',
#     '▁रहे',
#     '।'],
#    ['▁ऊ',
#     'ध',
#     'म',
#     'पुर',
#     '▁से',
#     '▁आने',
#     '▁वाली',
#     '▁132',
#     '▁kv',
#     '▁line',
#     '▁complete',
#     '▁तरह',
#     '▁से',
#     '▁ठ',
#     'प',
#     '▁होकर',
#     '▁रह',
#     '▁गई',
#     '▁थी',
#     '।'],
#    ['▁nh',
#     'p',
#     'c',
#     '▁के',
#     '▁officer',
#     '▁व',
#     '▁employee',
#     '▁3',
#     '▁days',
#     '▁से',
#     '▁con',
#     't',
#     'in',
#     'ous',
#     'ly',
#     '▁electricity',
#     '▁service',
#     '▁बहाल',
#     '▁करने',
#     '▁में',
#     '▁लगे',
#     '▁हुए',
#     '▁थे',
#     '।'],
#    ['▁eve',
#     'ing',
#     '▁साढ़े',
#     '▁सात',
#     '▁बजे',
#     '▁electricity',
#     '▁बहाल',
#     '▁कर',
#     '▁दी',
#     '▁गई',
#     '।'],
#    ['▁buyers', '▁के', '▁रुख', '▁में', '▁change', '▁आया', '▁है', '।'],
#    ['▁head',
#     '▁पं',
#     'स',
#     'स',
#     '▁की',
#     '▁meeting',
#     '▁मनमाने',
#     '▁ढंग',
#     '▁से',
#     '▁करते',
#     '▁हैं',
#     '।'],
#    ['▁उन्होंने',
#     '▁पंचायती',
#     '▁राज',
#     '▁पदाधिकारी',
#     '▁को',
#     '▁head',
#     '▁द्वारा',
#     '▁works',
#     '▁में',
#     '▁बरती',
#     '▁जा',
#     '▁रही',
#     '▁irregular',
#     'ity',
#     '▁का',
#     '▁proof',
#     '▁भी',
#     '▁दिया',
#     '▁है',
#     '।'],
#    ['▁मह',
#     'ंत',
#     '▁ने',
#     '▁कहा',
#     '▁कि',
#     '▁mind',
#     '▁में',
#     '▁ही',
#     'न',
#     '▁emotions',
#     '▁को',
#     '▁न',
#     '▁आने',
#     '▁दें',
#     '▁और',
#     '▁lord',
#     '▁devotion',
#     '▁में',
#     '▁mind',
#     '▁लगाएं',
#     '।'],
#    ['▁god',
#     '▁का',
#     '▁remember',
#     '▁करने',
#     '▁मात्र',
#     '▁से',
#     '▁ही',
#     '▁human',
#     '▁suffering',
#     '▁से',
#     '▁free',
#     '▁हो',
#     '▁जाता',
#     '▁है',
#     '।'],
#    ['▁उसे',
#     '▁यह',
#     '▁बात',
#     '▁समझ',
#     'नी',
#     '▁होगी',
#     '▁कि',
#     '▁उसके',
#     '▁इस',
#     '▁activity',
#     '▁से',
#     '▁border',
#     '▁के',
#     '▁both',
#     '▁ओर',
#     '▁रहने',
#     '▁वाले',
#     '▁common',
#     '▁people',
#     '▁को',
#     '▁ही',
#     '▁damage',
#     '▁पहुंच',
#     '▁रहा',
#     '▁है',
#     '।'],
#    ['▁ह',
#     'वन',
#     '▁व',
#     '▁श्रीमद्',
#     'कथा',
#     '▁का',
#     '▁cooking',
#     '▁करने',
#     '▁के',
#     '▁लिए',
#     '▁hundreds',
#     '▁devotee',
#     '▁पहुंच',
#     '▁रहे',
#     '▁हैं',
#     '।'],
#    ['▁saturday',
#     '▁को',
#     '▁stories',
#     '▁end',
#     '▁होगी',
#     '▁और',
#     '▁ह',
#     'वन',
#     '▁में',
#     '▁पूर्ण',
#     'ा',
#     'हु',
#     'ति',
#     '▁डाली',
#     '▁जाएगी',
#     '।'],
#    ['▁इसमें',
#     '▁school',
#     '▁students',
#     '▁के',
#     '▁साथ',
#     '▁teacher',
#     '▁and',
#     '▁common',
#     '▁people',
#     '▁ने',
#     '▁भी',
#     '▁part',
#     '▁लिया',
#     '।'],
#    ['▁इन',
#     '▁people',
#     '▁का',
#     '▁कहना',
#     '▁था',
#     '▁कि',
#     '▁corruption',
#     '▁current',
#     '▁time',
#     '▁की',
#     '▁big',
#     '▁problem',
#     '▁बनकर',
#     '▁उभरी',
#     '▁है',
#     '।'],
#    ['▁इसके',
#     '▁लिए',
#     '▁common',
#     '▁man',
#     '▁को',
#     '▁आगे',
#     '▁आना',
#     '▁ही',
#     '▁होगा',
#     '।'],
#    ['▁उसी',
#     '▁time',
#     '▁से',
#     '▁इस',
#     '▁festival',
#     '▁को',
#     '▁मनाने',
#     '▁की',
#     '▁tradition',
#     '▁शुरू',
#     '▁हुई',
#     '।'],
#    ['▁उन्होंने',
#     '▁students',
#     '▁का',
#     '▁आह्वान',
#     '▁किया',
#     '▁कि',
#     '▁वे',
#     '▁मर्यादा',
#     '▁पुरुष',
#     'ो',
#     'तम',
#     '▁god',
#     '▁श्री',
#     'राम',
#     '▁के',
#     '▁life',
#     '▁से',
#     '▁inspiration',
#     '▁लें',
#     '।'],
#    ['▁31',
#     '▁october',
#     '▁को',
#     '▁world',
#     '▁में',
#     '▁hallow',
#     'een',
#     '▁day',
#     '▁मनाया',
#     '▁गया',
#     '।'],
#    ['▁इसीलिए', '▁वो', '▁इस', '▁day', '▁को', '▁मना', 'ते', '▁हैं', '।'],
#    ['▁है',
#     'लो',
#     'वी',
#     'न',
#     '▁parties',
#     '▁में',
#     '▁उन्हें',
#     '▁strange',
#     '▁है',
#     'लो',
#     'वी',
#     'न',
#     '▁dress',
#     'es',
#     '▁में',
#     '▁देखा',
#     '▁जाता',
#     '▁है',
#     '।'],
#    ['▁इस',
#     '▁तरह',
#     '▁one',
#     '▁ही',
#     '▁है',
#     'लो',
#     'वी',
#     'न',
#     '▁party',
#     '▁में',
#     '▁आपको',
#     '▁ढेरों',
#     '▁strange',
#     '▁faces',
#     '▁दिख',
#     '▁जाएंगे',
#     '।'],
#    ['▁इनमें',
#     '▁से',
#     '▁कुछ',
#     '▁तो',
#     '▁extreme',
#     '▁डरा',
#     'व',
#     'ने',
#     '▁होते',
#     '▁हैं',
#     ',',
#     '▁जबकि',
#     '▁कुछ',
#     '▁को',
#     '▁देखकर',
#     '▁आप',
#     '▁laugh',
#     '▁बिना',
#     '▁नहीं',
#     '▁रह',
#     '▁सकते',
#     '।'],
#    ['▁dehradun',
#     '▁',
#     'marg',
#     '▁situated',
#     '▁एक',
#     '▁fire',
#     'cr',
#     'ack',
#     'er',
#     '▁की',
#     '▁shop',
#     '▁में',
#     '▁fire',
#     '▁लगने',
#     '▁से',
#     '▁',
#     'हड़',
#     'क',
#     'ंप',
#     '▁मच',
#     '▁गया',
#     '।'],
#    ['▁ग',
#     'नी',
#     'मत',
#     '▁रही',
#     '▁कि',
#     '▁time',
#     '▁रहते',
#     '▁fire',
#     '▁पर',
#     '▁control',
#     '▁पा',
#     '▁लिया',
#     '▁गया',
#     '।'],
#    ['▁इस',
#     '▁time',
#     '▁shop',
#     '▁पर',
#     '▁customer',
#     '▁भी',
#     '▁present',
#     '▁थे',
#     '।'],
#    ['▁shop',
#     '▁master',
#     '▁ने',
#     '▁fire',
#     '▁cylinder',
#     '▁and',
#     '▁sand',
#     '▁से',
#     '▁fire',
#     '▁को',
#     '▁बुझाने',
#     '▁की',
#     '▁try',
#     '▁की',
#     '।'],
#    ['▁इस',
#     '▁बीच',
#     '▁fire',
#     '▁brigade',
#     '▁भी',
#     '▁मौके',
#     '▁पर',
#     '▁पहुंच',
#     '▁गया',
#     '▁था',
#     '।'],
#    ['▁incident',
#     '▁में',
#     '▁किसी',
#     '▁को',
#     '▁भी',
#     '▁injury',
#     '▁नहीं',
#     '▁आई',
#     '।'],
#    ['▁fire',
#     'cr',
#     'ack',
#     'ers',
#     '▁की',
#     '▁shop',
#     '▁में',
#     '▁fire',
#     '▁से',
#     '▁people',
#     '▁में',
#     '▁',
#     'हड़',
#     'क',
#     'ंप',
#     '▁मच',
#     '▁गया',
#     '।'],
#    ['▁fire',
#     '▁officer',
#     '▁दान',
#     'ी',
#     '▁राम',
#     '▁ने',
#     '▁बताया',
#     '▁कि',
#     '▁time',
#     '▁रहते',
#     '▁fire',
#     '▁पर',
#     '▁control',
#     '▁पा',
#     '▁लिया',
#     '▁गया',
#     '▁था',
#     '।'],
#    ['▁incident',
#     '▁को',
#     '▁देखते',
#     '▁हुए',
#     '▁market',
#     '▁में',
#     '▁भी',
#     '▁shopkeeper',
#     's',
#     '▁से',
#     '▁security',
#     '▁बरतन',
#     'े',
#     '▁के',
#     '▁strict',
#     '▁instructions',
#     '▁दे',
#     '▁दिए',
#     '▁गए',
#     '▁हैं',
#     '।'],
#    ['▁इस',
#     '▁एक',
#     '्',
#     'ट्रेस',
#     '▁का',
#     '▁name',
#     '▁है',
#     '▁',
#     '"',
#     'अ',
#     'व',
#     'नि',
#     '▁मोदी',
#     '"',
#     '।'],
#    ['▁अव',
#     'नि',
#     '▁gujarat',
#     '▁के',
#     '▁district',
#     '▁gandhi',
#     'nagar',
#     '▁की',
#     '▁रहने',
#     '▁वाली',
#     '▁हैं',
#     '।'],
#    ['▁हालांकि',
#     '▁बाद',
#     '▁में',
#     '▁house',
#     '▁owner',
#     '▁के',
#     '▁आने',
#     '▁के',
#     '▁बाद',
#     '▁disclose',
#     '▁हुआ',
#     '▁कि',
#     '▁किशोर',
#     'ी',
#     '▁उसकी',
#     '▁relative',
#     '▁है',
#     '।'],
#    ['▁house',
#     '▁वाले',
#     '▁market',
#     '▁गये',
#     '▁थे',
#     '▁इसलिये',
#     '▁किशोर',
#     'ी',
#     '▁को',
#     '▁house',
#     '▁में',
#     '▁ही',
#     '▁छोड़कर',
#     '▁gate',
#     '▁close',
#     '▁करके',
#     '▁चले',
#     '▁गये',
#     '।'],
#    ['▁किशोर',
#     'ी',
#     '▁के',
#     '▁घर',
#     'वालों',
#     '▁को',
#     '▁बुला',
#     'कर',
#     '▁council',
#     'or',
#     '▁व',
#     '▁police',
#     '▁की',
#     '▁presence',
#     '▁में',
#     '▁उनके',
#     '▁हवाले',
#     '▁कर',
#     '▁दिया',
#     '▁गया',
#     '।'],
#    ['▁सोन',
#     'ी',
#     '▁के',
#     '▁husband',
#     '▁का',
#     '▁death',
#     '▁हो',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁here', '▁daughter', '▁house', '▁में', '▁ही', '▁रो', 'ने', '▁लगी', '।'],
#    ['▁society', '▁वाले', '▁भी', '▁भाग', 'े', '।'],
#    ['▁instant',
#     'ly',
#     '▁आसपास',
#     '▁के',
#     '▁people',
#     '▁ने',
#     '▁इसकी',
#     '▁information',
#     '▁police',
#     '▁को',
#     '▁दी',
#     '।'],
#    ['▁council', 'or', '▁अनू', 'प', '▁सा', 'व', '▁पहुंचे', '।'],
#    ['▁तब', '▁तक', '▁an', 'ja', 'li', '▁भी', '▁आ', '▁गई', '।'],
#    ['▁उसने',
#     '▁कहा',
#     '▁that',
#     '▁ब',
#     'च्च',
#     'ी',
#     '▁उसकी',
#     '▁relative',
#     '▁है',
#     '।'],
#    ['▁उसके',
#     '▁family',
#     '▁की',
#     '▁position',
#     '▁okay',
#     '▁नहीं',
#     '▁होने',
#     '▁के',
#     '▁reason',
#     '▁इसे',
#     '▁हम',
#     '▁रख',
#     '▁रहे',
#     '▁हैं',
#     '।'],
#    ['▁गिरी',
#     'डी',
#     'ह',
#     '▁के',
#     '▁बेल',
#     'ा',
#     'टा',
#     'ंड़',
#     '▁village',
#     '▁में',
#     '▁mother',
#     '▁सुनी',
#     'ता',
#     '▁देवी',
#     '▁a',
#     'ka',
#     '▁सोन',
#     'ी',
#     '▁and',
#     '▁family',
#     '▁रहता',
#     '▁है',
#     '।'],
#    ['▁father',
#     '▁मं',
#     'टू',
#     '▁विश्व',
#     'कर्म',
#     'ा',
#     '▁का',
#     '▁death',
#     '▁हो',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁evening', '▁को', '▁mother', '▁and', '▁mam', 'a', '▁पहुंचे', '।'],
#    ['▁council',
#     'or',
#     '▁and',
#     '▁police',
#     '▁के',
#     '▁सामने',
#     '▁सोन',
#     'ी',
#     '▁देवी',
#     '▁अपने',
#     '▁relative',
#     '▁के',
#     '▁यहां',
#     '▁से',
#     '▁ब',
#     'च्च',
#     'ी',
#     '▁को',
#     '▁अपने',
#     '▁साथ',
#     '▁ले',
#     '▁गए',
#     '।'],
#    ['▁an',
#     'ja',
#     'li',
#     '▁का',
#     '▁कहना',
#     '▁था',
#     '▁कि',
#     '▁हम',
#     '▁ब',
#     'च्च',
#     'ी',
#     '▁को',
#     '▁नहीं',
#     '▁रख',
#     '▁सकते',
#     '।'],
#    ['▁if', '▁baby', '▁कुछ', '▁कर', '▁लेती', '▁तो', '▁क्या', '▁होता', '।'],
#    ['▁incident', '▁में', '▁taxi', '▁driver', '▁injured', '▁हो', '▁गया', '।'],
#    ['▁driver',
#     '▁को',
#     '▁civilian',
#     's',
#     '▁hospital',
#     '▁सुंदर',
#     'नगर',
#     '▁में',
#     '▁admit',
#     '▁करवाया',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁उसकी',
#     '▁both',
#     '▁legs',
#     '▁में',
#     '▁fracture',
#     '▁बताया',
#     '▁जा',
#     '▁रहा',
#     '▁है',
#     '।'],
#    ['▁वहां',
#     '▁doctors',
#     '▁ने',
#     '▁ganga',
#     '▁devi',
#     '▁dead',
#     '▁declare',
#     '▁कर',
#     '▁दिया',
#     '।'],
#    ['▁ganga',
#     '▁अपनी',
#     '▁sister',
#     '▁से',
#     '▁मिलने',
#     '▁mumbai',
#     '▁जा',
#     '▁रही',
#     '▁थी',
#     '▁and',
#     '▁mumbai',
#     '▁के',
#     '▁लिए',
#     '▁chandigarh',
#     '▁से',
#     '▁afternoon',
#     '▁बाद',
#     '▁उसकी',
#     '▁flight',
#     '▁थी',
#     '।'],
#    ['▁case',
#     '▁की',
#     '▁जांच',
#     '▁sub',
#     '▁inspector',
#     '▁सुर',
#     'ेंद्र',
#     '▁कुमार',
#     '▁को',
#     '▁सौंपी',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁d',
#     'sp',
#     '▁कुल',
#     'भूषण',
#     '▁वर्मा',
#     '▁ने',
#     '▁incident',
#     '▁की',
#     '▁confirmation',
#     '▁की',
#     '▁है',
#     '।'],
#    ['▁three',
#     '▁hours',
#     '▁बाद',
#     '▁police',
#     '▁empty',
#     '▁hand',
#     '▁वापस',
#     '▁लौट',
#     '▁आई',
#     '।'],
#    ['▁three',
#     '▁seats',
#     '▁के',
#     '▁nominee',
#     's',
#     '▁की',
#     '▁announcement',
#     '▁अटक',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁list',
#     '▁में',
#     '▁वे',
#     '▁ही',
#     '▁name',
#     '▁ic',
#     'lude',
#     'd',
#     '▁हैं',
#     ',',
#     '▁जिनकी',
#     '▁starting',
#     '▁से',
#     '▁ही',
#     '▁अटक',
#     'ल',
#     'ें',
#     '▁लगाई',
#     '▁जा',
#     '▁रही',
#     '▁थीं',
#     '।'],
#    ['▁only',
#     '▁अंचल',
#     '▁सोन',
#     'कर',
#     '▁east',
#     '▁region',
#     '▁से',
#     '▁east',
#     '▁m',
#     'la',
#     '▁रह',
#     '▁चुके',
#     '▁हैं',
#     '।'],
#    ['▁हालांकि',
#     ',',
#     '▁officers',
#     '▁ने',
#     '▁फिल',
#     'हाल',
#     '▁excavation',
#     '▁में',
#     '▁कोई',
#     '▁rock',
#     '▁मिलने',
#     '▁की',
#     '▁बात',
#     '▁नहीं',
#     '▁कही',
#     '▁है',
#     '।'],
#    ['▁शो',
#     'भ',
#     'न',
#     '▁government',
#     '▁ने',
#     '▁media',
#     '▁से',
#     '▁बात',
#     '▁करते',
#     '▁हुए',
#     '▁many',
#     '▁times',
#     '▁a',
#     'ngry',
#     '▁भी',
#     '▁हुए',
#     '▁और',
#     '▁अपने',
#     '▁कहे',
#     '▁statement',
#     '▁से',
#     '▁पलट',
#     'े',
#     '▁भी',
#     '।'],
#    ['▁उन्होंने',
#     '▁जहां',
#     '▁one',
#     '▁time',
#     '▁यह',
#     '▁कहा',
#     '▁कि',
#     '▁यदि',
#     '▁यह',
#     '▁operation',
#     '▁army',
#     '▁करती',
#     '▁तो',
#     '▁truth',
#     '▁अब',
#     '▁तक',
#     '▁सामने',
#     '▁आ',
#     '▁चुका',
#     '▁होता',
#     '।'],
#    ['▁हमने',
#     '▁तो',
#     '▁excavation',
#     '▁के',
#     '▁straight',
#     '▁broadcast',
#     '▁की',
#     '▁demand',
#     '▁की',
#     '▁थी',
#     '।'],
#    ['▁उन्होंने',
#     '▁यह',
#     '▁जरूर',
#     '▁माना',
#     '▁कि',
#     '▁उन्होंने',
#     '▁जिस',
#     '▁location',
#     '▁पर',
#     '▁बताया',
#     '▁गया',
#     '▁था',
#     '▁as',
#     'i',
#     '▁की',
#     '▁team',
#     '▁वहीं',
#     '▁पर',
#     '▁excavation',
#     '▁कर',
#     '▁रही',
#     '▁है',
#     '।'],
#    ['▁saturday',
#     '▁को',
#     '▁इस',
#     '▁issue',
#     '▁पर',
#     '▁office',
#     '▁ब',
#     'ियर',
#     'र',
#     '▁meeting',
#     '▁बुला',
#     'कर',
#     '▁deliberat',
#     'ion',
#     '▁किया',
#     '▁जाएगा',
#     '।'],
#    ['▁डि',
#     'प्ट',
#     'ी',
#     '▁v',
#     'p',
#     '▁corporate',
#     '▁services',
#     '▁city',
#     '▁में',
#     '▁present',
#     '▁रहे',
#     '▁लेकिन',
#     '▁union',
#     '▁officers',
#     '▁से',
#     '▁interaction',
#     '▁नहीं',
#     '▁हो',
#     '▁सकी',
#     '।'],
#    ['▁अब',
#     '▁इस',
#     '▁issue',
#     '▁possible',
#     '▁monday',
#     '▁को',
#     '▁interaction',
#     '▁हो',
#     '▁सकेगी',
#     '।'],
#    ['▁light',
#     '▁festival',
#     '▁diwali',
#     '▁आज',
#     '▁से',
#     '▁start',
#     '▁हो',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁friday',
#     '▁को',
#     '▁small',
#     '▁diwali',
#     '▁यानी',
#     '▁की',
#     '▁dhan',
#     'ter',
#     'as',
#     '▁है',
#     '।'],
#    ['▁diwali',
#     '▁में',
#     '▁houses',
#     '▁की',
#     '▁सा',
#     'ज',
#     '-',
#     'स',
#     'ज्जा',
#     '▁के',
#     '▁साथ',
#     '▁एक',
#     '▁attraction',
#     '▁beautiful',
#     '▁रंग',
#     'ोल',
#     'ियां',
#     '▁भी',
#     '▁हैं',
#     '।'],
#    ['▁house',
#     '▁के',
#     '▁बाहर',
#     '▁या',
#     '▁आंगन',
#     '▁में',
#     '▁बनी',
#     '▁beautiful',
#     '▁rango',
#     'li',
#     '▁house',
#     '▁की',
#     '▁beauty',
#     '▁में',
#     '▁चार',
#     '-',
#     'चा',
#     'ंद',
#     '▁लगा',
#     '▁देती',
#     '▁है',
#     '।'],
#    ['▁इसी',
#     '▁मौके',
#     '▁पर',
#     '▁हम',
#     '▁ये',
#     '▁कुछ',
#     '▁photos',
#     '▁gujarat',
#     '▁से',
#     '▁चुनकर',
#     '▁लाए',
#     '▁हैं',
#     '।'],
#    ['▁ये',
#     '▁beautiful',
#     '▁रंग',
#     'ोल',
#     'ियां',
#     '▁बनाकर',
#     '▁आप',
#     '▁भी',
#     '▁अपने',
#     '▁house',
#     '▁की',
#     '▁beauty',
#     '▁बढ़ा',
#     '▁सकते',
#     '▁हैं',
#     '।'],
#    ['▁notice',
#     '▁के',
#     '▁answer',
#     '▁के',
#     '▁लिए',
#     '▁12',
#     '▁november',
#     '▁की',
#     '▁date',
#     '▁decide',
#     '▁की',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁इसके',
#     '▁बाद',
#     '▁parents',
#     '▁ने',
#     '▁honor',
#     'able',
#     '▁high',
#     'co',
#     'ur',
#     't',
#     '▁का',
#     '▁gate',
#     '▁खटखटा',
#     'या',
#     '▁है',
#     '।'],
#    ['▁इस',
#     '▁बार',
#     '▁भी',
#     '▁फिर',
#     '▁fees',
#     '▁बढ़ाने',
#     '▁से',
#     '▁parents',
#     '▁में',
#     '▁रोष',
#     '▁पाया',
#     '▁गया',
#     '।'],
#    ['▁new',
#     '▁session',
#     '▁start',
#     '▁होने',
#     '▁के',
#     '▁five',
#     '▁months',
#     '▁बाद',
#     '▁एक',
#     'ाएक',
#     '▁fees',
#     '▁बढ़ाने',
#     '▁से',
#     '▁parents',
#     '▁सकते',
#     '▁में',
#     '▁आ',
#     '▁गए',
#     '▁है',
#     '।'],
#    ['▁parents',
#     '▁का',
#     '▁कहना',
#     '▁है',
#     '▁कि',
#     '▁repeated',
#     '▁fees',
#     '▁बढ़ाना',
#     '▁right',
#     '▁नहीं',
#     '▁है',
#     '।'],
#    ['▁इससे',
#     '▁children',
#     '▁की',
#     '▁studies',
#     '▁खराब',
#     '▁होने',
#     '▁के',
#     '▁साथ',
#     '-',
#     'साथ',
#     '▁उनके',
#     '▁business',
#     '▁पर',
#     '▁भी',
#     '▁प्रतिकूल',
#     '▁असर',
#     '▁पड़ता',
#     '▁है',
#     '।'],
#    ['▁head',
#     '▁ने',
#     '▁कहा',
#     '▁कि',
#     '▁government',
#     '▁work',
#     '▁में',
#     '▁transparency',
#     '▁रखकर',
#     '▁development',
#     '▁work',
#     '▁को',
#     '▁आगे',
#     '▁बढ़ाने',
#     '▁की',
#     '▁जरूरत',
#     '▁है',
#     '।'],
#    ['▁कहा',
#     '▁कि',
#     '▁schemes',
#     '▁के',
#     '▁execution',
#     '▁में',
#     '▁किसी',
#     '▁type',
#     '▁की',
#     '▁irregular',
#     'ity',
#     '▁tolerate',
#     '▁नहीं',
#     '▁की',
#     '▁जाएगी',
#     '।'],
#    ['▁meeting',
#     '▁में',
#     '▁पार',
#     'ा',
#     '▁teachers',
#     '▁को',
#     '▁building',
#     '▁construction',
#     '▁work',
#     '▁में',
#     '▁नहीं',
#     '▁लगाने',
#     '▁का',
#     '▁instructions',
#     '▁दिया',
#     '▁गया',
#     '।'],
#    ['▁',
#     'BEEO',
#     '▁से',
#     '▁block',
#     '▁में',
#     '▁under',
#     '▁construction',
#     '▁school',
#     '▁buildings',
#     '▁की',
#     '▁list',
#     '▁मांगी',
#     '▁गयी',
#     '।'],
#    ['▁health',
#     '▁department',
#     '▁and',
#     '▁सी',
#     'डीपी',
#     'ओ',
#     '▁की',
#     '▁absence',
#     '▁में',
#     '▁meeting',
#     '▁में',
#     '▁present',
#     '▁होने',
#     '▁आए',
#     '▁representatives',
#     '▁को',
#     '▁सभागार',
#     '▁में',
#     '▁बैठने',
#     '▁नहीं',
#     '▁दिया',
#     '▁गया',
#     '।'],
#    ['▁उन्होंने',
#     '▁cooperative',
#     '▁department',
#     '▁के',
#     '▁works',
#     '▁की',
#     '▁high',
#     '▁level',
#     '▁जांच',
#     '▁पर',
#     '▁बल',
#     '▁दिया',
#     '।'],
#    ['▁emergency',
#     '▁में',
#     '▁congress',
#     'man',
#     '▁leader',
#     '▁देव',
#     'कांत',
#     '▁बरुआ',
#     '▁ने',
#     '▁',
#     "'",
#     'in',
#     'di',
#     'ra',
#     '▁इज',
#     '▁india',
#     "'",
#     '▁का',
#     '▁सिद्धांत',
#     '▁रखा',
#     '▁था',
#     '।'],
#    ['▁लेकिन', '▁history', '▁के', '▁facts', '▁different', '▁हैं', '।'],
#    ['▁nationbuilding', '▁का', '▁glorious', '▁history', '▁है', '।'],
#    ['▁india',
#     '▁के',
#     '▁people',
#     '▁ने',
#     '▁ही',
#     '▁अपने',
#     '▁सचेत',
#     '▁श्रम',
#     '▁से',
#     '▁nation',
#     '▁को',
#     '▁विश्व',
#     'प्रति',
#     'ष्ठ',
#     '▁किया',
#     '▁है',
#     '।'],
#    ['▁ancient',
#     '▁national',
#     '▁integration',
#     '▁के',
#     '▁लिए',
#     '▁चंद्र',
#     'गुप्त',
#     '▁मौर्य',
#     ',',
#     '▁अशोक',
#     '▁etc',
#     '▁की',
#     '▁राज',
#     'व्यवस्था',
#     'एं',
#     '▁हैं',
#     '।'],
#    ['▁foreign',
#     '▁attack',
#     '▁and',
#     '▁सत्ता',
#     'धी',
#     'श',
#     'ों',
#     '▁से',
#     '▁टकरा',
#     'ने',
#     '▁वाले',
#     '▁great',
#     '▁men',
#     '▁की',
#     '▁big',
#     '▁श्रृंखला',
#     '▁है',
#     '।'],
#    ['▁big', '▁lie', '▁more', '▁effective', '▁होता', '▁है', '।'],
#    ['▁58',
#     '▁central',
#     '▁schemes',
#     '▁में',
#     '▁से',
#     '▁16',
#     '▁राजीव',
#     '▁गांधी',
#     '▁के',
#     '▁name',
#     '▁हैं',
#     '।'],
#    ['▁great', '▁men', '▁के', '▁name', '▁inspire', '▁करते', '▁हैं', '।'],
#    ['▁public',
#     '▁distribution',
#     '▁system',
#     '▁पहले',
#     '▁से',
#     '▁ही',
#     '▁in',
#     'f',
#     'am',
#     'ous',
#     '▁है',
#     '।'],
#    ['▁congress',
#     '▁को',
#     '▁इस',
#     '▁scheme',
#     '▁के',
#     '▁name',
#     '▁पर',
#     '▁vote',
#     '▁मांग',
#     'ने',
#     '▁से',
#     '▁कौन',
#     '▁रोकता',
#     '▁है',
#     '?'],
#    ['▁लेकिन',
#     '▁nam',
#     'ing',
#     '▁के',
#     '▁time',
#     '▁नेहरू',
#     '▁family',
#     '▁के',
#     '▁बाहर',
#     '▁भी',
#     '▁one',
#     '▁look',
#     '▁डालने',
#     '▁में',
#     '▁क्या',
#     '▁कठिनाई',
#     '▁है',
#     '?'],
#    ['▁पटेल', '▁great', '▁nation', '▁निर्माता', '▁हैं', '।'],
#    ['▁उन्होंने',
#     '▁अपनी',
#     '▁device',
#     '▁से',
#     '▁5',
#     '62',
#     '▁state',
#     '▁units',
#     '▁को',
#     '▁nation',
#     '▁से',
#     '▁जोड़ा',
#     '▁था',
#     '।'],
#    ['▁',
#     'P',
#     'ate',
#     'l',
#     '▁सबके',
#     '▁हैं',
#     ',',
#     '▁समूच',
#     'े',
#     '▁',
#     'I',
#     'nd',
#     'ia',
#     '▁के',
#     '▁favorite',
#     '▁हैं',
#     ',',
#     '▁but',
#     '▁',
#     'C',
#     'on',
#     'gress',
#     '▁उन्हें',
#     '▁सिर्फ',
#     '▁अपनी',
#     '▁property',
#     '▁मानती',
#     '▁है',
#     '।'],
#    ['▁public',
#     '▁distribution',
#     '▁system',
#     '▁का',
#     '▁name',
#     '▁',
#     'P',
#     'ate',
#     'l',
#     '▁पर',
#     '▁भी',
#     '▁किया',
#     '▁जा',
#     '▁सकता',
#     '▁है',
#     '।'],
#    ['▁इससे',
#     '▁',
#     'P',
#     'ate',
#     'l',
#     '▁के',
#     '▁importance',
#     '▁पर',
#     '▁कोई',
#     '▁difference',
#     '▁न',
#     '▁पड़ेगा',
#     '।'],
#    ['▁',
#     'C',
#     'on',
#     'gress',
#     '▁long',
#     '▁time',
#     '▁से',
#     '▁power',
#     '▁में',
#     '▁है',
#     '।'],
#    ['▁',
#     'S',
#     'che',
#     'me',
#     's',
#     '▁का',
#     '▁राजनीतिक',
#     'रण',
#     '▁',
#     'C',
#     'on',
#     'gress',
#     '▁ने',
#     '▁ही',
#     '▁किया',
#     '।'],
#    ['▁', 'P', 'art', 'y', '▁और', '▁family', '▁synonym', '▁हो', '▁गए', '।'],
#    ['▁',
#     'F',
#     'ami',
#     'ly',
#     '▁और',
#     '▁country',
#     '▁को',
#     '▁synonym',
#     '▁बताने',
#     '▁के',
#     '▁लिए',
#     '▁ही',
#     '▁',
#     "'I",
#     'nd',
#     'ra',
#     '▁इज',
#     '▁',
#     'I',
#     'nd',
#     'ia',
#     "'",
#     '▁की',
#     '▁नारे',
#     'बाजी',
#     '▁हुई',
#     '।'],
#    ['▁',
#     'S',
#     'che',
#     'me',
#     's',
#     '▁का',
#     '▁नामकरण',
#     '▁भी',
#     '▁domestic',
#     '▁issue',
#     '▁हो',
#     '▁गया',
#     '।'],
#    ['▁',
#     'G',
#     'over',
#     'n',
#     'ment',
#     '▁schemes',
#     '▁country',
#     '▁के',
#     '▁taxpayer',
#     's',
#     '▁से',
#     '▁संचित',
#     '▁राज',
#     'कोष',
#     '▁से',
#     '▁चलती',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'C',
#     'o',
#     'un',
#     'try',
#     '▁का',
#     '▁treasure',
#     '▁congress',
#     '▁के',
#     '▁एक',
#     '▁family',
#     '▁की',
#     '▁property',
#     '▁नहीं',
#     '▁है',
#     '।'],
#    ['▁',
#     'C',
#     'on',
#     'gress',
#     '▁की',
#     '▁देखा',
#     '-',
#     'देख',
#     'ी',
#     '▁हरेक',
#     '▁group',
#     '▁ने',
#     '▁अपने',
#     '▁great',
#     '▁men',
#     '▁गढ़',
#     'े',
#     '।'],
#    ['▁',
#     'R',
#     'eg',
#     'ion',
#     'al',
#     '▁groups',
#     '▁ने',
#     '▁मन',
#     'मा',
#     'फिक',
#     '▁politicians',
#     '▁के',
#     '▁names',
#     '▁से',
#     '▁schemes',
#     '▁चलाई',
#     'ं',
#     '।'],
#    ['▁',
#     'G',
#     're',
#     'at',
#     '▁man',
#     '▁सभी',
#     '▁के',
#     '▁होते',
#     '▁हैं',
#     ',',
#     '▁but',
#     '▁दल',
#     'ीय',
#     '▁great',
#     '▁man',
#     '▁की',
#     '▁list',
#     '▁बढ़ती',
#     '▁गई',
#     '।'],
#    ['▁',
#     'P',
#     're',
#     's',
#     'ent',
#     '▁हरेक',
#     '▁छोटे',
#     '-',
#     'बड़े',
#     '▁group',
#     '▁के',
#     '▁अपने',
#     '▁great',
#     '▁man',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'A',
#     'mer',
#     'ic',
#     'a',
#     '▁में',
#     '▁politicians',
#     '▁के',
#     '▁name',
#     '▁पर',
#     '▁government',
#     '▁schemes',
#     '▁नहीं',
#     '▁चलाई',
#     '▁जाती',
#     'ं',
#     '।'],
#    ['▁',
#     'I',
#     'nd',
#     'ia',
#     '▁में',
#     '▁इनका',
#     '▁justification',
#     '▁द',
#     'यनीय',
#     '▁है',
#     '।'],
#    ['▁',
#     'C',
#     'on',
#     'gress',
#     '▁अपनी',
#     '▁heritage',
#     '▁से',
#     '▁cut',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁',
#     'R',
#     'ah',
#     'ul',
#     '-S',
#     'on',
#     'iya',
#     '▁के',
#     '▁संदेश',
#     '▁या',
#     '▁उपदेश',
#     '▁ही',
#     '▁',
#     'C',
#     'on',
#     'gress',
#     '▁के',
#     '▁काम',
#     '▁आते',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'S',
#     'oc',
#     'ial',
#     '▁welfare',
#     '▁से',
#     '▁जुड़ी',
#     '▁योजनाओं',
#     '▁का',
#     '▁polit',
#     'ic',
#     'ization',
#     '▁न',
#     'िंद',
#     'नीय',
#     '▁है',
#     '।'],
#    ['▁उत्त',
#     'ार',
#     '▁state',
#     '▁में',
#     '▁different',
#     '▁laptop',
#     '▁में',
#     '▁',
#     'SP',
#     '▁chief',
#     '▁के',
#     '▁picture',
#     '▁हैं',
#     '।'],
#    ['▁बेशक',
#     '▁voter',
#     '▁बहुमत',
#     '▁प्राप्त',
#     '▁group',
#     '▁को',
#     '▁policy',
#     '▁निर्माण',
#     '▁का',
#     '▁right',
#     '▁देते',
#     '▁हैं',
#     '।'],
#    ['▁राज',
#     'कोष',
#     '▁का',
#     '▁political',
#     '▁दुरुपयोग',
#     '▁constitutional',
#     '▁crime',
#     '▁है',
#     '।'],
#    ['▁नामकरण',
#     '▁का',
#     '▁कोई',
#     '▁ethics',
#     '▁तो',
#     '▁develop',
#     '▁करना',
#     '▁ही',
#     '▁होगा',
#     '।'],
#    ['▁',
#     'P',
#     'oli',
#     'tic',
#     'ian',
#     '▁ही',
#     '▁हर',
#     '▁म',
#     'र्ज',
#     '▁की',
#     '▁medicine',
#     '▁नहीं',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'I',
#     'nd',
#     'ia',
#     '▁बहुआयाम',
#     'ी',
#     '▁brilliant',
#     '▁intellect',
#     '▁से',
#     '▁भरपूर',
#     '▁है',
#     '।'],
#    ['▁',
#     'H',
#     'ig',
#     'her',
#     '▁education',
#     '▁संस्थान',
#     '/',
#     'शोध',
#     '▁संस्थान',
#     '▁का',
#     '▁नाम',
#     '▁किसी',
#     '▁talent',
#     'ed',
#     '▁indian',
#     '▁scientist',
#     '▁के',
#     '▁नाम',
#     '▁पर',
#     '▁होना',
#     '▁चाहिए',
#     '।'],
#    ['▁',
#     'P',
#     'oli',
#     'tic',
#     's',
#     '▁में',
#     '▁sense',
#     '▁of',
#     '▁history',
#     '▁का',
#     '▁अभाव',
#     '▁है',
#     '।'],
#    ['▁',
#     'C',
#     'on',
#     's',
#     'ti',
#     'tu',
#     'tion',
#     '▁assembly',
#     '▁में',
#     '▁country',
#     '▁के',
#     '▁नामकरण',
#     '▁पर',
#     '▁भी',
#     '▁लंबी',
#     '▁बहस',
#     '▁हुई',
#     '▁थी',
#     '।'],
#    ['▁से',
#     'ठ',
#     '▁',
#     'G',
#     'ov',
#     'in',
#     'dda',
#     's',
#     ',',
#     '▁',
#     'K',
#     'a',
#     'mala',
#     'pati',
#     '▁',
#     'T',
#     'ri',
#     'path',
#     'i',
#     '▁आदि',
#     '▁ने',
#     '▁',
#     "'I",
#     'nd',
#     'ia',
#     "'",
#     '▁पर',
#     '▁जोर',
#     '▁दिया',
#     '।'],
#    ['▁भारत',
#     '▁name',
#     '▁को',
#     '▁38',
#     '▁और',
#     '▁इंडिया',
#     '▁को',
#     '▁51',
#     '▁vote',
#     '▁मिले',
#     '।'],
#    ['▁',
#     'B',
#     'as',
#     'ic',
#     '▁question',
#     '▁यह',
#     '▁है',
#     '▁कि',
#     '▁schemes',
#     '▁के',
#     '▁नामकरण',
#     '▁पर',
#     '▁deep',
#     '▁thought',
#     '▁क्यों',
#     '▁नहीं',
#     '▁होता',
#     '?'],
#    ['▁इसमें', '▁politics', '▁ही', '▁क्यों', '▁चलती', '▁है', '?'],
#    ['▁एक',
#     '▁ही',
#     '▁family',
#     '▁को',
#     '▁ऐसी',
#     '▁prominence',
#     '▁क्यों',
#     '▁है',
#     '?'],
#    ['▁सर्व',
#     'मान्य',
#     '▁popular',
#     '▁नामों',
#     '▁की',
#     '▁कोई',
#     '▁list',
#     '▁center',
#     '▁क्यों',
#     '▁नहीं',
#     '▁बनाता',
#     '?'],
#    ['▁इसी',
#     '▁अराजकता',
#     '▁के',
#     '▁चलते',
#     '▁युवा',
#     '▁पीढ़ी',
#     '▁freedom',
#     '▁struggle',
#     '▁सेनानियों',
#     '▁के',
#     '▁नाम',
#     '▁भी',
#     '▁भूल',
#     '▁रही',
#     '▁है',
#     '।'],
#    ['▁यहां', '▁तरह', '-', 'तरह', '▁के', '▁great', '▁actor', '▁हैं', '।'],
#    ['▁कुछ',
#     '▁',
#     'T',
#     'V',
#     '▁के',
#     '▁गढ़',
#     'े',
#     '▁हुए',
#     '▁और',
#     '▁mostly',
#     '▁political',
#     '▁पक्षपात',
#     '▁से',
#     '▁रंग',
#     'े',
#     '▁हुए',
#     '।'],
#    ['▁नामकरण', '▁inform', 'ative', '▁होता', '▁है', '।'],
#    ['▁ऋग्वेद',
#     '▁के',
#     '▁',
#     "'",
#     'en',
#     'light',
#     'en',
#     'ed',
#     "'",
#     '▁में',
#     '▁name',
#     '▁रखने',
#     '▁को',
#     '▁ही',
#     '▁knowledge',
#     '▁का',
#     '▁start',
#     '▁बताया',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁',
#     'S',
#     'che',
#     'me',
#     's',
#     '▁का',
#     '▁अच्छा',
#     '▁नामकरण',
#     '▁motivation',
#     'al',
#     '▁भी',
#     '▁होता',
#     '▁है',
#     '।'],
#    ['▁अभी',
#     '▁दो',
#     '-',
#     'ती',
#     'न',
#     '▁month',
#     '▁पूर्व',
#     '▁हुए',
#     '▁एक',
#     '▁survey',
#     '▁में',
#     '▁country',
#     '▁के',
#     '▁आधे',
#     '▁से',
#     '▁च',
#     '्या',
#     'दा',
#     '▁',
#     'V',
#     'ill',
#     'age',
#     '▁town',
#     '▁',
#     'R',
#     'am',
#     '▁name',
#     '▁से',
#     '▁जुड़े',
#     '▁बताए',
#     '▁गए',
#     '▁थे',
#     '।'],
#    ['▁अनेक',
#     '▁नाम',
#     '▁special',
#     '▁और',
#     '▁vision',
#     '▁विशेष',
#     '▁के',
#     '▁representative',
#     '▁हो',
#     '▁जाते',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'C',
#     'on',
#     'gress',
#     '▁friends',
#     '▁से',
#     '▁request',
#     '▁है',
#     '▁कि',
#     '▁एक',
#     '▁ही',
#     '▁परिवार',
#     '▁में',
#     '▁name',
#     '▁खोजने',
#     '▁की',
#     '▁ल',
#     'त',
#     '▁से',
#     '▁बाहर',
#     '▁आएं',
#     '।'],
#    ['▁',
#     'I',
#     'nd',
#     'ia',
#     '▁के',
#     '▁history',
#     '▁में',
#     '▁ही',
#     '▁golden',
#     '▁a',
#     'ura',
#     '▁वाले',
#     '▁अनेक',
#     '▁नाम',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'F',
#     'ami',
#     'ly',
#     '▁ने',
#     '▁compensation',
#     '▁के',
#     '▁रूप',
#     '▁में',
#     '▁25',
#     '.',
#     '82',
#     '▁crore',
#     '▁rupees',
#     '▁मांगे',
#     '▁थे',
#     '।'],
#    ['▁उनका', '▁death', '▁भी', '▁इसी', '▁accident', '▁में', '▁हुआ', '▁था', '।'],
#    ['▁इसमें',
#     '▁near',
#     'ly',
#     '▁70',
#     '▁फीस',
#     'द',
#     '▁राशि',
#     '▁',
#     '(',
#     '15',
#     '.',
#     '12',
#     '▁lakh',
#     '▁rupees',
#     ')',
#     '▁',
#     'M',
#     'SR',
#     'T',
#     'C',
#     '▁देगा',
#     '।'],
#    ['▁उन्होंने',
#     '▁इस',
#     '▁दौरान',
#     '▁party',
#     '▁supporter',
#     's',
#     '▁व',
#     '▁members',
#     '▁से',
#     '▁organizational',
#     '▁activities',
#     '▁पर',
#     '▁चर्चा',
#     '▁की',
#     '।'],
#    ['▁इस',
#     '▁बार',
#     '▁twin',
#     '▁city',
#     '▁के',
#     '▁उन',
#     '▁लोगों',
#     '▁को',
#     '▁deep',
#     'aw',
#     'ali',
#     '▁अंधेरे',
#     '▁में',
#     '▁मना',
#     'नी',
#     '▁पड़',
#     '▁सकती',
#     '▁है',
#     '।'],
#    ['▁जिन्होंने',
#     '▁electricity',
#     '▁का',
#     '▁bill',
#     '▁due',
#     '▁date',
#     '▁में',
#     '▁नहीं',
#     '▁भरा',
#     '▁है',
#     '।'],
#    ['▁',
#     'D',
#     'ue',
#     '▁date',
#     '▁के',
#     '▁15',
#     '▁days',
#     '▁के',
#     '▁बाद',
#     '▁connection',
#     '▁काटे',
#     '▁जा',
#     '▁रहे',
#     '▁हैं',
#     '।'],
#    ['▁इसी',
#     '▁वजह',
#     '▁से',
#     '▁electricity',
#     '▁के',
#     '▁office',
#     '▁connection',
#     '▁कट',
#     'ने',
#     '▁वाले',
#     '▁consumers',
#     '▁की',
#     '▁भीड़',
#     '▁बढ़',
#     '▁रही',
#     '▁है',
#     '।'],
#    ['▁', 'C', 'on', 's', 'um', 'ers', '▁परेशान', '▁हैं', '।'],
#    ['▁इसीलिए',
#     '▁सभी',
#     '▁sub',
#     '▁division',
#     '▁के',
#     '▁',
#     'XEN',
#     '▁व',
#     '▁',
#     'SDO',
#     '▁को',
#     '▁यह',
#     '▁target',
#     '▁पूरे',
#     '▁करने',
#     '▁के',
#     '▁order',
#     '▁दिए',
#     '▁गए',
#     '▁हैं',
#     '।'],
#    ['▁31',
#     '▁october',
#     '▁इस',
#     '▁target',
#     '▁की',
#     '▁end',
#     '▁date',
#     '▁थी',
#     '▁जो',
#     '▁complete',
#     '▁नहीं',
#     '▁हो',
#     '▁सकी',
#     '।'],
#    ['▁दोनों',
#     '▁precious',
#     '▁metals',
#     '▁के',
#     '▁वै',
#     'श्र',
#     'ि',
#     '्व',
#     'क',
#     '▁value',
#     '▁में',
#     '▁up',
#     's',
#     '▁and',
#     '▁down',
#     's',
#     '▁के',
#     '▁मद्देनज',
#     'र',
#     '▁इसमें',
#     '▁change',
#     '▁किया',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁',
#     'P',
#     're',
#     'c',
#     'ious',
#     '▁metals',
#     '▁का',
#     '▁import',
#     '▁duty',
#     '▁value',
#     '▁पर',
#     '▁custom',
#     '▁duty',
#     '▁लगाया',
#     '▁जाता',
#     '▁है',
#     '।'],
#    ['▁इस',
#     '▁कारण',
#     '▁illegal',
#     '▁रूप',
#     '▁से',
#     '▁travel',
#     '▁करने',
#     '▁वालों',
#     '▁में',
#     '▁कमी',
#     '▁आई',
#     '▁है',
#     '।'],
#    ['▁यह', '▁supreme', '▁court', '▁का', '▁oral', '▁आदेश', '▁है', '।'],
#    ['▁उन्होंने',
#     '▁कहा',
#     '▁यह',
#     '▁country',
#     '▁में',
#     '▁सेवानिवृत्त',
#     '▁officers',
#     '▁और',
#     '▁social',
#     '▁workers',
#     '▁द्वारा',
#     '▁propagat',
#     '▁किया',
#     '▁जा',
#     '▁रहा',
#     '▁खतरनाक',
#     '▁circulation',
#     '▁है',
#     '।'],
#    ['▁अब',
#     '▁retirement',
#     '▁के',
#     '▁बाद',
#     '▁sudden',
#     '▁उन्हें',
#     '▁',
#     'K',
#     'no',
#     'wl',
#     'ed',
#     'ge',
#     '▁attain',
#     '▁हुआ',
#     '▁कि',
#     '▁सभी',
#     '▁leader',
#     '▁crazy',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'K',
#     'an',
#     'n',
#     'ur',
#     '▁country',
#     '▁का',
#     '▁ऐसा',
#     '▁first',
#     '▁district',
#     '▁बन',
#     '▁गया',
#     '▁है',
#     '▁जिसमें',
#     '▁अब',
#     '▁कोई',
#     '▁family',
#     '▁landless',
#     '▁नहीं',
#     '▁है',
#     '।',
#     "',"],
#    ['▁यह', '▁historical', '▁step', '▁है', '।'],
#    ['▁उन्होंने',
#     '▁सभी',
#     '▁states',
#     '▁से',
#     '▁kerala',
#     '▁में',
#     '▁land',
#     '▁distribution',
#     '▁के',
#     '▁उदाहरण',
#     '▁से',
#     '▁सीख',
#     '▁लेने',
#     '▁की',
#     '▁अपील',
#     '▁की',
#     '।'],
#    ['▁उन्होंने',
#     '▁कहा',
#     '▁कि',
#     '▁ऐसे',
#     '▁dec',
#     'es',
#     'ion',
#     '▁के',
#     '▁लिए',
#     '▁political',
#     '▁wisdom',
#     '▁और',
#     '▁कड़े',
#     '▁rules',
#     '▁की',
#     '▁need',
#     '▁पड़ती',
#     '▁है',
#     '।'],
#    ['▁seven',
#     '▁years',
#     '▁back',
#     '▁भी',
#     '▁',
#     'S',
#     'up',
#     're',
#     'me',
#     '▁court',
#     '▁ने',
#     '▁पुलिस',
#     '▁सुधार',
#     '▁को',
#     '▁लेकर',
#     '▁एक',
#     '▁order',
#     '▁दिया',
#     '▁था',
#     '।'],
#    ['▁वह', '▁order', '▁भी', '▁कुछ', '▁ऐसा', '▁ही', '▁था', '।'],
#    ['▁अपने',
#     '▁आप',
#     '▁से',
#     '▁पूछ',
#     'िए',
#     '▁that',
#     '▁क्या',
#     '▁उन',
#     '▁orders',
#     '▁का',
#     '▁राज्यों',
#     '▁में',
#     '▁compliance',
#     '▁हुआ'],
#    ['▁offender',
#     '▁मोहन',
#     'पुर',
#     '▁ई',
#     'ट',
#     'वा',
#     '▁',
#     'marg',
#     '▁होते',
#     '▁हुए',
#     '▁b',
#     'odh',
#     'ga',
#     'ya',
#     '▁ब',
#     'कर',
#     'ौर',
#     '▁bridge',
#     '▁of',
#     '▁पास',
#     '▁खड़ा',
#     '▁किया',
#     '▁था',
#     '।'],
#    ['▁thursday',
#     '▁को',
#     '▁truck',
#     's',
#     '▁की',
#     '▁intensive',
#     '▁जा',
#     'च',
#     '▁हो',
#     '▁रही',
#     '▁थी',
#     '।'],
#    ['▁जब',
#     '▁police',
#     '▁',
#     'B',
#     'ak',
#     'ra',
#     'ur',
#     '▁',
#     'B',
#     'odh',
#     'ga',
#     'ya',
#     '▁bridge',
#     '▁के',
#     '▁पास',
#     '▁पहुंची',
#     '▁तो',
#     '▁लूट',
#     '▁के',
#     '▁truck',
#     '▁से',
#     '▁अपराधी',
#     '▁भागने',
#     '▁लगे',
#     '।'],
#    ['▁भाग',
#     '▁रहे',
#     '▁criminals',
#     '▁में',
#     '▁दो',
#     '▁को',
#     '▁truck',
#     '▁के',
#     '▁साथ',
#     '▁arrest',
#     '▁कर',
#     '▁लिया',
#     '▁गया',
#     '।'],
#    ['▁',
#     'P',
#     'oli',
#     'ce',
#     '▁station',
#     '▁chief',
#     '▁ने',
#     '▁बताया',
#     '▁that',
#     '▁इन',
#     '▁criminals',
#     '▁का',
#     '▁एक',
#     '▁बहुत',
#     '▁बड़ा',
#     '▁gang',
#     '▁है',
#     '।'],
#    ['▁जिसका', '▁master', '▁mind', '▁', 'P', 'ra', 'mod', '▁है', '।'],
#    ['▁pra',
#     'mod',
#     '▁ने',
#     '▁अन्य',
#     '▁criminals',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁information',
#     '▁दी',
#     '▁है',
#     '।'],
#    ['▁इस',
#     '▁बार',
#     '▁आप',
#     '▁जब',
#     '▁market',
#     '▁में',
#     '▁children',
#     '▁के',
#     '▁लिए',
#     '▁fire',
#     'cr',
#     'ack',
#     'ers',
#     '▁की',
#     '▁',
#     'S',
#     'h',
#     'op',
#     'ping',
#     '▁करने',
#     '▁जाएंगे',
#     '▁तो',
#     '▁खाली',
#     '▁हाथ',
#     '▁नहीं',
#     '▁आएंगे',
#     '।'],
#    ['▁',
#     'C',
#     'ere',
#     'mony',
#     '▁में',
#     '▁पूर्व',
#     '▁prime',
#     '▁minister',
#     '▁',
#     'I',
#     'nd',
#     'ra',
#     '▁',
#     'G',
#     'and',
#     'hi',
#     '▁को',
#     '▁tribute',
#     '▁अर्प',
#     'ित',
#     '▁की',
#     '▁गई',
#     '।'],
#    ['▁यह',
#     '▁information',
#     '▁school',
#     '▁के',
#     '▁principal',
#     '▁',
#     'N',
#     'a',
#     'fe',
#     '▁',
#     'S',
#     'ing',
#     'h',
#     '▁ने',
#     '▁दी',
#     '।'],
#    ['▁उन्होंने',
#     '▁बताया',
#     '▁कि',
#     '▁teacher',
#     '▁and',
#     '▁professor',
#     's',
#     '▁ने',
#     '▁indira',
#     '▁gandhi',
#     '▁के',
#     '▁चित्र',
#     '▁पर',
#     '▁push',
#     'pa',
#     'ja',
#     'li',
#     '▁अर्प',
#     'ित',
#     '▁की',
#     '।'],
#    ['▁progress',
#     '▁के',
#     '▁path',
#     '▁पर',
#     '▁',
#     'H',
#     'ary',
#     'ana',
#     '▁विषय',
#     '▁पर',
#     '▁essay',
#     '▁competition',
#     '▁का',
#     '▁आयोजन',
#     '▁किया',
#     '▁गया',
#     '।'],
#    ['▁',
#     'M',
#     'an',
#     'ju',
#     '▁la',
#     'x',
#     'sh',
#     'mi',
#     '▁first',
#     '▁and',
#     '▁shilp',
#     'a',
#     '▁ने',
#     '▁second',
#     '▁स्थान',
#     '▁प्राप्त',
#     '▁किया',
#     '।'],
#    ['▁',
#     'P',
#     'r',
#     'inc',
#     'ip',
#     'al',
#     '▁ने',
#     '▁haryana',
#     '▁की',
#     '▁',
#     'P',
#     'ro',
#     'gress',
#     '▁विषय',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁information',
#     '▁दी',
#     '।'],
#    ['▁उसका', '▁body', '▁drain', '▁के', '▁पास', '▁पड़ा', '▁मिला', '▁था', '।'],
#    ['▁मरने',
#     '▁वाले',
#     '▁युवक',
#     '▁की',
#     '▁पहचान',
#     '▁har',
#     'ish',
#     '▁ge',
#     'h',
#     'lot',
#     '▁के',
#     '▁रूप',
#     '▁में',
#     '▁हुई',
#     '▁है',
#     '।'],
#    ['▁युवक',
#     '▁के',
#     '▁body',
#     '▁पर',
#     '▁गोली',
#     '▁के',
#     '▁दो',
#     '▁marks',
#     '▁मिले',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'E',
#     'v',
#     'ent',
#     '▁site',
#     '▁पर',
#     '▁पहुंचने',
#     '▁पर',
#     '▁पता',
#     '▁चला',
#     '▁कि',
#     '▁उसकी',
#     '▁death',
#     '▁हो',
#     '▁चुकी',
#     '▁है',
#     '।'],
#    ['▁बाद',
#     '▁में',
#     '▁उसकी',
#     '▁identify',
#     '▁',
#     'D',
#     'har',
#     'mapura',
#     '▁resident',
#     '▁',
#     'H',
#     'ar',
#     'ish',
#     '▁के',
#     '▁रूप',
#     '▁में',
#     '▁हुई',
#     '।'],
#    ['▁युवक',
#     '▁की',
#     '▁waist',
#     '▁व',
#     '▁back',
#     '▁पर',
#     '▁दो',
#     '▁गोली',
#     '▁मारी',
#     '▁गई',
#     '▁है',
#     '।'],
#    ['▁',
#     'H',
#     'ar',
#     'ish',
#     '▁10',
#     'वीं',
#     '▁की',
#     '▁studying',
#     '▁बीच',
#     '▁में',
#     '▁छोड़',
#     '▁रखी',
#     '▁है',
#     '।'],
#    ['▁फिल',
#     'हाल',
#     '▁वह',
#     '▁unemployed',
#     '▁था',
#     '▁और',
#     '▁उसकी',
#     '▁संगत',
#     '▁anti',
#     '▁social',
#     '▁elements',
#     '▁के',
#     '▁साथ',
#     '▁थी',
#     '।'],
#    ['▁last',
#     '▁time',
#     '▁लोगों',
#     '▁ने',
#     '▁',
#     'H',
#     'ar',
#     'ish',
#     '▁को',
#     '▁एक',
#     '▁person',
#     '▁के',
#     '▁साथ',
#     '▁देखा',
#     '▁था',
#     '।'],
#    ['▁इस',
#     '▁दौरान',
#     '▁',
#     'K',
#     'ot',
#     'ran',
#     'ka',
#     '▁स्थित',
#     '▁ph',
#     'e',
#     '▁department',
#     '▁के',
#     '▁office',
#     '▁में',
#     '▁lock',
#     '▁लटका',
#     '▁मिला',
#     '▁and',
#     '▁employee',
#     '▁न',
#     'दार',
#     'द',
#     '▁मिले',
#     '।'],
#    ['▁जिसमें',
#     '▁बड़ी',
#     '▁number',
#     '▁में',
#     '▁employees',
#     '▁के',
#     '▁साथ',
#     '▁साथ',
#     '▁कई',
#     '▁high',
#     '▁officers',
#     '▁भी',
#     '▁duty',
#     '▁से',
#     '▁गैर',
#     '▁हाजिर',
#     '▁पाए',
#     '▁गए',
#     '।'],
#    ['▁tehsil',
#     'dar',
#     '▁',
#     'K',
#     'ot',
#     'ran',
#     'ka',
#     '▁स्थित',
#     '▁ph',
#     'e',
#     '▁department',
#     '▁के',
#     '▁office',
#     '▁पहुंचे',
#     '▁तो',
#     '▁वहां',
#     '▁lock',
#     '▁लगा',
#     '▁हुआ',
#     '▁था',
#     '।'],
#    ['▁कोई', '▁भी', '▁employee', '▁वहां', '▁present', '▁नहीं', '▁था', '।'],
#    ['▁',
#     'K',
#     'ot',
#     'ran',
#     'ka',
#     '▁hospital',
#     '▁में',
#     '▁doctors',
#     '▁के',
#     '▁अलावा',
#     '▁14',
#     '▁employees',
#     '▁को',
#     '▁गैर',
#     '▁हाजिर',
#     '▁पाया',
#     '▁गया',
#     '।'],
#    ['▁',
#     'B',
#     'M',
#     'O',
#     '▁खुद',
#     '▁भी',
#     '▁duty',
#     '▁पर',
#     '▁present',
#     '▁नहीं',
#     '▁थी',
#     '।'],
#    ['▁इसके',
#     '▁साथ',
#     '▁साथ',
#     '▁',
#     'BDO',
#     '▁office',
#     '▁में',
#     '▁दो',
#     '▁temporary',
#     '▁employee',
#     '▁को',
#     '▁छोड़',
#     '▁कर',
#     '▁',
#     'BDO',
#     '▁including',
#     '▁अन्य',
#     '▁employee',
#     '▁office',
#     '▁में',
#     '▁present',
#     '▁नहीं',
#     '▁थे',
#     '।'],
#    ['▁',
#     'CDPO',
#     '▁office',
#     '▁का',
#     '▁working',
#     '▁भी',
#     '▁एक',
#     '▁pe',
#     'on',
#     '▁चला',
#     '▁रहा',
#     '▁था',
#     '।'],
#    ['▁office',
#     '▁के',
#     '▁register',
#     '▁में',
#     '▁employees',
#     '▁की',
#     '▁attendance',
#     '▁next',
#     '▁2',
#     '▁days',
#     '▁तक',
#     '▁लगी',
#     '▁हुई',
#     '▁थी',
#     '।'],
#    ['▁इसके',
#     '▁साथ',
#     '▁',
#     'CADP',
#     '▁office',
#     '▁में',
#     '▁सिर्फ',
#     '▁',
#     'T',
#     'SO',
#     '▁ही',
#     '▁हाजिर',
#     '▁थे',
#     ',',
#     '▁अन्य',
#     '▁employees',
#     '▁गैर',
#     '▁हाजिर',
#     '▁थे',
#     '।'],
#    ['▁इन',
#     '▁सभी',
#     '▁employees',
#     '▁की',
#     '▁list',
#     '▁prepare',
#     '▁कर',
#     '▁tehsil',
#     'dar',
#     '▁ने',
#     '▁district',
#     '▁commissioner',
#     '▁के',
#     '▁पास',
#     '▁भेजी',
#     '▁है',
#     '।'],
#    ['▁sources',
#     '▁के',
#     '▁हवाले',
#     '▁से',
#     '▁आ',
#     '▁रही',
#     '▁खबर',
#     '▁के',
#     '▁according',
#     '▁',
#     'R',
#     'a',
#     'ja',
#     'ram',
#     '▁minister',
#     '▁पद',
#     '▁से',
#     '▁हटाए',
#     '▁जाने',
#     '▁के',
#     '▁बाद',
#     '▁से',
#     '▁tension',
# ...
#     '▁position',
#     '▁में',
#     '▁इसे',
#     '▁',
#     'berlin',
#     '▁और',
#     '▁bru',
#     's',
#     's',
#     'el',
#     's',
#     '▁द्वारा',
#     '▁लगाए',
#     '▁जाने',
#     '▁वाले',
#     '▁म',
#     'ित',
#     'व्यय',
#     'िता',
#     '▁के',
#     '▁rules',
#     '▁स्वीकार',
#     '▁करने',
#     '▁होंगे',
#     '।'],
#    ['▁time', '▁से', '▁पहले', '▁यौवन', 'ः', '▁जल्दी', '▁बड़ा', '▁होना'],
#    ['▁शोध',
#     '▁दर्शाते',
#     '▁हैं',
#     '▁कि',
#     '▁african',
#     '-',
#     'am',
#     'eri',
#     'can',
#     '▁तथा',
#     '▁his',
#     'pan',
#     'ic',
#     '▁girls',
#     '▁अपनी',
#     '▁age',
#     '▁की',
#     '▁गोर',
#     'ी',
#     '▁girls',
#     '▁की',
#     '▁comparison',
#     '▁में',
#     '▁कम',
#     '▁age',
#     '▁में',
#     '▁यौवन',
#     '▁प्राप्त',
#     '▁कर',
#     '▁लेती',
#     '▁हैं',
#     '।'],
#    ['▁physical',
#     '▁change',
#     '▁का',
#     '▁यह',
#     '▁meaning',
#     '▁नहीं',
#     '▁है',
#     '▁कि',
#     '▁यौवन',
#     '▁near',
#     '▁है'],
#    ['▁इस',
#     '▁बात',
#     '▁के',
#     '▁कोई',
#     '▁testimon',
#     'y',
#     '▁नहीं',
#     '▁हैं',
#     '▁कि',
#     '▁hormone',
#     '▁अथवा',
#     '▁किसी',
#     '▁other',
#     '▁chemicals',
#     '▁को',
#     '▁दोष',
#     '▁दिया',
#     '▁जा',
#     '▁सकता',
#     '▁है'],
#    ['▁experts',
#     '▁का',
#     '▁मानना',
#     '▁है',
#     '▁कि',
#     '▁obesity',
#     '▁प्रकोप',
#     ',',
#     '▁कम',
#     '▁age',
#     '▁में',
#     '▁यौवन',
#     '▁का',
#     '▁एक',
#     '▁कारण',
#     '▁हो',
#     '▁सकता',
#     '▁है'],
#    ['▁time',
#     '▁से',
#     '▁पहले',
#     '▁यौवन',
#     '▁का',
#     '▁मामला',
#     '▁boys',
#     '▁में',
#     '▁उतना',
#     '▁effective',
#     '▁नहीं',
#     '▁है'],
#    ['▁सी',
#     '.',
#     'एन',
#     '.',
#     'एन',
#     '.',
#     '▁के',
#     '▁former',
#     '▁correspondent',
#     '▁पै',
#     'ट',
#     '▁ई',
#     'थ',
#     'रिज',
#     '▁children',
#     '▁के',
#     '▁health',
#     '▁और',
#     '▁family',
#     '▁issues',
#     '▁में',
#     '▁specialist',
#     '▁journalist',
#     '▁हैं',
#     '।'],
#    ['▁क्या',
#     '▁mother',
#     '▁को',
#     '▁worried',
#     '▁होना',
#     '▁चाहिए',
#     ',',
#     '▁यदि',
#     '▁उसकी',
#     '▁daughter',
#     '▁में',
#     '▁7',
#     '▁or',
#     '▁8',
#     '▁year',
#     '▁की',
#     '▁age',
#     '▁में',
#     '▁ही',
#     '▁breasts',
#     '▁का',
#     '▁development',
#     '▁तथा',
#     '▁genital',
#     's',
#     '▁के',
#     '▁बाल',
#     '▁निकलना',
#     '▁start',
#     '▁हो',
#     '▁जाएं',
#     '?'],
#    ['▁इस',
#     '▁week',
#     '▁ऑ',
#     'र',
#     'लै',
#     'न्ड',
#     'ो',
#     ',',
#     '▁फ्लोर',
#     'िड',
#     'ा',
#     '▁में',
#     '▁american',
#     '▁बाल',
#     '▁medicine',
#     '▁अकादमी',
#     '▁के',
#     '▁annual',
#     '▁conference',
#     '▁में',
#     '▁बाल',
#     '▁medicine',
#     '▁एंड',
#     'ो',
#     'क्र',
#     'ाइन',
#     'ोल',
#     'ॉ',
#     'ज',
#     'िस्ट',
#     '▁डॉ',
#     '.',
#     '▁पॉल',
#     '▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '्ज',
#     '▁ने',
#     '▁clear',
#     '▁किया',
#     '▁कि',
#     '▁ये',
#     '▁आरंभिक',
#     '▁physical',
#     '▁change',
#     '▁american',
#     '▁girls',
#     '▁में',
#     '▁आम',
#     '▁बात',
#     '▁है',
#     ',',
#     '▁ये',
#     '▁new',
#     '▁चलन',
#     '▁दर्शाते',
#     '▁हैं',
#     '।'],
#    ['▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '्ज',
#     '▁कहते',
#     '▁हैं',
#     ',',
#     '▁',
#     '"',
#     'मैं',
#     '▁बहुत',
#     '-',
#     'सा',
#     '▁time',
#     '▁parents',
#     '▁को',
#     '▁यह',
#     '▁trust',
#     '▁दिलाने',
#     '▁में',
#     '▁खर्च',
#     '▁करता',
#     '▁हूँ',
#     '▁',
#     '-',
#     '▁कि',
#     '▁आम',
#     '▁तौर',
#     '▁से',
#     '▁यह',
#     '▁पूर्ण',
#     '▁यौवन',
#     '▁की',
#     '▁direction',
#     '▁में',
#     '▁द्रुत',
#     '▁progress',
#     '▁को',
#     '▁नहीं',
#     '▁दर्शाता',
#     '।',
#     '"'],
#    ['▁development',
#     '▁के',
#     '▁direct',
#     '▁symptoms',
#     '▁जैसे',
#     '▁breasts',
#     '▁का',
#     '▁अंकुर',
#     'ित',
#     '▁होना',
#     ',',
#     '▁genital',
#     's',
#     '▁और',
#     '▁का',
#     'ँ',
#     'ख',
#     '▁के',
#     '▁बाल',
#     '▁तथा',
#     '▁physical',
#     '▁smell',
#     '▁girls',
#     '▁में',
#     '▁time',
#     '▁से',
#     '▁पहले',
#     '▁दिख',
#     '▁रही',
#     '▁है',
#     '।'],
#    ['▁लेकिन',
#     '▁पिछले',
#     '▁four',
#     '▁centuries',
#     '▁में',
#     '▁रज',
#     'ो',
#     'दर्शन',
#     '▁',
#     '(',
#     'प्रथम',
#     '▁मासिक',
#     '-',
#     'धर्म',
#     ')',
#     '▁की',
#     '▁age',
#     '▁में',
#     '▁बहुत',
#     '▁मामूली',
#     '▁change',
#     '▁रहा',
#     '▁है',
#     '।'],
#    ['▁united',
#     '▁states',
#     '▁में',
#     ',',
#     '▁average',
#     '▁age',
#     '▁12',
#     '.',
#     '5',
#     '▁year',
#     '▁है',
#     ',',
#     '▁जो',
#     '▁year',
#     '▁1970',
#     '▁में',
#     '▁12',
#     '.',
#     '75',
#     '▁थी',
#     '।'],
#    ['▁जब',
#     '▁breasts',
#     '▁विकसित',
#     '▁होना',
#     '▁start',
#     '▁होते',
#     '▁हैं',
#     '▁तो',
#     '▁पहले',
#     '▁रज',
#     'ो',
#     'दर्शन',
#     '▁में',
#     '▁कम',
#     '▁से',
#     '▁कम',
#     '▁दो',
#     '▁से',
#     '▁तीन',
#     '▁year',
#     '▁लगते',
#     '▁हैं',
#     '▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '्ज',
#     '▁बताते',
#     '▁हैं',
#     '▁',
#     ',',
#     '▁जो',
#     '▁',
#     '"',
#     'gir',
#     'l',
#     's',
#     '▁में',
#     '▁समय',
#     '-',
#     'पूर्व',
#     '▁यौवन',
#     'ः',
#     '▁इस',
#     '▁आम',
#     '▁problem',
#     '▁से',
#     '▁निपटने',
#     '▁के',
#     '▁लिए',
#     '▁आवश्यक',
#     '▁मार्ग',
#     'दर्श',
#     'िका',
#     '।',
#     '"',
#     '▁के',
#     '▁लेखक',
#     '▁भी',
#     '▁हैं'],
#    ['▁यौवन',
#     '▁के',
#     '▁development',
#     '▁का',
#     '▁सबसे',
#     '▁accurate',
#     '▁testing',
#     '▁time',
#     '▁है',
#     '।'],
#    ['▁यौवन',
#     '▁का',
#     '▁start',
#     '▁क्या',
#     '▁है',
#     ',',
#     '▁इस',
#     '▁बारे',
#     '▁में',
#     '▁बहस',
#     '▁होती',
#     '▁है',
#     ',',
#     '▁लेकिन',
#     '▁जब',
#     '▁8',
#     '▁year',
#     '▁की',
#     '▁age',
#     '▁से',
#     '▁पहले',
#     '▁breasts',
#     '▁development',
#     '▁के',
#     '▁साथ',
#     '▁वृद्धि',
#     '▁होती',
#     '▁है',
#     '▁दो',
#     '▁इसे',
#     '▁',
#     '"',
#     'बाल',
#     '-',
#     'प्र',
#     'ौ',
#     'ढ़',
#     '"',
#     '▁कहते',
#     '▁हैं',
#     '।'],
#    ['▁most',
#     '▁cases',
#     '▁में',
#     '▁यह',
#     '▁process',
#     '▁slow',
#     '▁हो',
#     '▁जाएगी',
#     '▁अथवा',
#     '▁रुक',
#     '▁जाएगी',
#     '▁',
#     '-',
#     '▁जिसका',
#     '▁बाल',
#     '▁doctor',
#     '▁नज़दीक',
#     '▁से',
#     '▁inspection',
#     '▁कर',
#     '▁सकते',
#     '▁हैं',
#     '।'],
#    ['▁अधिक',
#     '▁द्रुत',
#     '▁progress',
#     '▁की',
#     '▁position',
#     '▁में',
#     '▁एन्ड',
#     'ो',
#     'क्र',
#     'ाइन',
#     'ोल',
#     'ॉ',
#     'ज',
#     'िस्ट',
#     '▁द्वारा',
#     '▁check',
#     '▁up',
#     '▁की',
#     '▁आवश्यकता',
#     '▁हो',
#     '▁सकती',
#     '▁है',
#     '▁ताकि',
#     '▁tumor',
#     's',
#     '▁अथवा',
#     '▁cyst',
#     '▁जैसी',
#     '▁गम्भीर',
#     '▁problems',
#     '▁की',
#     '▁संभावना',
#     'ओं',
#     '▁को',
#     '▁दूर',
#     '▁किया',
#     '▁जा',
#     '▁सके',
#     '।'],
#    ['▁समय',
#     '-',
#     'पूर्व',
#     '▁मासिक',
#     '-',
#     'धर्म',
#     '▁तथा',
#     '▁other',
#     '▁results',
#     '▁को',
#     '▁abort',
#     '▁करने',
#     '▁के',
#     '▁लिए',
#     '▁treatment',
#     '▁हैंः',
#     '▁bones',
#     '▁की',
#     '▁समय',
#     '-',
#     'पूर्व',
#     '▁आयु',
#     '-',
#     'वृद्धि',
#     ',',
#     '▁जिसके',
#     '▁कारण',
#     '▁अ',
#     'विकसित',
#     '▁वृद्धि',
#     '▁तथा',
#     '▁adult',
#     '▁के',
#     '▁रूप',
#     '▁में',
#     '▁ना',
#     'टा',
#     '▁कद',
#     '▁हो',
#     '▁सकता',
#     '▁है',
#     '।'],
#    ['▁drug',
#     '▁अथवा',
#     '▁hormone',
#     '▁treatment',
#     '▁के',
#     '▁लिए',
#     '▁संस्तुत',
#     'ियाँ',
#     ',',
#     '▁child',
#     '▁की',
#     '▁age',
#     ',',
#     '▁development',
#     '▁दर',
#     ',',
#     '▁वृद्धि',
#     '▁दर',
#     ',',
#     '▁तथा',
#     '▁emotional',
#     '▁वयस्क',
#     'ता',
#     '▁पर',
#     '▁निर्भर',
#     '▁करती',
#     '▁हैं',
#     '।'],
#    ['▁',
#     'P',
#     's',
#     'y',
#     'ch',
#     'ologist',
#     '▁पहलू',
#     '▁भी',
#     '▁important',
#     '▁हैं',
#     '।'],
#    ['▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '़',
#     'ज',
#     '▁medicines',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁सजग',
#     '▁हैं',
#     '▁लेकिन',
#     '▁स्वीकार',
#     '▁करते',
#     '▁हैं',
#     ',',
#     '▁',
#     '"',
#     'य',
#     'ौ',
#     'वन',
#     '▁को',
#     '▁दबा',
#     'ना',
#     '▁practical',
#     '▁issue',
#     '▁बढ़ा',
#     '▁सकता',
#     '▁है',
#     ',',
#     '▁तथा',
#     '▁girls',
#     '▁अपने',
#     '▁companions',
#     '▁से',
#     '▁different',
#     '▁महसूस',
#     '▁करने',
#     '▁लग',
#     '▁सकती',
#     '▁हैं',
#     '।',
#     '"'],
#    ['▁दूसरी',
#     '▁बड़ी',
#     '▁problem',
#     '▁समझी',
#     '▁जा',
#     '▁सकती',
#     '▁हैः',
#     '▁parents',
#     '▁बस',
#     '▁नहीं',
#     '▁चाहते',
#     '▁कि',
#     '▁उनकी',
#     '▁कम',
#     '▁age',
#     '▁की',
#     '▁daughter',
#     '▁को',
#     '▁मासिक',
#     '-',
#     'धर्म',
#     '▁हो',
#     '।'],
#    ['▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '़',
#     'ज',
#     '▁ने',
#     '▁कहा',
#     ',',
#     '▁',
#     '"',
#     'वे',
#     '▁pregnancy',
#     '▁के',
#     '▁risk',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁चिंता',
#     '▁करते',
#     '▁हैं',
#     ',',
#     '▁or',
#     '▁फिर',
#     '▁यह',
#     '▁कि',
#     '▁वे',
#     '▁किस',
#     '▁तरह',
#     '▁से',
#     '▁स्वच्छता',
#     '▁बनाए',
#     '▁रखें',
#     'गी',
#     '।',
#     '"'],
#    ['▁एक',
#     '▁महिला',
#     ',',
#     '▁जिनकी',
#     '▁daughter',
#     '▁को',
#     '▁10',
#     '▁year',
#     '▁की',
#     '▁age',
#     '▁में',
#     '▁मासिक',
#     '▁religion',
#     '▁start',
#     '▁हो',
#     '▁गया',
#     '▁था',
#     ',',
#     '▁याद',
#     '▁करती',
#     '▁हैं',
#     ',',
#     '▁',
#     '"',
#     'यह',
#     '▁झ',
#     'ट',
#     'का',
#     '▁था',
#     '।',
#     '’'],
#    ['▁यद्यपि',
#     '▁इस',
#     '▁बात',
#     '▁के',
#     '▁symptoms',
#     '▁थे',
#     '▁तथा',
#     '▁हमने',
#     '▁मासिक',
#     '-',
#     'धर्म',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁बात',
#     '▁भी',
#     '▁की',
#     '▁थी',
#     ',',
#     '▁लेकिन',
#     '▁वह',
#     '▁emotional',
#     '▁रूप',
#     '▁से',
#     '▁तैयार',
#     '▁नहीं',
#     '▁थी',
#     '।'],
#    ['▁वह',
#     '▁अपने',
#     '▁school',
#     '▁से',
#     '▁डर',
#     'ी',
#     '▁हुई',
#     '▁तथा',
#     '▁परेशान',
#     '▁लौट',
#     'ी',
#     '▁कि',
#     '▁अपनी',
#     '▁friends',
#     '▁में',
#     '▁उसे',
#     '▁सबसे',
#     '▁पहले',
#     '▁मासिक',
#     '▁religion',
#     '▁start',
#     '▁हुआ',
#     '▁था',
#     '।'],
#    ['▁untimel',
#     'y',
#     '▁यौवन',
#     '▁के',
#     '▁causes',
#     '▁के',
#     '▁बारे',
#     '▁में',
#     '▁बहुत',
#     '▁से',
#     '▁well',
#     '▁known',
#     '▁सिद्धांत',
#     '▁हैं',
#     '।'],
#    ['▁फिर',
#     '▁भी',
#     ',',
#     '▁इस',
#     '▁बात',
#     '▁के',
#     '▁कोई',
#     '▁sustain',
#     'ed',
#     '▁testimon',
#     'y',
#     '▁नहीं',
#     '▁है',
#     '▁कि',
#     '▁milk',
#     '▁अथवा',
#     '▁other',
#     '▁खाद्य',
#     '-',
#     'पद',
#     'ार्थ',
#     'ों',
#     '▁में',
#     '▁hormone',
#     ',',
#     '▁en',
#     'vir',
#     'on',
#     'n',
#     'ment',
#     '▁में',
#     '▁chemicals',
#     '▁अथवा',
#     '▁media',
#     '▁में',
#     '▁यौन',
#     'ोन्मुख',
#     'ी',
#     '▁messages',
#     '▁पर',
#     '▁charges',
#     '▁लगाया',
#     '▁जा',
#     '▁सके',
#     '।'],
#    ['▁boys',
#     '▁भी',
#     '▁',
#     '-',
#     '▁girls',
#     '▁की',
#     '▁ही',
#     '▁तरह',
#     '▁',
#     '-',
#     '▁समय',
#     '-',
#     'पूर्व',
#     '▁यौवन',
#     '▁प्राप्त',
#     '▁कर',
#     '▁रहे',
#     '▁हैं',
#     '।'],
#    ['▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '़',
#     'ज',
#     '▁यह',
#     '▁rules',
#     '▁specified',
#     '▁करते',
#     '▁हैं',
#     '▁कि',
#     '▁इसका',
#     '▁सबसे',
#     '▁main',
#     '▁कारण',
#     '▁obesity',
#     '▁का',
#     '▁प्रकोप',
#     '▁है',
#     '।'],
#    ['▁उन्होंने',
#     '▁year',
#     '▁2001',
#     '▁में',
#     '▁6',
#     '▁से',
#     '▁9',
#     '▁year',
#     '▁की',
#     '▁girls',
#     '▁के',
#     '▁ऊपर',
#     '▁study',
#     '▁संचालित',
#     '▁करने',
#     '▁में',
#     '▁help',
#     '▁की',
#     '▁थी',
#     ',',
#     '▁जो',
#     '▁body',
#     '▁के',
#     '▁fat',
#     '▁को',
#     '▁यौवन',
#     '▁के',
#     '▁time',
#     '▁के',
#     '▁साथ',
#     '▁जोड़ती',
#     '▁है',
#     '।'],
#    ['▁अन्य',
#     '▁result',
#     '▁इस',
#     '▁निष्कर्ष',
#     '▁का',
#     '▁support',
#     '▁करते',
#     '▁हैं',
#     ',',
#     '▁परन्तु',
#     '▁इसमें',
#     '▁contribution',
#     '▁करने',
#     '▁वाले',
#     '▁बहुत',
#     '▁से',
#     '▁other',
#     '▁factor',
#     '▁भी',
#     '▁हैं',
#     '।'],
#    ['▁इस',
#     '▁country',
#     '▁में',
#     ',',
#     '▁african',
#     '-',
#     'am',
#     'eri',
#     'can',
#     '▁तथा',
#     '▁his',
#     'pan',
#     'ic',
#     '▁girls',
#     '▁में',
#     '▁अपनी',
#     '▁age',
#     '▁वाली',
#     '▁गोर',
#     'ी',
#     '▁girls',
#     '▁से',
#     '▁पहले',
#     '▁यौवन',
#     '▁प्राप्त',
#     '▁करने',
#     '▁की',
#     '▁प्रवृत्ति',
#     '▁होती',
#     '▁है',
#     '।'],
#    ['▁इस', '▁बात', '▁के', '▁बहुत', '-', 'से', '▁clarification', '▁हैं', '।'],
#    ['▁global',
#     '▁level',
#     '▁पर',
#     ',',
#     '▁समय',
#     '-',
#     'पूर्व',
#     '▁यौवन',
#     '▁का',
#     '▁प्रतिरूप',
#     ',',
#     '▁economic',
#     '▁condition',
#     '▁से',
#     '▁लेकर',
#     '▁weather',
#     '▁व',
#     '▁genes',
#     '▁तक',
#     ',',
#     '▁सभी',
#     '▁चीजों',
#     '▁से',
#     '▁प्रभावित',
#     '▁प्रतीत',
#     '▁होते',
#     '▁हैं',
#     '।'],
#    ['▁अन्य',
#     '▁पहेली',
#     'ः',
#     '▁यद्यपि',
#     '▁boys',
#     '▁face',
#     '▁व',
#     '▁genital',
#     's',
#     '▁के',
#     '▁बाल',
#     '▁कम',
#     '▁age',
#     '▁में',
#     '▁प्राप्त',
#     '▁कर',
#     '▁रहे',
#     '▁हैं',
#     ',',
#     '▁लेकिन',
#     '▁पूर्ण',
#     '▁रूप',
#     '▁से',
#     '▁यौवन',
#     '▁का',
#     '▁चलन',
#     '▁उनमें',
#     '▁girls',
#     '▁जितन',
#     'ा',
#     '▁clear',
#     '▁नहीं',
#     '▁है',
#     '।'],
#    ['▁ए',
#     '.',
#     'ए',
#     '.',
#     'पी',
#     '.',
#     '▁conference',
#     '▁में',
#     '▁present',
#     '▁होने',
#     '▁वाले',
#     '▁other',
#     '▁doctors',
#     '▁ने',
#     '▁subject',
#     '▁की',
#     '▁complex',
#     'ities',
#     '▁का',
#     '▁support',
#     '▁किया',
#     '।'],
#    ['▁यहां',
#     '▁तक',
#     '▁कि',
#     '▁शिशु',
#     'ओं',
#     '▁और',
#     '▁children',
#     '▁में',
#     '▁भी',
#     '▁ac',
#     'ne',
#     '▁और',
#     '▁genital',
#     's',
#     '▁के',
#     '▁बाल',
#     '▁देखा',
#     '▁जाना',
#     '▁आम',
#     '▁हो',
#     '▁गया',
#     '▁है',
#     '।'],
#    ['▁मॉ',
#     'रिस',
#     'टा',
#     'उन',
#     ',',
#     '▁new',
#     '▁jersey',
#     '▁में',
#     '▁गॉ',
#     'र',
#     'ये',
#     'ब',
#     '▁children',
#     "'",
#     's',
#     '▁hospital',
#     '▁में',
#     '▁बाल',
#     '▁doctor',
#     '▁एन्ड',
#     'ो',
#     'क्र',
#     'ाइन',
#     'ोल',
#     'ॉ',
#     'ज',
#     'िस्ट',
#     ',',
#     '▁डॉ',
#     '.',
#     '▁लॉ',
#     'र',
#     'ेन्स',
#     '▁silver',
#     'man',
#     '▁कहते',
#     '▁हैं',
#     ',',
#     '▁',
#     '"',
#     'हमें',
#     '▁इसके',
#     '▁बारे',
#     '▁में',
#     '▁सावधान',
#     '▁रहने',
#     '▁की',
#     '▁आवश्यकता',
#     '▁है',
#     '▁कि',
#     '▁हम',
#     '▁यौवन',
#     '▁के',
#     '▁real',
#     '▁start',
#     '▁की',
#     '▁किस',
#     '▁तरह',
#     '▁से',
#     '▁पहचान',
#     '▁करते',
#     '▁हैं',
#     '।',
#     '"'],
#    ['▁parents',
#     '▁को',
#     '▁इस',
#     '▁बारे',
#     '▁में',
#     '▁राय',
#     '▁लेने',
#     '▁के',
#     '▁लिए',
#     '▁अपने',
#     '▁बाल',
#     '▁doctor',
#     '▁से',
#     '▁मार्गदर्शन',
#     '▁लेने',
#     '▁में',
#     '▁संकोच',
#     '▁नहीं',
#     '▁करना',
#     '▁चाहिए',
#     '▁कि',
#     '▁अपने',
#     '▁children',
#     '▁से',
#     '▁कैसे',
#     '▁बात',
#     '▁करें',
#     '।'],
#    ['▁कैप',
#     '्लो',
#     'वि',
#     'ट',
#     '्ज',
#     '▁ने',
#     '▁advice',
#     '▁दी',
#     ',',
#     '▁',
#     '"',
#     'इस',
#     'का',
#     '▁meaning',
#     '▁required',
#     '▁time',
#     '▁से',
#     '▁पहले',
#     '▁बातचीत',
#     '▁करना',
#     '▁हो',
#     '▁सकता',
#     '▁है',
#     '।',
#     '"'],
#    ['▁यदि',
#     '▁आप',
#     '▁calm',
#     '▁रहेंगे',
#     '▁तो',
#     '▁आपका',
#     '▁बच्चा',
#     '▁सामान्यतः',
#     '▁ठीक',
#     '▁से',
#     '▁response',
#     '▁देगा',
#     '।'],
#    ['▁time',
#     '▁से',
#     '▁पूर्व',
#     '▁development',
#     '▁करने',
#     '▁वाली',
#     '▁girls',
#     '▁का',
#     '▁यह',
#     '▁trust',
#     '▁दिला',
#     'ए',
#     '▁जाने',
#     '▁की',
#     '▁आवश्यकता',
#     '▁होती',
#     '▁है',
#     '▁कि',
#     '▁भले',
#     '▁ही',
#     '▁यह',
#     '▁time',
#     '▁से',
#     '▁पूर्व',
#     '▁हो',
#     '▁रहा',
#     '▁हो',
#     '▁लेकिन',
#     '▁यह',
#     '▁common',
#     '▁life',
#     '▁का',
#     '▁part',
#     '▁है',
#     '।'],
#    ['▁वीर',
#     'वार',
#     '▁को',
#     '▁temperature',
#     '▁में',
#     '▁3',
#     '.',
#     '1',
#     '▁degree',
#     '▁c',
#     'el',
#     'si',
#     'us',
#     '▁गिरावट',
#     '▁दर्ज',
#     '▁की',
#     '▁गई',
#     '।'],
#    ['▁w',
#     'ed',
#     'nes',
#     'दिन',
#     '▁night',
#     '▁को',
#     '▁हुई',
#     '▁rain',
#     '▁व',
#     '▁ठंड',
#     '▁air',
#     '▁ने',
#     '▁people',
#     '▁को',
#     '▁खूब',
#     '▁ठंड',
#     '▁का',
#     '▁एहसास',
#     '▁कराया',
#     '।'],
#    ['▁गुरु',
#     'वार',
#     '▁को',
#     '▁people',
#     '▁sweat',
#     'er',
#     '▁पहन',
#     '▁कर',
#     '▁markets',
#     '▁व',
#     '▁अपने',
#     '▁destination',
#     '▁की',
#     '▁ओर',
#     '▁निकले',
#     '।'],
#    ...]}}
